# %%
# =============================================================================
# STEP 0: INSTALL DEPENDENCIES
# =============================================================================
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes
# !pip install -q sentence-transformers faiss-cpu

print("✓ Dependencies installed. Please RESTART RUNTIME now.")
print("After restart, run the cells below.")
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.4/284.4 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 19.1 MB/s eta 0:00:00
#   Building wheel for unsloth (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 52.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 24.8 MB/s eta 0:00:00
# ERROR: Operation cancelled by user
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 119.3 MB/s eta 0:00:00
# ✓ Dependencies installed. Please RESTART RUNTIME now.
# After restart, run the cells below.

# %%
# =============================================================================
# STEP 1: IMPORTS
# =============================================================================
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from typing import List, Tuple
import pickle
from unsloth import FastLanguageModel
import torch

print("✓ Imports successful")
# Out:
# /tmp/ipython-input-274030368.py:9: UserWarning: WARNING: Unsloth should be imported before transformers, peft to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ✓ Imports successful

# %%
# =============================================================================
# STEP 2: DEFINE RETRIEVER CLASS
# =============================================================================
class TranslationRetriever:
    def __init__(self, model_name='paraphrase-multilingual-MiniLM-L12-v2'):
        """Initialize retriever with embedding model"""
        self.embedding_model = SentenceTransformer(model_name)
        self.index = None
        self.spanish_sentences = []
        self.english_sentences = []

    def build_knowledge_base(self, spanish_file, english_file):
        """Build FAISS index from parallel files"""
        print("Loading sentences...")
        with open(spanish_file, 'r', encoding='utf-8') as f:
            self.spanish_sentences = [line.strip() for line in f if line.strip()]

        with open(english_file, 'r', encoding='utf-8') as f:
            self.english_sentences = [line.strip() for line in f if line.strip()]

        assert len(self.spanish_sentences) == len(self.english_sentences), \
            f"Mismatch: {len(self.spanish_sentences)} Spanish vs {len(self.english_sentences)} English"

        print(f"✓ Loaded {len(self.spanish_sentences)} sentence pairs")
        print(f"\nFirst example:")
        print(f"ES: {self.spanish_sentences[0][:100]}...")
        print(f"EN: {self.english_sentences[0][:100]}...")

        # Generate embeddings
        print("\n⏳ Generating embeddings (this takes ~5-10 minutes for 50k sentences)...")
        embeddings = self.embedding_model.encode(
            self.spanish_sentences,
            show_progress_bar=True,
            batch_size=32,
            convert_to_numpy=True
        )

        # Normalize for cosine similarity
        faiss.normalize_L2(embeddings)

        # Build FAISS index
        print("Building FAISS index...")
        dimension = embeddings.shape[1]
        self.index = faiss.IndexFlatIP(dimension)
        self.index.add(embeddings)

        print(f"✓ Knowledge base built with {self.index.ntotal} vectors")

    def retrieve(self, query: str, k: int = 1) -> List[Tuple[str, str, float]]:
        """Retrieve top-k most similar translation pairs"""
        if self.index is None:
            raise ValueError("Knowledge base not built. Call build_knowledge_base() first")

        query_embedding = self.embedding_model.encode([query], convert_to_numpy=True)
        faiss.normalize_L2(query_embedding)

        distances, indices = self.index.search(query_embedding, k)

        results = []
        for dist, idx in zip(distances[0], indices[0]):
            results.append((
                self.spanish_sentences[idx],
                self.english_sentences[idx],
                float(dist)
            ))

        return results

    def save(self, save_path):
        """Save the retriever to disk"""
        faiss.write_index(self.index, f"{save_path}_index.faiss")
        with open(f"{save_path}_data.pkl", 'wb') as f:
            pickle.dump({
                'spanish': self.spanish_sentences,
                'english': self.english_sentences
            }, f)
        print(f"✓ Saved to {save_path}")

    def load(self, load_path):
        """Load the retriever from disk"""
        self.index = faiss.read_index(f"{load_path}_index.faiss")
        with open(f"{load_path}_data.pkl", 'rb') as f:
            data = pickle.load(f)
            self.spanish_sentences = data['spanish']
            self.english_sentences = data['english']
        print(f"✓ Loaded from {load_path}")

print("✓ TranslationRetriever class defined")
# Out:
# ✓ TranslationRetriever class defined

# %%
# =============================================================================
# STEP 3: BUILD KNOWLEDGE BASE (Run once, then use load() instead)
# =============================================================================
print("="*70)
print("BUILDING KNOWLEDGE BASE")
print("="*70)

retriever = TranslationRetriever()

# Build from your training data
retriever.build_knowledge_base(
    spanish_file='/content/drive/MyDrive/MT_data/all-filtered.es.fuzzy.smalltrain',
    english_file='/content/drive/MyDrive/MT_data/all-filtered.en.fuzzy.smalltrain'
)

# Save for future use
retriever.save('translation_kb')

print("\n✓ Knowledge base ready!")
# Out:
# ======================================================================
# BUILDING KNOWLEDGE BASE
# ======================================================================
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loading sentences...
# ✓ Loaded 50000 sentence pairs
#
# First example:
# ES: E12 Sin embargo se identificó que los adolescentes perciben una imagen corporal distorsionada y sent...
# EN: E12 It was identified, however, that adolescents perceive a distorted body image and feelings of inf...
#
# ⏳ Generating embeddings (this takes ~5-10 minutes for 50k sentences)...
# Batches:   0%|          | 0/1563 [00:00<?, ?it/s]
# Building FAISS index...
# ✓ Knowledge base built with 50000 vectors
# ✓ Saved to translation_kb
#
# ✓ Knowledge base ready!

# %%
# =============================================================================
# STEP 4: TEST RETRIEVAL (Verify knowledge base works)
# =============================================================================
print("="*70)
print("TESTING RETRIEVAL")
print("="*70)

# Test query
test_query = "El gato está durmiendo en el sofá"

print(f"\nQuery: {test_query}\n")

# Test top 1 (for ICL)
print("--- Top 1 (ICL) ---")
top1 = retriever.retrieve(test_query, k=1)
for es, en, score in top1:
    print(f"Score: {score:.4f}")
    print(f"ES: {es}")
    print(f"EN: {en}\n")

# Test top 5 (for RAG)
print("--- Top 5 (RAG) ---")
top5 = retriever.retrieve(test_query, k=5)
for i, (es, en, score) in enumerate(top5, 1):
    print(f"{i}. Score: {score:.4f}")
    print(f"   ES: {es[:80]}...")
    print(f"   EN: {en[:80]}...\n")
# Out:
# ======================================================================
# TESTING RETRIEVAL
# ======================================================================
#
# Query: El gato está durmiendo en el sofá
#
# --- Top 1 (ICL) ---
# Score: 0.4841
# ES: LEUCOFELIGEN FeLV/RCP liofilizado y suspensión para suspensión inyectable para gatos
# EN: LEUCOFELIGEN FeLV/RCP lyophilisate and suspension for suspension for injection for cats
#
# --- Top 5 (RAG) ---
# 1. Score: 0.4841
#    ES: LEUCOFELIGEN FeLV/RCP liofilizado y suspensión para suspensión inyectable para g...
#    EN: LEUCOFELIGEN FeLV/RCP lyophilisate and suspension for suspension for injection f...
#
# 2. Score: 0.4516
#    ES: Peso del gato (kg)...
#    EN: Body Weight of Cat (kg)...
#
# 3. Score: 0.4516
#    ES: Peso del gato (kg)...
#    EN: Weight of cat [kg]...
#
# 4. Score: 0.4481
#    ES: En un modelo de inflamación en gatos, la inyección de robenacoxib tuvo efectos a...
#    EN: In an inflammation model in cats, robenacoxib injection had analgesic, anti-infl...
#
# 5. Score: 0.4213
#    ES: • en los gatos con anemia, el índice de mortalidad oscila alrededor del 60%, a l...
#    EN: • in anaemic cats, mortality rate of about 60% at 4, 6, 9 and 12 months was redu...

# %%
# =============================================================================
# STEP 5: LOAD LLAMA MODEL
# =============================================================================
print("="*70)
print("LOADING LLAMA 3.1 MODEL")
print("="*70)

max_seq_length = 2048
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

# Enable fast inference
FastLanguageModel.for_inference(model)

print("✓ Llama 3.1 model loaded and ready")
# Out:
# ======================================================================
# LOADING LLAMA 3.1 MODEL
# ======================================================================
# ==((====))==  Unsloth 2025.11.4: Fast Llama patching. Transformers: 4.57.2.
#    \\   /|    NVIDIA A100-SXM4-80GB. Num GPUs = 1. Max memory: 79.318 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# ✓ Llama 3.1 model loaded and ready

# %%
def build_rag_prompt(query: str, retriever: TranslationRetriever) -> str:
    """Build RAG prompt with top 5 examples"""
    examples = retriever.retrieve(query, k=5)

    prompt = """<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are a professional Spanish to English translator. Use the reference translations below to guide your translation.

IMPORTANT: Output ONLY the English translation. Do not include phrases like "Here is the translation:" or "The translation is:". Just provide the direct translation.<|eot_id|><|start_header_id|>user<|end_header_id|>

Reference translations:

"""

    for i, (es, en, score) in enumerate(examples, 1):
        prompt += f"{i}. Spanish: {es}\n   English: {en}\n\n"

    prompt += f"""Now translate (output ONLY the translation):
Spanish: {query}
English:<|eot_id|><|start_header_id|>assistant<|end_header_id|>

"""

    return prompt


def build_icl_prompt(query: str, retriever: TranslationRetriever) -> str:
    """Build ICL prompt with top 1 example"""
    examples = retriever.retrieve(query, k=1)
    es, en, score = examples[0]

    prompt = f"""<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are a professional Spanish to English translator.

IMPORTANT: Output ONLY the English translation. Do not add any preamble.<|eot_id|><|start_header_id|>user<|end_header_id|>

Translate the following Spanish text to English.

Example:
Spanish: {es}
English: {en}

Now translate (output ONLY the translation):
Spanish: {query}
English:<|eot_id|><|start_header_id|>assistant<|end_header_id|>

"""

    return prompt
print("✓ Prompt building functions defined")
# Out:
# ✓ Prompt building functions defined

# %%
# =============================================================================
# GPU BATCH PROCESSING (CLEAN VERSION, NO CLEANUP)
# =============================================================================

def translate_all_icl_batched(test_sources, retriever, model, tokenizer, batch_size=8, max_new_tokens=256):
    """
    Translate using GPU batching (much faster than sequential)
    """
    print(f"Translating {len(test_sources)} sentences with GPU batching (batch_size={batch_size})...")

    all_translations = []

    for i in range(0, len(test_sources), batch_size):
        batch_queries = test_sources[i:i+batch_size]

        # Build prompts for entire batch
        batch_prompts = [build_icl_prompt(q, retriever) for q in batch_queries]

        # Tokenize batch
        inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True).to("cuda")

        # Generate for entire batch at once
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                temperature=0.3,
                top_p=0.9,
                use_cache=True,
                pad_token_id=tokenizer.pad_token_id
            )

        # Decode batch
        batch_results = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # Extract translations
        for result in batch_results:
            translation = result.split("assistant")[-1].strip()
            all_translations.append(translation)

        print(f"Batch {i//batch_size + 1}/{(len(test_sources)-1)//batch_size + 1} done ✓")

    return all_translations


def translate_all_rag_batched(test_sources, retriever, model, tokenizer, batch_size=4, max_new_tokens=256):
    """
    Translate using GPU batching for RAG
    """
    print(f"Translating {len(test_sources)} sentences with GPU batching (batch_size={batch_size})...")

    all_translations = []

    for i in range(0, len(test_sources), batch_size):
        batch_queries = test_sources[i:i+batch_size]

        # Build prompts for entire batch
        batch_prompts = [build_rag_prompt(q, retriever) for q in batch_queries]

        # Tokenize batch
        inputs = tokenizer(batch_prompts, return_tensors="pt", padding=True, truncation=True).to("cuda")

        # Generate for entire batch at once
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                temperature=0.3,
                top_p=0.9,
                use_cache=True,
                pad_token_id=tokenizer.pad_token_id
            )

        # Decode batch
        batch_results = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        # Extract translations
        for result in batch_results:
            translation = result.split("assistant")[-1].strip()
            all_translations.append(translation)

        print(f"Batch {i//batch_size + 1}/{(len(test_sources)-1)//batch_size + 1} done ✓")

    return all_translations

# %%
# # =============================================================================
# # STEP 7: DEFINE TRANSLATION FUNCTIONS
# # =============================================================================

# def translate_icl(query: str, retriever: TranslationRetriever, max_new_tokens: int = 256):
#     """Translate using ICL (top 1 example)"""
#     prompt = build_icl_prompt(query, retriever)

#     inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

#     outputs = model.generate(
#         **inputs,
#         max_new_tokens=max_new_tokens,
#         temperature=0.3,
#         top_p=0.9,
#         use_cache=True
#     )

#     result = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     translation = result.split("assistant")[-1].strip()

#     return translation


# def translate_rag(query: str, retriever: TranslationRetriever, max_new_tokens: int = 256):
#     """Translate using RAG (top 5 examples)"""
#     prompt = build_rag_prompt(query, retriever)

#     inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

#     outputs = model.generate(
#         **inputs,
#         max_new_tokens=max_new_tokens,
#         temperature=0.3,
#         top_p=0.9,
#         use_cache=True
#     )

#     result = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     translation = result.split("assistant")[-1].strip()

#     return translation

# print("✓ Translation functions defined")
# Out:
# ✓ Translation functions defined

# %%
# =============================================================================
# STEP 1: IMPORTS (UPDATED)
# =============================================================================
# !pip install -q sacrebleu unbabel-comet nltk
# !python -m nltk.downloader wordnet omw-1.4

print("✓ Evaluation libraries installed")

import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from typing import List, Tuple
import pickle
from unsloth import FastLanguageModel
import torch
import sacrebleu
import nltk
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
import json
import pandas as pd

print("✓ Imports successful")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 3.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# <frozen runpy>:128: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ✓ Evaluation libraries installed
# ✓ Imports successful

# %%
# =============================================================================
# FIX: DOWNLOAD MISSING NLTK DATA
# =============================================================================
import nltk
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')

print("✓ NLTK data downloaded")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ✓ NLTK data downloaded
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# =============================================================================
# STEP 6: LOAD COMET MODEL
# =============================================================================
print("="*70)
print("LOADING COMET EVALUATION MODEL")
print("="*70)

# Updated import method for COMET
from comet import download_model, load_from_checkpoint

# Download and load COMET model
comet_model_path = download_model("Unbabel/wmt22-comet-da")
comet_model = load_from_checkpoint(comet_model_path)

print("✓ COMET model loaded")
# Out:
# ======================================================================
# LOADING COMET EVALUATION MODEL
# ======================================================================
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# LICENSE: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# hparams.yaml:   0%|          | 0.00/567 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# checkpoints/model.ckpt:   0%|          | 0.00/2.32G [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.6.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/2760a223ac957f30acfb18c8aa649b01cf1d75f2/checkpoints/model.ckpt`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# ✓ COMET model loaded
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/core/saving.py:197: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']

# %%
# =============================================================================
# STEP 7: DEFINE EVALUATION FUNCTIONS
# =============================================================================

def compute_bleu(predictions, references):
    """Compute BLEU score (0-100, higher is better)"""
    bleu = sacrebleu.corpus_bleu(predictions, [references])
    return bleu.score

def compute_chrf(predictions, references):
    """Compute chrF score (0-100, higher is better)"""
    chrf = sacrebleu.corpus_chrf(predictions, [references])
    return chrf.score

def compute_meteor(predictions, references):
    """Compute METEOR score (0-1, higher is better)"""
    scores = []
    for pred, ref in zip(predictions, references):
        pred_tokens = word_tokenize(pred.lower())
        ref_tokens = word_tokenize(ref.lower())
        score = meteor_score([ref_tokens], pred_tokens)
        scores.append(score)

    return sum(scores) / len(scores) if scores else 0.0

def compute_comet(predictions, references, sources):
    """Compute COMET score (0-1+, higher is better)"""
    data = []
    for src, pred, ref in zip(sources, predictions, references):
        data.append({
            "src": src,
            "mt": pred,
            "ref": ref
        })

    model_output = comet_model.predict(data, batch_size=8, gpus=1)

    return model_output.system_score

def evaluate_all_metrics(predictions, references, sources, approach_name=""):
    """Compute all metrics at once"""
    print(f"\n{'='*70}")
    print(f"COMPUTING METRICS: {approach_name}")
    print(f"{'='*70}")

    bleu = compute_bleu(predictions, references)
    chrf = compute_chrf(predictions, references)
    meteor = compute_meteor(predictions, references)
    comet = compute_comet(predictions, references, sources)

    print(f"\n RESULTS (n={len(predictions)} sentences):")
    print(f"{'='*70}")
    print(f"BLEU:   {bleu:.2f}  (higher is better, 0-100)")
    print(f"chrF:   {chrf:.2f}  (higher is better, 0-100)")
    print(f"METEOR: {meteor:.4f}  (higher is better, 0-1)")
    print(f"COMET:  {comet:.4f}  (higher is better, 0-1+)")
    print(f"{'='*70}\n")

    return {
        'bleu': bleu,
        'chrf': chrf,
        'meteor': meteor,
        'comet': comet
    }

print("✓ Evaluation functions defined")
# Out:
# ✓ Evaluation functions defined

# %%
# =============================================================================
# STEP 8: LOAD TEST DATA
# =============================================================================
# IMPORTANT: Replace these paths with your actual test files
# These should be DIFFERENT from your training files (all-filtered_*_fuzzy.smalltrain)

# Option 1: If you have test.fuzzy files, upload them and use:
# test_sources_file = '/mnt/user-data/uploads/test.fuzzy.es'
# test_references_file = '/mnt/user-data/uploads/test.fuzzy.en'

# Option 2: Use a small sample for quick testing
# test_sources = [
# "Período de validez después de abierto el envase: 10 horas.",
# "Niños y adolescentes No se recomienda el uso de Telmisartán Teva en niños y adolescentes hasta 18 años.",
# "Promover la mejora, de conformidad con las normas internacionales, de las condiciones de internamiento y el trato a las personas privadas de libertad.",
# "De los 1,165 pacientes tratados con Picato en ensayos clínicos sobre queratosis actínica llevados a cabo con ingenol mebutato gel, 656 pacientes (56%) tenían 65 años o más, mientras que 241 pacientes (21%) tenían 75 años o más.",
# "Ante la poca eficacia de este mecanismo en los trabajos de los Miembros y de la OMC, las ONG hoy defienden que tales materiales estén mejor organizados en la página electrónica e, incluso, que la Secretaría adopte una posición más activa, indicando algunos temas para la presentación del material en base a plazos y patrones más predefinidos.",
# "275 • Cuando el área de piel limpiada previamente se haya secado, pellízquela y sujétela firmemente con una mano.",
# "Una dosis comúnmente utilizada para inducir la superovulación consiste en la administración de 150- 225 UI (0,24-0,36 ml) de GONAL-f por día, comenzando el día 2 ó 3 del ciclo de tratamiento.",
# "150 UI/ kg 3x/ semana ó 450 UI/ kg una vez a la semana.",
# "Sin embargo, en la muestra, el SAPS II y el LODS mostraron buena capacidad discriminatoria para ocurrencia de muerte en la UTI AUC=0,85 y 0,83.",
# "El factor 'Aumento del costo de material lleva al uso de materiales de baja calidad lo que resulta prejudicial a los trabajadores' ocupó la segunda posición dentro del grupo implementación del proyecto con un IIR = 0.631 y se posicionó 43 dentro de todos los grupos de factores de cal¡dad.",
# "Se aplican por primera vez los métodos de la epidemiología moderna en nuestras publicaciones."
# ]

# test_references = [
# "Shelf life after first opening the container: 10 hours.",
# "Children and adolescents The use of Telmisartan Teva in children and adolescents up to the age of 18 years is not recommended.",
# "Support the improvement, in line with international standards, of the detention conditions and treatment of persons deprived of liberty.",
# "Of the 1,165 patients treated with Picato in the actinic keratosis clinical studies conducted with ingenol mebutate gel, 656 patients (56%) were 65 years and older, while 241 patients (21%) were 75 years and older.",
# "Aware of what little influence these position papers have on the WTO and its Members, NGOs are now calling for these papers to be better organized on the website and, moreover, for the Secretariat to take a more active stance, proposing topics on which to present papers, with more pre-defined timescales and standards.",
# "DO NOT touch this area again before giving the injection.  When the cleaned area of skin has dried, pinch and hold it firmly with one hand.",
# "A commonly used dose for superovulation involves the administration of 150-225 IU (0.24-0.36 ml) of GONAL-f daily, commencing on days 2 or 3 of the treatment cycle.",
# "140 150 IU/ kg 3x/ week or 450 IU/ kg once weekly.",
# "In He sample, however, SAPS II and LODS showed good discriminatory capacity for the occurrence of death at the ICU AUC=0.85 and 0.83.",
# "Increase of material price leads to use of low quality material thus harms workers factor was ranked in the second position among project implementation group with RII = 0.631 and was ranked in the 43rd position among all groups factors of qulity.",
# "Modern epidemiological methods were applied in our publications for the first time."
# ]

# If you have actual test files, uncomment and use this:
# =============================================================================
# LOAD FIRST 5K LINES FOR TEST SET ONLY
# =============================================================================

def load_first_n_lines(filepath, n=5000):
    """Load first n lines from a file"""
    sentences = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if i >= n:
                break
            line = line.strip()
            if line:  # Only add non-empty lines
                sentences.append(line)
    return sentences

# Load test data (first 5k lines)
test_sources = load_first_n_lines(
    '/content/drive/MyDrive/MT_data/all-filtered.es.real.test',
    n=5000
)

# Load corresponding English references (upload the English file first)
test_references = load_first_n_lines(
    '/content/drive/MyDrive/MT_data/all-filtered.en.real.test',  # Update path when uploaded
    n=5000
)

print(f"✓ Loaded {len(test_sources)} test sentences")
print(f"✓ Loaded {len(test_references)} reference translations")

# Verify they match
assert len(test_sources) == len(test_references), "Mismatch in test data!"

print(f"\nFirst test example:")
print(f"ES: {test_sources[0]}")
print(f"EN: {test_references[0]}")

print(f"✓ Loaded {len(test_sources)} test sentences with references")
# Out:
# ✓ Loaded 5000 test sentences
# ✓ Loaded 5000 reference translations
#
# First test example:
# ES: Período de validez después de abierto el envase: 10 horas.
# EN: Shelf life after first opening the container: 10 hours.
# ✓ Loaded 5000 test sentences with references

# %%
# # =============================================================================
# # STEP 9: RUN ICL TRANSLATION & EVALUATION
# # =============================================================================
# print("="*70)
# print("ICL TRANSLATION (Top 1 Example)")
# print("="*70)

# icl_predictions = []

# for i, spanish_sent in enumerate(test_sources):
#     print(f"Translating {i+1}/{len(test_sources)}...", end=' ')
#     translation = translate_icl(spanish_sent, retriever)
#     icl_predictions.append(translation)
#     print("✓")

#     # Show translations
#     if i in range (0, len(test_sources)):
#         print(f"\nExample:")
#         print(f"  Source:     {spanish_sent}")
#         print(f"  ICL Output: {translation}")
#         print(f"  Reference:  {test_references[i]}")

# # Evaluate ICL
# icl_scores = evaluate_all_metrics(icl_predictions, test_references, test_sources, "ICL (Top 1)")

# %%
# =============================================================================
# USAGE: ICL TRANSLATION WITH BATCHING
# =============================================================================
print("="*70)
print("ICL TRANSLATION (Top 1 Example) - GPU BATCHED")
print("="*70)

import time
start_time = time.time()

icl_predictions = translate_all_icl_batched(
    test_sources,
    retriever,
    model,
    tokenizer,
    batch_size=12
)

elapsed = time.time() - start_time
print(f"\n✓ Translated {len(icl_predictions)} sentences in {elapsed:.1f}s ({len(icl_predictions)/elapsed:.1f} sent/s)")

# Evaluate
icl_scores = evaluate_all_metrics(icl_predictions, test_references, test_sources, "ICL (Top 1)")
# Out:
# ======================================================================
# ICL TRANSLATION (Top 1 Example) - GPU BATCHED
# ======================================================================
# Translating 5000 sentences with GPU batching (batch_size=8)...
# Batch 1/625 done ✓
# Batch 2/625 done ✓
# Batch 3/625 done ✓
# Batch 4/625 done ✓
# Batch 5/625 done ✓
# Batch 6/625 done ✓
# Batch 7/625 done ✓
# Batch 8/625 done ✓
# Batch 9/625 done ✓
# Batch 10/625 done ✓
# Batch 11/625 done ✓
# Batch 12/625 done ✓
# Batch 13/625 done ✓
# Batch 14/625 done ✓
# Batch 15/625 done ✓
# Batch 16/625 done ✓
# Batch 17/625 done ✓
# Batch 18/625 done ✓
# Batch 19/625 done ✓
# Batch 20/625 done ✓
# Batch 21/625 done ✓
# Batch 22/625 done ✓
# Batch 23/625 done ✓
# Batch 24/625 done ✓
# Batch 25/625 done ✓
# Batch 26/625 done ✓
# Batch 27/625 done ✓
# Batch 28/625 done ✓
# Batch 29/625 done ✓
# Batch 30/625 done ✓
# Batch 31/625 done ✓
# Batch 32/625 done ✓
# Batch 33/625 done ✓
# Batch 34/625 done ✓
# Batch 35/625 done ✓
# Batch 36/625 done ✓
# Batch 37/625 done ✓
# Batch 38/625 done ✓
# Batch 39/625 done ✓
# Batch 40/625 done ✓
# Batch 41/625 done ✓
# Batch 42/625 done ✓
# Batch 43/625 done ✓
# Batch 44/625 done ✓
# Batch 45/625 done ✓
# Batch 46/625 done ✓
# Batch 47/625 done ✓
# Batch 48/625 done ✓
# Batch 49/625 done ✓
# Batch 50/625 done ✓
# Batch 51/625 done ✓
# Batch 52/625 done ✓
# Batch 53/625 done ✓
# Batch 54/625 done ✓
# Batch 55/625 done ✓
# Batch 56/625 done ✓
# Batch 57/625 done ✓
# Batch 58/625 done ✓
# Batch 59/625 done ✓
# Batch 60/625 done ✓
# Batch 61/625 done ✓
# Batch 62/625 done ✓
# Batch 63/625 done ✓
# Batch 64/625 done ✓
# Batch 65/625 done ✓
# Batch 66/625 done ✓
# Batch 67/625 done ✓
# Batch 68/625 done ✓
# Batch 69/625 done ✓
# Batch 70/625 done ✓
# Batch 71/625 done ✓
# Batch 72/625 done ✓
# Batch 73/625 done ✓
# Batch 74/625 done ✓
# Batch 75/625 done ✓
# Batch 76/625 done ✓
# Batch 77/625 done ✓
# Batch 78/625 done ✓
# Batch 79/625 done ✓
# Batch 80/625 done ✓
# Batch 81/625 done ✓
# Batch 82/625 done ✓
# Batch 83/625 done ✓
# Batch 84/625 done ✓
# Batch 85/625 done ✓
# Batch 86/625 done ✓
# Batch 87/625 done ✓
# Batch 88/625 done ✓
# Batch 89/625 done ✓
# Batch 90/625 done ✓
# Batch 91/625 done ✓
# Batch 92/625 done ✓
# Batch 93/625 done ✓
# Batch 94/625 done ✓
# Batch 95/625 done ✓
# Batch 96/625 done ✓
# Batch 97/625 done ✓
# Batch 98/625 done ✓
# Batch 99/625 done ✓
# Batch 100/625 done ✓
# Batch 101/625 done ✓
# Batch 102/625 done ✓
# Batch 103/625 done ✓
# Batch 104/625 done ✓
# Batch 105/625 done ✓
# Batch 106/625 done ✓
# Batch 107/625 done ✓
# Batch 108/625 done ✓
# Batch 109/625 done ✓
# Batch 110/625 done ✓
# Batch 111/625 done ✓
# Batch 112/625 done ✓
# Batch 113/625 done ✓
# Batch 114/625 done ✓
# Batch 115/625 done ✓
# Batch 116/625 done ✓
# Batch 117/625 done ✓
# Batch 118/625 done ✓
# Batch 119/625 done ✓
# Batch 120/625 done ✓
# Batch 121/625 done ✓
# Batch 122/625 done ✓
# Batch 123/625 done ✓
# Batch 124/625 done ✓
# Batch 125/625 done ✓
# Batch 126/625 done ✓
# Batch 127/625 done ✓
# Batch 128/625 done ✓
# Batch 129/625 done ✓
# Batch 130/625 done ✓
# Batch 131/625 done ✓
# Batch 132/625 done ✓
# Batch 133/625 done ✓
# Batch 134/625 done ✓
# Batch 135/625 done ✓
# Batch 136/625 done ✓
# Batch 137/625 done ✓
# Batch 138/625 done ✓
# Batch 139/625 done ✓
# Batch 140/625 done ✓
# Batch 141/625 done ✓
# Batch 142/625 done ✓
# Batch 143/625 done ✓
# Batch 144/625 done ✓
# Batch 145/625 done ✓
# Batch 146/625 done ✓
# Batch 147/625 done ✓
# Batch 148/625 done ✓
# Batch 149/625 done ✓
# Batch 150/625 done ✓
# Batch 151/625 done ✓
# Batch 152/625 done ✓
# Batch 153/625 done ✓
# Batch 154/625 done ✓
# Batch 155/625 done ✓
# Batch 156/625 done ✓
# Batch 157/625 done ✓
# Batch 158/625 done ✓
# Batch 159/625 done ✓
# Batch 160/625 done ✓
# Batch 161/625 done ✓
# Batch 162/625 done ✓
# Batch 163/625 done ✓
# Batch 164/625 done ✓
# Batch 165/625 done ✓
# Batch 166/625 done ✓
# Batch 167/625 done ✓
# Batch 168/625 done ✓
# Batch 169/625 done ✓
# Batch 170/625 done ✓
# Batch 171/625 done ✓
# Batch 172/625 done ✓
# Batch 173/625 done ✓
# Batch 174/625 done ✓
# Batch 175/625 done ✓
# Batch 176/625 done ✓
# Batch 177/625 done ✓
# Batch 178/625 done ✓
# Batch 179/625 done ✓
# Batch 180/625 done ✓
# Batch 181/625 done ✓
# Batch 182/625 done ✓
# Batch 183/625 done ✓
# Batch 184/625 done ✓
# Batch 185/625 done ✓
# Batch 186/625 done ✓
# Batch 187/625 done ✓
# Batch 188/625 done ✓
# Batch 189/625 done ✓
# Batch 190/625 done ✓
# Batch 191/625 done ✓
# Batch 192/625 done ✓
# Batch 193/625 done ✓
# Batch 194/625 done ✓
# Batch 195/625 done ✓
# Batch 196/625 done ✓
# Batch 197/625 done ✓
# Batch 198/625 done ✓
# Batch 199/625 done ✓
# Batch 200/625 done ✓
# Batch 201/625 done ✓
# Batch 202/625 done ✓
# Batch 203/625 done ✓
# Batch 204/625 done ✓
# Batch 205/625 done ✓
# Batch 206/625 done ✓
# Batch 207/625 done ✓
# Batch 208/625 done ✓
# Batch 209/625 done ✓
# Batch 210/625 done ✓
# Batch 211/625 done ✓
# Batch 212/625 done ✓
# Batch 213/625 done ✓
# Batch 214/625 done ✓
# Batch 215/625 done ✓
# Batch 216/625 done ✓
# Batch 217/625 done ✓
# Batch 218/625 done ✓
# Batch 219/625 done ✓
# Batch 220/625 done ✓
# Batch 221/625 done ✓
# Batch 222/625 done ✓
# Batch 223/625 done ✓
# Batch 224/625 done ✓
# Batch 225/625 done ✓
# Batch 226/625 done ✓
# Batch 227/625 done ✓
# Batch 228/625 done ✓
# Batch 229/625 done ✓
# Batch 230/625 done ✓
# Batch 231/625 done ✓
# Batch 232/625 done ✓
# Batch 233/625 done ✓
# Batch 234/625 done ✓
# Batch 235/625 done ✓
# Batch 236/625 done ✓
# Batch 237/625 done ✓
# Batch 238/625 done ✓
# Batch 239/625 done ✓
# Batch 240/625 done ✓
# Batch 241/625 done ✓
# Batch 242/625 done ✓
# Batch 243/625 done ✓
# Batch 244/625 done ✓
# Batch 245/625 done ✓
# Batch 246/625 done ✓
# Batch 247/625 done ✓
# Batch 248/625 done ✓
# Batch 249/625 done ✓
# Batch 250/625 done ✓
# Batch 251/625 done ✓
# Batch 252/625 done ✓
# Batch 253/625 done ✓
# Batch 254/625 done ✓
# Batch 255/625 done ✓
# Batch 256/625 done ✓
# Batch 257/625 done ✓
# Batch 258/625 done ✓
# Batch 259/625 done ✓
# Batch 260/625 done ✓
# Batch 261/625 done ✓
# Batch 262/625 done ✓
# Batch 263/625 done ✓
# Batch 264/625 done ✓
# Batch 265/625 done ✓
# Batch 266/625 done ✓
# Batch 267/625 done ✓
# Batch 268/625 done ✓
# Batch 269/625 done ✓
# Batch 270/625 done ✓
# Batch 271/625 done ✓
# Batch 272/625 done ✓
# Batch 273/625 done ✓
# Batch 274/625 done ✓
# Batch 275/625 done ✓
# Batch 276/625 done ✓
# Batch 277/625 done ✓
# Batch 278/625 done ✓
# Batch 279/625 done ✓
# Batch 280/625 done ✓
# Batch 281/625 done ✓
# Batch 282/625 done ✓
# Batch 283/625 done ✓
# Batch 284/625 done ✓
# Batch 285/625 done ✓
# Batch 286/625 done ✓
# Batch 287/625 done ✓
# Batch 288/625 done ✓
# Batch 289/625 done ✓
# Batch 290/625 done ✓
# Batch 291/625 done ✓
# Batch 292/625 done ✓
# Batch 293/625 done ✓
# Batch 294/625 done ✓
# Batch 295/625 done ✓
# Batch 296/625 done ✓
# Batch 297/625 done ✓
# Batch 298/625 done ✓
# Batch 299/625 done ✓
# Batch 300/625 done ✓
# Batch 301/625 done ✓
# Batch 302/625 done ✓
# Batch 303/625 done ✓
# Batch 304/625 done ✓
# Batch 305/625 done ✓
# Batch 306/625 done ✓
# Batch 307/625 done ✓
# Batch 308/625 done ✓
# Batch 309/625 done ✓
# Batch 310/625 done ✓
# Batch 311/625 done ✓
# Batch 312/625 done ✓
# Batch 313/625 done ✓
# Batch 314/625 done ✓
# Batch 315/625 done ✓
# Batch 316/625 done ✓
# Batch 317/625 done ✓
# Batch 318/625 done ✓
# Batch 319/625 done ✓
# Batch 320/625 done ✓
# Batch 321/625 done ✓
# Batch 322/625 done ✓
# Batch 323/625 done ✓
# Batch 324/625 done ✓
# Batch 325/625 done ✓
# Batch 326/625 done ✓
# Batch 327/625 done ✓
# Batch 328/625 done ✓
# Batch 329/625 done ✓
# Batch 330/625 done ✓
# Batch 331/625 done ✓
# Batch 332/625 done ✓
# Batch 333/625 done ✓
# Batch 334/625 done ✓
# Batch 335/625 done ✓
# Batch 336/625 done ✓
# Batch 337/625 done ✓
# Batch 338/625 done ✓
# Batch 339/625 done ✓
# Batch 340/625 done ✓
# Batch 341/625 done ✓
# Batch 342/625 done ✓
# Batch 343/625 done ✓
# Batch 344/625 done ✓
# Batch 345/625 done ✓
# Batch 346/625 done ✓
# Batch 347/625 done ✓
# Batch 348/625 done ✓
# Batch 349/625 done ✓
# Batch 350/625 done ✓
# Batch 351/625 done ✓
# Batch 352/625 done ✓
# Batch 353/625 done ✓
# Batch 354/625 done ✓
# Batch 355/625 done ✓
# Batch 356/625 done ✓
# Batch 357/625 done ✓
# Batch 358/625 done ✓
# Batch 359/625 done ✓
# Batch 360/625 done ✓
# Batch 361/625 done ✓
# Batch 362/625 done ✓
# Batch 363/625 done ✓
# Batch 364/625 done ✓
# Batch 365/625 done ✓
# Batch 366/625 done ✓
# Batch 367/625 done ✓
# Batch 368/625 done ✓
# Batch 369/625 done ✓
# Batch 370/625 done ✓
# Batch 371/625 done ✓
# Batch 372/625 done ✓
# Batch 373/625 done ✓
# Batch 374/625 done ✓
# Batch 375/625 done ✓
# Batch 376/625 done ✓
# Batch 377/625 done ✓
# Batch 378/625 done ✓
# Batch 379/625 done ✓
# Batch 380/625 done ✓
# Batch 381/625 done ✓
# Batch 382/625 done ✓
# Batch 383/625 done ✓
# Batch 384/625 done ✓
# Batch 385/625 done ✓
# Batch 386/625 done ✓
# Batch 387/625 done ✓
# Batch 388/625 done ✓
# Batch 389/625 done ✓
# Batch 390/625 done ✓
# Batch 391/625 done ✓
# Batch 392/625 done ✓
# Batch 393/625 done ✓
# Batch 394/625 done ✓
# Batch 395/625 done ✓
# Batch 396/625 done ✓
# Batch 397/625 done ✓
# Batch 398/625 done ✓
# Batch 399/625 done ✓
# Batch 400/625 done ✓
# Batch 401/625 done ✓
# Batch 402/625 done ✓
# Batch 403/625 done ✓
# Batch 404/625 done ✓
# Batch 405/625 done ✓
# Batch 406/625 done ✓
# Batch 407/625 done ✓
# Batch 408/625 done ✓
# Batch 409/625 done ✓
# Batch 410/625 done ✓
# Batch 411/625 done ✓
# Batch 412/625 done ✓
# Batch 413/625 done ✓
# Batch 414/625 done ✓
# Batch 415/625 done ✓
# Batch 416/625 done ✓
# Batch 417/625 done ✓
# Batch 418/625 done ✓
# Batch 419/625 done ✓
# Batch 420/625 done ✓
# Batch 421/625 done ✓
# Batch 422/625 done ✓
# Batch 423/625 done ✓
# Batch 424/625 done ✓
# Batch 425/625 done ✓
# Batch 426/625 done ✓
# Batch 427/625 done ✓
# Batch 428/625 done ✓
# Batch 429/625 done ✓
# Batch 430/625 done ✓
# Batch 431/625 done ✓
# Batch 432/625 done ✓
# Batch 433/625 done ✓
# Batch 434/625 done ✓
# Batch 435/625 done ✓
# Batch 436/625 done ✓
# Batch 437/625 done ✓
# Batch 438/625 done ✓
# Batch 439/625 done ✓
# Batch 440/625 done ✓
# Batch 441/625 done ✓
# Batch 442/625 done ✓
# Batch 443/625 done ✓
# Batch 444/625 done ✓
# Batch 445/625 done ✓
# Batch 446/625 done ✓
# Batch 447/625 done ✓
# Batch 448/625 done ✓
# Batch 449/625 done ✓
# Batch 450/625 done ✓
# Batch 451/625 done ✓
# Batch 452/625 done ✓
# Batch 453/625 done ✓
# Batch 454/625 done ✓
# Batch 455/625 done ✓
# Batch 456/625 done ✓
# Batch 457/625 done ✓
# Batch 458/625 done ✓
# Batch 459/625 done ✓
# Batch 460/625 done ✓
# Batch 461/625 done ✓
# Batch 462/625 done ✓
# Batch 463/625 done ✓
# Batch 464/625 done ✓
# Batch 465/625 done ✓
# Batch 466/625 done ✓
# Batch 467/625 done ✓
# Batch 468/625 done ✓
# Batch 469/625 done ✓
# Batch 470/625 done ✓
# Batch 471/625 done ✓
# Batch 472/625 done ✓
# Batch 473/625 done ✓
# Batch 474/625 done ✓
# Batch 475/625 done ✓
# Batch 476/625 done ✓
# Batch 477/625 done ✓
# Batch 478/625 done ✓
# Batch 479/625 done ✓
# Batch 480/625 done ✓
# Batch 481/625 done ✓
# Batch 482/625 done ✓
# Batch 483/625 done ✓
# Batch 484/625 done ✓
# Batch 485/625 done ✓
# Batch 486/625 done ✓
# Batch 487/625 done ✓
# Batch 488/625 done ✓
# Batch 489/625 done ✓
# Batch 490/625 done ✓
# Batch 491/625 done ✓
# Batch 492/625 done ✓
# Batch 493/625 done ✓
# Batch 494/625 done ✓
# Batch 495/625 done ✓
# Batch 496/625 done ✓
# Batch 497/625 done ✓
# Batch 498/625 done ✓
# Batch 499/625 done ✓
# Batch 500/625 done ✓
# Batch 501/625 done ✓
# Batch 502/625 done ✓
# Batch 503/625 done ✓
# Batch 504/625 done ✓
# Batch 505/625 done ✓
# Batch 506/625 done ✓
# Batch 507/625 done ✓
# Batch 508/625 done ✓
# Batch 509/625 done ✓
# Batch 510/625 done ✓
# Batch 511/625 done ✓
# Batch 512/625 done ✓
# Batch 513/625 done ✓
# Batch 514/625 done ✓
# Batch 515/625 done ✓
# Batch 516/625 done ✓
# Batch 517/625 done ✓
# Batch 518/625 done ✓
# Batch 519/625 done ✓
# Batch 520/625 done ✓
# Batch 521/625 done ✓
# Batch 522/625 done ✓
# Batch 523/625 done ✓
# Batch 524/625 done ✓
# Batch 525/625 done ✓
# Batch 526/625 done ✓
# Batch 527/625 done ✓
# Batch 528/625 done ✓
# Batch 529/625 done ✓
# Batch 530/625 done ✓
# Batch 531/625 done ✓
# Batch 532/625 done ✓
# Batch 533/625 done ✓
# Batch 534/625 done ✓
# Batch 535/625 done ✓
# Batch 536/625 done ✓
# Batch 537/625 done ✓
# Batch 538/625 done ✓
# Batch 539/625 done ✓
# Batch 540/625 done ✓
# Batch 541/625 done ✓
# Batch 542/625 done ✓
# Batch 543/625 done ✓
# Batch 544/625 done ✓
# Batch 545/625 done ✓
# Batch 546/625 done ✓
# Batch 547/625 done ✓
# Batch 548/625 done ✓
# Batch 549/625 done ✓
# Batch 550/625 done ✓
# Batch 551/625 done ✓
# Batch 552/625 done ✓
# Batch 553/625 done ✓
# Batch 554/625 done ✓
# Batch 555/625 done ✓
# Batch 556/625 done ✓
# Batch 557/625 done ✓
# Batch 558/625 done ✓
# Batch 559/625 done ✓
# Batch 560/625 done ✓
# Batch 561/625 done ✓
# Batch 562/625 done ✓
# Batch 563/625 done ✓
# Batch 564/625 done ✓
# Batch 565/625 done ✓
# Batch 566/625 done ✓
# Batch 567/625 done ✓
# Batch 568/625 done ✓
# Batch 569/625 done ✓
# Batch 570/625 done ✓
# Batch 571/625 done ✓
# Batch 572/625 done ✓
# Batch 573/625 done ✓
# Batch 574/625 done ✓
# Batch 575/625 done ✓
# Batch 576/625 done ✓
# Batch 577/625 done ✓
# Batch 578/625 done ✓
# Batch 579/625 done ✓
# Batch 580/625 done ✓
# Batch 581/625 done ✓
# Batch 582/625 done ✓
# Batch 583/625 done ✓
# Batch 584/625 done ✓
# Batch 585/625 done ✓
# Batch 586/625 done ✓
# Batch 587/625 done ✓
# Batch 588/625 done ✓
# Batch 589/625 done ✓
# Batch 590/625 done ✓
# Batch 591/625 done ✓
# Batch 592/625 done ✓
# Batch 593/625 done ✓
# Batch 594/625 done ✓
# Batch 595/625 done ✓
# Batch 596/625 done ✓
# Batch 597/625 done ✓
# Batch 598/625 done ✓
# Batch 599/625 done ✓
# Batch 600/625 done ✓
# Batch 601/625 done ✓
# Batch 602/625 done ✓
# Batch 603/625 done ✓
# Batch 604/625 done ✓
# Batch 605/625 done ✓
# Batch 606/625 done ✓
# Batch 607/625 done ✓
# Batch 608/625 done ✓
# Batch 609/625 done ✓
# Batch 610/625 done ✓
# Batch 611/625 done ✓
# Batch 612/625 done ✓
# Batch 613/625 done ✓
# Batch 614/625 done ✓
# Batch 615/625 done ✓
# Batch 616/625 done ✓
# Batch 617/625 done ✓
# Batch 618/625 done ✓
# Batch 619/625 done ✓
# Batch 620/625 done ✓
# Batch 621/625 done ✓
# Batch 622/625 done ✓
# Batch 623/625 done ✓
# Batch 624/625 done ✓
# Batch 625/625 done ✓
#
# ✓ Translated 5000 sentences in 2237.3s (2.2 sent/s)
#
# ======================================================================
# COMPUTING METRICS: ICL (Top 1)
# ======================================================================
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 625/625 [00:42<00:00, 14.87it/s]
#  RESULTS (n=5000 sentences):
# ======================================================================
# BLEU:   47.45  (higher is better, 0-100)
# chrF:   71.44  (higher is better, 0-100)
# METEOR: 0.7289  (higher is better, 0-1)
# COMET:  0.8724  (higher is better, 0-1+)
# ======================================================================

# %%
icl_predictions
# Out:
# ['Shelf life after first opening the vial: 10 hours.',
#  'Children and adolescents Telmisartan Teva is not recommended for use in children and adolescents until 18 years.',
#  'Promote, in accordance with international standards, the improvement of detention conditions and the treatment of persons deprived of liberty.',
#  'Out of 1,165 patients treated with Picato in clinical trials on actinic keratosis conducted with ingenol mebutate gel, 656 patients (56%) were aged 65 or over, while 241 patients (21%) were aged 75 or over.',
#  'In light of the limited effectiveness of this mechanism in the work of Members and the WTO, NGOs today argue that such materials should be better organized on the electronic page and, even, that the Secretariat adopt a more active position, indicating some topics for the presentation of the material based on more predefined deadlines and patterns.',
#  'When the previously cleaned skin area has dried, pinch it and hold it firmly with one hand.',
#  'A commonly used dose to induce ovulation consists of the administration of 150-225 IU (0.24-0.36 ml) of GONAL-f per day, starting on day 2 or 3 of the treatment cycle.',
#  '150 IU/ kg 3x/ week or 450 IU/ kg once a week',
#  'However, in the sample, the SAPS II and LODS showed good discriminatory capacity for mortality occurrence in ICU AUC=0.85 and 0.83.',
#  'The factor "Increase in material cost leads to the use of low-quality materials which is prejudicial to workers" was ranked in the second position among the project implementation group with RII = 0.631 and was ranked 43 among all quality factors groups.',
#  'Modern epidemiological methods are applied for the first time in our publications.',
#  'This process develops in the following stages: 1 initial, in which symptoms are perceived and interpreted, 2 assumption of the patient role after interpreting symptoms as disease, 3 search for assistance to resolve the problem, 4 assumption of the patient role accepting recommendations, and 5 recovery or acceptance of the disease in case of chronicity.',
#  'The coronavirus pandemic has severely affected consumer spending, industrial production, investment, trade, capital flows, and supply chains.',
#  'The CHMP considered that the impossibility of the HPS2-THRIVE study to achieve the main efficacy objectives raises serious reservations about the efficacy of laropiprant/nicotine acid.',
#  'To clarify that question, we used an additional regression model using stratification of iPTH levels.',
#  'The reconstituted and diluted medicinal product should be visually inspected before administration to check for the presence of particulate matter or discoloration.',
#  'Another observation that deserves emphasis is that many countries that adopt the logic of a universal health system do not guarantee the right to health, but, yes, the right to health services.',
#  'Likert-type questions with five response options, which varied from very satisfied to very dissatisfied in the Satisfaction subscale. In the Impact and concerns subscale it varied from never to always.',
#  'Drake, in 174 cases of complex aneurysms, reports good surgical results in 71.5% of the patients, poor results in 13% and fatal results in 15.5%.',
#  'For the analysis of the data related to the MBI, each dimension of emotional exhaustion, professional satisfaction, and depersonalization was added.',
#  'For a long time, people who are deaf were considered ill, with limitations and cognitive deficits, stigmatized and objects of prejudice.',
#  'In normal volunteers, differences were found between the sexes in the pharmacokinetic parameters of phenylbutyrate and phenylacetate (AUC and Cmax approximately 30-50% higher in women), but not of phenylacetylglutamine.',
#  'Another classification described is given by the triggering cause: benign, malignant or idiopathic.',
#  'Liprolog Mix50 100 U/ ml Pen suspension for injection 50% insulin lispro and 50% insulin lispro protamine suspension (rDNA origin)',
#  'A similar pattern of impulse control disorders has also been reported with rasagiline after marketing, which also included compulsions, obsessive thoughts, and impulsive behavior (see section 4.4).',
#  'Duavive demonstrated that it improved symptoms caused by oestrogen deficiency in postmenopausal women, when compared with placebo.',
#  'Core of the tablet: microcrystalline cellulose (E460) anhydrous calcium dihydrogen phosphate (E341) croscarmellose sodium (E468) magnesium stearate (E470b) stearate and sodium fumarate',
#  'In this study, no increased incidence of lymphoproliferative disorders or tumors was observed.',
#  'These buildings offer tourist services regardless of the reasons and include monasteries, convents, seminaries, religious schools, etc.',
#  'It is possible to go outside after nightfall.',
#  'The company also presented results from a series of studies with other vaccines containing different bluetongue virus serotypes, as well as published information to demonstrate how the vaccine will act in younger sheep.',
#  'According to this distinction, nurses are not simple passive transmitters of knowledge, connecting the academic world and public service networks with the community, but they have the autonomy to adapt communication according to contexts and situations.',
#  'The primary variable of the two studies was the 4-week continuous quit rate index (4W-CQR) from week 9 to week 12, confirmed by carbon monoxide (CO).',
#  'p-value < 0.0001.',
#  "Head and neck tumors cause deficiencies at various levels, potentially compromising the functional integrity of mastication, voice, speech, swallowing, and articulation, causing psychological and aesthetic damage, and leading to occupational disturbances in the patient's lifestyle.",
#  'Analysis of data.',
#  'With the intensification of globalization, the exchange of goods, services, people, and diseases between countries, interest in global health issues has increased in various health professions, and consequently, these contents are inserted in various undergraduate courses in the health area and other related areas.',
#  'To complete his academic formation, he declared himself a reader by "hobby".',
#  'This fact can be attributed to the increase in fatty acid oxidation potential in the muscle of trained animals and also to the permissive effect of GC on the lipolytic action of adrenaline and noradrenaline, whose plasma concentrations are elevated during physical exercise.',
#  'For data collection, a semi-structured questionnaire of own elaboration was used, which consisted of two parts: the first collected general and personal data of the family and the responsible for the medicine cabinet; the second part was formed by questions related to the study variables.',
#  'Cattle, sheep, pigs',
#  'There are some possible explanations for the differences between our results and what is reported in the literature.',
#  'The revised proposal was adopted with 671 votes in favor, 10 against and 15 abstentions.',
#  'Treatment and prevention of respiratory infections associated with Mycoplasma gallisepticum in chickens.',
#  'The session this year was held in a virtual format.',
#  'Erasmus+ Projects Results Platform',
#  'Flebogamma DIF 100 mg/ml should be administered intravenously at an initial rate of 0.01 ml/kg/min for the first thirty minutes.',
#  'Immediately before the booster injection, anti-PRP GMTs were 0.40 µg/ml and 0.64 µg/ml for HEXAVAC and the control group respectively.',
#  'When compared with REYATAZ 300 mg/ritonavir 100 mg once daily in the afternoon without efavirenz.',
#  'The benefits of such practices for the maintenance of the quality of life of people were the great motivator of this study.',
#  'Bondronat is indicated for:',
#  'Left ventricular ejection fraction LVEF was calculated from the final diastolic volume VDF and the final systolic volume VSF data.',
#  'In the scenario of Brazilian democracy, the CEPs are spaces for that debate.',
#  'It was considered: hemodynamic support use of infusion for vasoactive drugs, antiarrhythmics, antihypertensives, inotropics; mechanical support use of intraaortic balloon/BIA; and ventilatory support use of invasive mechanical ventilation.',
#  'When recommended loading doses are administered, either intravenously or orally, plasma concentrations approach steady-state levels within the first 24 hours of administration.',
#  'The observation and interviews revealed that families make festive gatherings or among friends a reason to share a few drinks.',
#  'Drinks for cats',
#  'On March 19, Trump falsely claimed that the drug chloroquine was approved by the FDA as a treatment for COVID-19.',
#  'QUADRAMET is only used in bone metastases capable of capturing a type of chemical substances called bisphosphonates, which means that the metastases will also capture the QUADRAMET drug.',
#  '• a pre-loaded Pelgraz syringe;',
#  'In another study conducted in France, which used linear regression analysis, the authors found a relationship between low knowledge and not having received training, and feeling poorly informed.',
#  'Physical education information',
#  'In more than 60 years of existence, Brazilian Archives of Cardiology has been the main vehicle for the dissemination of Brazilian scientific research in the field of cardiovascular diseases, representing the largest heritage of the Brazilian Society of Cardiology.',
#  'There are no safety data available after treatment with Ziagen in children under three months.',
#  'The Marketing Authorisation Holder (TAC) shall carry out the following programme of studies within the specified period, the results of which shall serve as the basis for the annual reassessment of the benefit/ risk profile.',
#  'Special effects animation services for film and video',
#  'The marketing authorisation was renewed on 16 October 2003 and 16 October 2008.',
#  "The efficacy of rotigotine in the treatment of the signs and symptoms of idiopathic Parkinson's disease was evaluated in an international pharmaceutical development program that consisted of four pivotal, parallel, randomized, double-blind, placebo-controlled studies and three studies on specific aspects of Parkinson's disease.",
#  'Most of the reactions were managed by a reduction in the infusion rate, temporary cessation of infusion or pre-treatment, usually with oral antihistamines, antipyretics and/ or corticosteroids.',
#  'The EDGE study included 7,111 patients with OA treated with a dose of etoricoxib 90 mg per day (1.5 times the recommended dose in OA) or diclofenac 150 mg per day for a mean duration of 9.1 months (maximum 16.6 months, median 11.4 months).',
#  'Also see ribavirin SPC if interferon alfa-2b is to be administered in combination with ribavirin in patients with chronic hepatitis C.',
#  'Pertussis toxoid, Filamentous haemagglutinin, Pertactin, Recombinant Hepatitis B surface antigen',
#  'In a validity study of the AUDIT in 302 university students in Mexico, 40.13% abstained from drinking, 88.29% were high-risk drinkers, and 10.34% met the criteria for dependence.',
#  'The lessons learned will be taken into account to detect any deficiency or problem or a potential improvement of the actions or their results and to contribute to maximizing their exploitation or impact.',
#  'Glycine',
#  'The literature points to a decrease in sleep quality in the first days after surgical intervention, with return to preoperative levels in varying intervals; however, there are no reports of improvement in sleep quality in the postoperative period, as was found in this study.',
#  'Thus, the paradox was that I received a couple of Skype calls from friends in the US and Saudi Arabia on the same Saturday, and many email messages, indicating the concern that this catastrophe generated all over the world, in circumstances that I only had phone contact with my brother, who lives just a few kilometers away in Santiago, three days later.',
#  '• An allergic reaction in the eye',
#  'Patients should be clinically evaluated after two years of treatment and the continuation of treatment should be decided by the prescribing physician on an individual basis.',
#  'The content development was based on scientific literature, to ensure it was credible.',
#  'No dose adjustment is required in these patients.',
#  'Type 2 diabetes is a disease in which the pancreas does not produce enough insulin to control the concentration of glucose in the blood, or in which the body is unable to use insulin effectively.',
#  'DATE OF REVISION OF THE TEXT [To be completed nationally]',
#  'How to promote this new way of thinking and managing the SUS?',
#  'The work done by these professionals is characterized by a low control of the activities performed, overwork, repetition of tasks, high competitiveness and low salaries.',
#  'In addition, the age of onset of the problems coincided with the residency phase and immediately after residency, which appears to be a period of greater vulnerability for this type of dependency in particular.',
#  "It is considered a'site' the grouping of one or several curves of similar geometric characteristics of the same condition, whether horizontal curve, vertical curve or the combination Fitzpatrick et al., 2000.",
#  'Vaccination with Nobivac Piro does not prevent infection.',
#  'In Brazil, following global trends, breast cancer takes first place in the statistics, followed by Cervical Cancer (CCU) which takes second place.',
#  'For the model related to horizontal movements, the response variable was the closest distance to the coast where the fish was found and the selected explanatory variables were the bathymetry of the area, the water temperature recorded by the acoustic transmitters, the time of day and gender.',
#  'Decreased renal excretion of calcium may be accompanied by a drop in serum phosphate levels, which does not require therapeutic measures.',
#  'Novartis Animal Health GmbH Tel: +43-(0)5338 2000',
#  'Residential stability, a concept opposite to residential mobility, facilitates the transmission of intergenerational values and the subsequent creation of social networks that provide new generations with opportunities to maintain or improve their social status.',
#  'In a Phase 3b international, single-arm, open clinical trial (ENHANCE), 2378 adult patients with severe sepsis were treated with drotrecogin alfa (activated).',
#  'The nitrogenous waste is in the form of ammonia, which is especially toxic to the brain and causes, in severe cases, a decrease in the level of consciousness and coma.',
#  'That recognition is related to the vulnerability of the professional, which will be, in some way, alleviated, if he is aware.',
#  'Diclofenac sodium Voltarol Ampoules 75mg/3ml, solution for injection',
#  'Therapeutic strategies to overcome this infection have been basically two.',
#  'In reality, the Limean history of the passages has been built under the imprint of a basic condition.',
#  'A tool was developed for the study containing the following variables: age, gender, presence of concomitant diseases diabetes mellitus, hypertension, history of peripheral vascular disease, severe coronary artery disease, and smoking >10 cigarettes/day.',
#  'The women were categorized as belonging to a low socio-economic canton or a high socio-economic canton solely based on their reported place of residence, and not on any other demographic characteristic.',
#  "The scientific committee's opinion is transmitted to the European Commission.",
#  'Finally, our patients had received antivenom at the accident site. However, the time elapsed between the accident and the administration of antivenom exceeded the ideal time for its beneficial effects.',
#  'Of the 93 deaths from all causes, 21 classified as "ill-defined conditions" were of unknown cause.',
#  '32/ 50 The simultaneous administration of ENGERIX B and a standard dose of IgHB does not result in lower antibody titres against anti-HBs, provided they are administered in different injection sites.',
#  'The Union has experience in the field of loans for financial assistance, particularly within the framework of the European Financial Stability Mechanism (EFSM) and the provision of balance of payments assistance.',
#  'Safety: Precautions question 6; Adverse effects question 7; Contraindications question 8; Interactions question 10;',
#  'Ski racks for vehicles',
#  'Coconut leaves [raw or partially processed]',
#  'The immunogenicity of HEXAVAC may be reduced by immunosuppressive treatment or immunodeficiency.',
#  'A significantly higher percentage of women treated with Livensa showed a benefit in all three variables, which was considered clinically significant, compared to women who received a placebo.',
#  'A bicompartmental model with parallel linear and non-linear clearance from the central compartment described the trastuzumab concentration-time profile.',
#  'The National Institute of Nursing Research (NINR) has been funding nursing research through training programs, as well as supporting individual researchers to investigate nursing phenomena, using existing funding mechanisms at the NIH.',
#  'In this sense, the valuation of society between parents and the healthcare team in the relief of postoperative pain in the child constitutes one of the important efforts for the occurrence of that practice.',
#  '3 mm in diameter and supplied in a single dose applicator (labeled as [sublingual tablet]).',
#  'These study results are expected to serve as guidance and support for nursing research in the healthcare systems and services across the entire region.',
#  'Focetria should not be administered at the same time as other vaccines (if another vaccine is required at the same time, the injection should be carried out in a different limb.',
#  'In all cases, it is a matter of variable band-type coral communities and/or reefs, located in bays or behind rocks that protect them from the waves, that do not exceed a depth of 12 m.',
#  'Only nine items had mean scores for the total sample that were 4.0 or less; while only other 12 items had mean scores less than 4.0 for one or more subsamples.',
#  'A questionnaire was designed with closed questions, where the following variables were collected: Age, gender, bile duct size on ultrasound, bile duct dilation on ERCP, common bile duct diameter on ERCP, post-ERCP diagnosis and failed ERCP.',
#  'The Spanish framework allows for the granting of aid in accordance with the modifications to the Temporary Framework, approved by the Commission on April 3, 2020.',
#  'Before inserting the cartridge into the reusable OptiClik pen, the cartridge must be stored at room temperature for 1 or 2 hours.',
#  'J.',
#  'Estonia BRISTOL-MYERS SQUIBB GYÓGYSZERKERESKEDELMI KFT.',
#  'In men, FSH is needed for the production of sperm.',
#  'Based on these parameters, the consumption ranges were re-grouped, thus throwing out the population that is below and above the consumption levels suggested by this organization.',
#  'The findings of that study allowed observing that the highest number of interventions/activities was related to the domains "Complex Physiological" and "Health System".',
#  'Cross-resistance is observed with other fluoroquinolones.',
#  'Single-dose vial containing 15 vials with powder and 15 pre-filled syringes with solvent.',
#  'However, its efficacy was lower in areas with high metronidazole resistance.',
#  'The average FEVD in the four groups was, respectively, 42.4 ± 4.7, 28.2 ± 2.7, 50.3 ± 5.1, and 22.0 ± 6.5%.',
#  'A standardized observer analyzed the radiographs using a radiograph viewer to evaluate the presence of supernumerary teeth, which was later confirmed through photographs.',
#  'Therefore, it can be concluded that closantel administered subcutaneously should not be used during drying.',
#  'Ciprofloxacin is present in the plasma to a great extent in a non-ionized form, and, in a steady state, has a wide volume of distribution, of 2 to 3 L/kg of body weight.',
#  '17, Boulevards De La Plaine B-1050 Bruxelles Belgium',
#  'Reconstitute with one of the three suitable reconstitution solutions as follows:',
#  '- Do not take antacids, multivitamins, or other products containing calcium (such as milk',
#  '(It is also better to avoid Amlodipino/Valsartán Mylan in early pregnancy, see Pregnancy section).',
#  'The correlation analysis of the numerical variables between the two stages of the study was carried out by the Pearson correlation test.',
#  'In the first moment of the operationalization of the data, the mapping of the exploratory phase of the research was concretized, developed in three phases:',
#  'Valproic Acid/Emtricitabine',
#  'Piroxicam resulted in a negligible increase of 0.49 mmHg in mean blood pressure.',
#  'The term "post-secular ethics" is coined by Jürgen Habermas, which is surprising in a thinker cataloged and criticized as excessively rationalist, although worn down by his consequent search for dialogue with religiosity, as illustrated by his respectful conversations with then Cardinal Ratzinger.',
#  'Initially, three categories of ethical problems affecting nurses were identified, namely moral suffering, moral uncertainty, and moral dilemmas.',
#  'The ARP is significantly higher in obese patients when compared to lean normotensive subjects, regardless of blood pressure levels, thus the activation of the renin-angiotensin-aldosterone system SRAA is involved in arterial hypertension HA and obesity.',
#  'Atripla should be avoided in patients infected with HIV-1 harbouring the K65R, M184V/I or K103N mutation (see sections 4.1 and 5.1).',
#  'The Member States, with the support of the Commission and the European Medicines Agency, must continue to carry out the following tasks:',
#  'It is necessary to think about the disastrous consequences for the international order of the hypothesis that each of the nearly two hundred states invokes for itself the right to carry out "preventive attacks", based on unilateralism.',
#  'An axial and coronary image composite was performed in all cases.',
#  "The patients' responses were compared with the data contained in the file.",
#  'In the absence of compatibility studies, this medicinal product must not be mixed with other medicinal products except with human NPH insulin.',
#  'Early gastric cancer (CGT) is a tumor confined to the mucosa or submucosa, regardless of the presence or absence of lymph node metastasis 15, whose prognosis is excellent if it can be detected and treated in time, achieving a survival rate of over 90% at 5 years, which contrasts notably with that of advanced gastric cancer 15, 16.',
#  'Erythema multiforme1), Stevens-Johnson syndrome1), angioedema1), cutaneous vasculitis1) lichenoid reaction in the skin1)',
#  'In acute toxicity studies, single intravenous and oral doses of iloprost produced severe symptoms of intoxication or death (IV) at doses approximately two orders of magnitude above the intravenous therapeutic dose.',
#  'Administering dose A.',
#  'Intrathecal opioids are known to increase the analgesia of subtherapeutic doses of local anesthetics.',
#  'The population was constituted by the nursing students of 1st Grade enrolled in Faculties and Schools of the University District of Seville during the academic course 2010-2011 N=510.',
#  'Adverse reactions attributed to MIRCERA treatment in controlled clinical trials in patients with chronic kidney disease.',
#  'It is primarily bacteriostatic and it is believed that its antimicrobial effect is due to the inhibition of protein synthesis.',
#  'The most commonly used vasoconstrictors in combination with local anaesthetics belong to the group of sympathomimetics that includes adrenaline, noradrenaline, levonordefrin, phenylephrine and methoxamine.',
#  'After reconstitution, the liquid should be colourless and essentially particle-free; the parathyroid hormone (ADH) should not be used if the reconstituted solution is cloudy, coloured or contains visible particles.',
#  'Round, biconvex white tablet with the inscription "OL 5" on one face.',
#  'Administration of higher doses than recommended (see section 4.2) for a longer period (several months) may cause suppression of the hypothalamic-pituitary-adrenal axis.',
#  'On rectal examination, a hypotonic sphincter with a limited anal margin and non-tender circular papillae was observed.',
#  'Communication of data by electronic means',
#  'There are no data or the data on the use of filgrastim in pregnant women are limited.',
#  '• Patients receiving injectable calcitonin who have questions should consult their doctor or pharmacist.',
#  'Piglets treated with Metacam presented a significant decrease in blood cortisol levels (indicating they were exposed to lower levels of stress) 30 minutes after castration compared to the control group.',
#  'Storage of Insulin Human Winthrop Rapid Contents of the container and additional information',
#  'The company was asked to provide more data to justify the use of that comparison drug and specifically, to see how the furoate of mometasone was released in the body of the comparison drug and the already approved medicine.',
#  "In a 2005 study conducted by SCS Engineers at the RESA in Chihuahua, Mexico, it was found that they used the SCS Model, which is a modified version of the EPA's model.",
#  'If you are taking diltiazem, verapamil,',
#  'Insulin Human Winthrop Infusat 100 IU/ml solution for injection in a vial Insulin human',
#  'From the geometry of Figure 3a, the length of the sliding plane is LBD = h/2 cos?, the inclination angle iBD is equal to?/2 -? +?, and as shown in Figure 3b the increase in speed is',
#  'The gravitational field effect between celestial bodies of great mass also shows analogy with the electromagnetic forces that guarantee the organized arrangement of electrons in their orbits around the atomic nucleus.',
#  'The target of adalimumab is a protein called tumor necrosis factor (TNFα), whose levels increase in the inflammatory diseases listed above.',
#  'Because of this, mothers are advised to stop breastfeeding before taking Zerit.',
#  'No prolongation of the QT interval was observed for nintedanib in the clinical trial program (see Section 5.1).',
#  'With regard to alternative transportation (7), the circumstances of the COVID-19 outbreak may affect the right to choose an alternative mode of transport as quickly as possible (8).',
#  'Furthermore, the medication should be administered under the close supervision of a healthcare professional with experience and in an environment that has immediate access to a full resuscitation team.',
#  "The aftermaths left by LM significantly impair people's ability to perform some activities in their daily life, mainly those that require a lot from musculoskeletal functions such as: transferring, walking and climbing stairs.",
#  'Mother, E5, P.12',
#  'The "great time" is, above all, this possibility of the "strange coincidences", as if destiny were leading one to it with some inextricable purpose.',
#  'At the end of the surgeries, the patients were monitored in the recovery room for 60 minutes after they woke up and were then transferred to the admission units.',
#  'Certain health problems, that you may have or have had, require special precautions before or during treatment with Invirase/ritonavir.',
#  'The participating subject will express their consent in writing or, failing that, orally in the presence of an independent witness from the research team who will record it in writing under their responsibility.',
#  'There are assisted feeding alternatives that should be taken into account before suggesting artificial feeding to these patients 5, 14.',
#  'If you have any problem, please ask for help or advice from your doctor or nurse.',
#  'The examples of multiple substitutions were insufficient to determine a consistent substitution pattern or its effect on viral susceptibility to enfuvirtide.',
#  'The Web server allows access to the configuration and diagnostic data of the concentrator circuit through an Internet browser.',
#  'Mouth dry',
#  'Sandimmun concentrated for infusion solution contains ricinoleate of macrogolglycerol/ricinoleic acid polyethoxylate which may cause redisolution of polyvinyl chloride phthalate.',
#  'Symptoms may recur after treatment is discontinued.',
#  'The objective of this study is to present the results of ICPs in Brazil, with a focus on the access route used, in the 2005-2008 four-year period, according to the data from the National Cardiovascular Intervention Centre CENIC.',
#  'Administration of glucagon can help regain consciousness more quickly if you give yourself an injection of glucagon.',
#  'That foreign word is being semantically modified.',
#  "Incidentally, the community doesn't need a new indicator, but rather to carry out the work of the documentary historians of the past century, and a good start would be to handle the bibliographies, and then who knows, propose new indicators.",
#  'The pharmacokinetics of eltrombopag have been studied after the administration of eltrombopag to adults with renal impairment.',
#  'Even when they recognize differences, areas of dispute and conflicts, they seek strategies for overcoming and continuous learning in the work environment, in order to improve interpersonal relationships, as illustrated in the following comments:',
#  'It is worth noting that the prevalence of non-adherence in individuals with hemoglobin A1c greater than 7% was 85.7%.',
#  'Calcitonin Sandoz 100 IU/ml solution for injection and infusion for intravenous use, intramuscular use, subcutaneous use',
#  'For this very reason, it was also possible to suppose that divine wisdom had disposed each of the natural forms on earth in such a way that distances would not neutralize their intentions.',
#  'The following haematological parameters should be determined before the start of treatment and after each dose of VEPESID and associated brand names: platelet count, haemoglobin, white cell count and differential.',
#  'The mother presented a normoevolutive pregnancy and regular prenatal controls that showed at 28 weeks of intrauterine life an increase in the fetal cranial contour and abnormalities in the development of the upper and lower limbs.',
#  'It seems the inspiratory part is very long, almost 3 times compared to the expiratory part E, not being the I:E ratio most suitable for an asthmatic crisis, nor is the respiratory frequency and the volumes are a bit low.',
#  'The total number of cases increased to 15,679 and the number of deaths reached 277.',
#  'Being so, she does not limit herself to the issue of the sexual act, it goes much further and is configured as a symbolically constructed reality.',
#  'Thus, it is not to the figure of other professionals that nurses approach in that analogy, and yes to the function of those professionals.',
#  "It's very good.",
#  'The EG study in patients with IRC on dialytic treatment and conservative treatment, did not show statistically significant differences in the gastric retention curve and the EG T½, when compared to a group of healthy patients.',
#  'Some studies have been showing that patients with LES have a risk of 2 to 50 times higher of acquiring coronary artery disease, which represents an important cause of premature mortality in that disease.',
#  'HOW TO USE VELCADE',
#  'Multiple logistic regression analysis was conducted with consideration of variables that presented p<0.20 in the bivariate analysis.',
#  'These terms share the root that they share: the discipline, from the Latin discere, which means to learn, from which derive discente and disciple.',
#  'Stormwater collection system installation',
#  '12',
#  'What you need to know before starting to use LUMIGAN 0.3 mg/ml',
#  'The anticoagulant efficacy of Clopidogrel BMS was compared with that of aspirin in a study called CAPRIE which included some 19,000 patients with atherothrombosis.',
#  'Remote control vehicle models',
#  'If it is used well and widely applied, eSalud can be a strategic tool that allows for improved access, expanded coverage, and increased financial efficiency of health care systems.',
#  'Total dose = patient weight multiplied by the recommended dose (1.8 mg/kg)',
#  'A shared approach between patient and healthcare professional could avoid the knowledge gaps of diabetic patients.',
#  'The AHRLJ is published twice a year, in March and in October.',
#  'For diagnostic use only.',
#  'Distribution No significant binding to plasma proteins, except to circulating insulin antibodies (if present).',
#  'The fetus is a vital organ during gestation and plays a leading role; as Dr. Alejandro Bautista expresses, "it is a dynamic force in the orchestration of its own destiny".',
#  'Back pain Arthralgia Muscle spasms Myalgia',
#  'In a model of visceral pain, colorectal nociceptive response was attenuated by intrathecal administration of NMDA receptor antagonist in ovariectomized rats, compared to those ovariectomized with estradiol replacement.',
#  'Myelosuppression Tasigna treatment has been associated with thrombocytopenia, neutropenia and anemia (Grade 3-4 according to the "Common Toxicity Criteria" of the National Cancer Institute).',
#  'The nursing diagnosis was the only unrecorded stage on the charts.',
#  'Take the soluble tablets once a day, with a meal to increase absorption, and at the same time each day, preferably in the morning.',
#  'The factor "The current negative culture that dominates the domestic community decreases quality" ranked second in the promotion group of safety and health with an IIR = 0.701 and ranked 27 among all quality factor groups.',
#  'The carcinogenic potential of cladribine was evaluated in a 22-month long-term study with subcutaneous administration in mice and a 26-week short-term study by oral administration in transgenic mice.',
#  'Although the DC increased in both groups between the 3rd and 18th weeks, the rise was lower in the GEA than in the CG only in the 18th week.',
#  'To be taken into consideration by patients on a controlled sodium diet.',
#  'In the attempt to explain and justify the answers, the following constructions were gathered: “they are homonyms”; “one is tied to the other”; “they go together”; “the two things walk together”, and “nothing happens by chance, everything has a meaning”.',
#  'In all studies, the primary criterion of effectiveness was the recovery time of the muscles.',
#  'In case of pump malfunction, patients should always have injection devices (injection syringe or pen) and insulin available for subcutaneous injection.',
#  'Ziconotide is a peptide formed by 25 natural L-amino acids and does not appear to undergo significant metabolism in the LCR.',
#  'Table 1 Recommended dosing schedule for Farydak in combination with bortezomib and dexamethasone (cycles 1-8)',
#  'The recommended dose for the second week of treatment is the total dose administered during the first week.',
#  'In comparison to fasting administration, dosing of tenofovir disoproxil and emtricitabine with a high-fat or light meal increased the mean AUC of tenofovir by 43.6% and 40.5%, and the Cmax by 16% and 13.5%, respectively, without affecting emtricitabine exposures.',
#  'The processes are the set of tangible and intangible inputs that are related to each other, and operate and transform to produce the expected outcome or output.',
#  '1 ml (one vial) contains 400 micrograms of methoxy polyethylene glycol-epoetin beta*.',
#  'This article deals with the use of this algorithm to solve the Duhamel Integral, and focuses on the effect produced by varying the population size on the ability to find an appropriate answer.',
#  'These data are suitable as a bridge between the documented efficacy of the reference product (Drontal Plus) and the product of interest (Milaxyn Plus, Strantel Plus, Prazical Plus, Voxical Plus, Exitel Plus, Cazitel Plus and Prazitel Plus and associated trade names).',
#  'The overall safety profile of these subjects was not different from that of the general population.',
#  'Since it is not possible to predict the end of the current crisis, it may quickly lead to a paralysis of activities and businesses in a very sector sensitive to cyclical variations.',
#  'Subsequently, patients underwent a mandatory reduction schedule with a complete discontinuation of corticosteroids by week 19.',
#  'There are significant differences in communication skills and job performance among healthcare workers who received training in the AIEPI intervention group and those who did not receive the intervention group.',
#  'Tadalafil is more than 10,000 times more potent for PDE5 than for PDE7, PDE8, PDE9, and PDE10.',
#  'It is also important that there be a sufficient number of properly trained researchers to prepare and conduct a valid and ethically correct study.',
#  '• Type I diabetes that may include feeling hungrier or thirstier than normal, having to urinate more frequently, weight loss and feeling tired',
#  'Researchers found an excess of collagen intermingled with myocardial cells that made up to 20% of the material examined.',
#  'In this study, the participants who made medication errors reported that the occurrence "did not cause harm" to the patient, probably because the mistakes made did not cause injury, or in other words, were errors that apparently did not become adverse events.',
#  'The following aspects must be recorded at each visit: age, weight, height and psychomotor development assessment performance.',
#  'Given the significant socio-economic consequences of the COVID-19 outbreak and the need for liquidity in the economy, it should be possible to support the temporary suspension of fishing activities caused by the COVID-19 outbreak with a maximum co-financing percentage of 75% of the eligible public expenditure.',
#  'In the case of perinatal mortality, the direct determinants are the biological factors: low birth weight and prematurity.',
#  'Zinc chloride Glycerol Metacresol Phenol Disodium phosphate dihydrate Sodium hydroxide (for pH adjustment) Hydrochloric acid (for pH adjustment) Protamine sulphate Water for injections',
#  'The potential risk to humans is unknown.',
#  'The cause of allergic reactions with BeneFIX has not yet been determined.',
#  'A bivariate analysis found that men who self-reported hypertension had a prevalence ratio of 1.44 to have overweight and obesity, and for women that ratio was 1.72.',
#  'Those results, both of PPV and NPV, are in line with those found in the literature in adults.',
#  'Throughout 2019, the evolution of the labor market remained positive, but disparities persisted between regions, rural and urban areas and socio-economic groups.',
#  'Patients with hepatic insufficiency: The effect of hepatic insufficiency on pharmacokinetics in the steady state of saquinavir/ritonavir (1000 mg/100 mg twice a day for 14 days) was studied in 7 HIV-infected patients with moderate hepatic insufficiency (Child Pugh grade B, 7 to 9 points).',
#  'If you take more Bonviva than you should, you may suffer a decrease in blood levels of calcium, phosphorus, or magnesium.',
#  'The interaction between the technical skills and knowledge of the systems engineer and administrative knowledge can generate software products that support teaching and training processes in SISP.',
#  'For many years science was part of philosophy, in such a way that scientists were called Natural Philosophers.',
#  'Financial services facilitated by phone and through a global computer network or Internet',
#  '9/ 19 PARTICULARS TO APPEAR ON THE OUTER PACKAGE',
#  'Patients in whom more than one attempt at laryngoscopy and intubation was made, or whose laryngoscopy and intubation operation took more than 20 seconds, were also excluded from the study.',
#  'Olanzapine Teva should be taken with food and drinks. Olanzapine Teva should not be taken with alcohol as the combination of Olanzapine Teva and alcohol may cause drowsiness.',
#  'The correct identification of risk factors from the available information, site visits, and obtaining additional data, allows the formulation of measures in favor of the reduction of accidents.',
#  'Additionally, it represents an important medical-legal risk for the healthcare professional and the work team in this area; figures from the United Kingdom show that around 70% of medical-legal payments are derived from obstetric care.',
#  'The word iatrogenesis is derived from Greek and is composed of iatros, meaning "doctor", and genesis, "origin".',
#  'The Association of Anesthesiologists of Ireland and England generated a 25-page document specifically to deal with the problem of fatigue in its members and made recommendations on issues of equipment and patient safety.',
#  'This study aims to identify the NPS of the UTIN and the interior of an incubator of a university hospital affiliated with a public university in São Paulo - SP - Brazil.',
#  'Dogs committed or weakened:',
#  'Many conclusions have been drawn and many types of filters have been proposed in order to minimize its effect, for example, a differential mode filter has been proposed by S. J. Kim and S. K. Sul in 1997 and a common mode filter has been proposed by S. Ogasawara and H. Akagi in 2001.',
#  'The seroprotection rate, the seroconversion rate and seroconversion factor for anti-HA antibodies 21 days after the first dose were as follows 11 anti-HA antibodies',
#  'Pharmacokinetic parameters of Spectrila were determined in 7 adult patients after intravenous infusion of 5000 U/m².',
#  'In the unfortunate case of no means being available, at least the wound must be covered from the air and microbic agents with a piece of cloth or any handkerchief, as long as it is well cleaned.',
#  '• Hold the vial upright and tap lightly before removing the top to prevent spillage.',
#  'Another limitation refers to the fact that, in the studied sample, the psychosocial variables determining medication adherence that could enable the better delineation of the intervention - motivational and/or volitional.',
#  'Limited experience with Hemlibra overdose.',
#  'Talc, hypromellose, macrogol, titanium dioxide (E171)',
#  'Natriuretic peptides PNB and NT-proPNB have utility in the diagnosis of decompensated HF in emergencies, confirming or ruling out the diagnosis in patients with breathlessness, and giving a prognostic value to that population, especially in hospital discharge, to prevent future events.',
#  'The ENDES Baseline 2008 involved women between 15 and 49 years old.',
#  'With the end of the Mexican Empire, from mid-1867 onwards, several men of science, involved in imperial scientific activities, had to reorient their political activities under the republican government of Benito Juárez and disentangle themselves from the imperial past in order to pursue the scientific and professional goals they were seeking.',
#  'In vitro tests with human microsomes show that concomitant treatment with substances metabolized by CYP450 isoforms may produce higher or lower plasma concentrations of masitinib or those substances.',
#  'Calendar publication',
#  'Solvent for injectable suspension.',
#  'All sequences of the cagA, FR and WSR regions of the reference strain: H. pylori NCTC 11637 were compared with the sequences already reported in the databases, therefore it was used as a positive control of the sequencing.',
#  'More information about Ceplene',
#  'Very common side effects (may affect at least 1 in 10 patients)',
#  'As can be seen, of the 50 samples analyzed for meat, 48% of the establishments presented a good appearance and all were kept in refrigeration chambers; the opposite for the sausage, where around 54% of the establishments appeared in a regular to bad condition.',
#  '• Treatment of hyperlipoproteinemia, • Primary prevention of cardiovascular morbidity.',
#  'Neither EVA nor morphological side effects were evaluated.',
#  'It is worth noting that the concept of vulnerability gained strength and visibility in the Brazilian health area with the advent of AIDS, due to the association of the disease transmission mode with the concept of risk.',
#  'The calculation of the required dose of factor IX is based on the empirical finding that 1 International Unit (IU) of factor IX per kg body weight increases plasma factor IX activity by 0.7 IU/dl (range of 0.31 to 1.0 IU/dl) or 0.7% of normal activity in patients under 12 years of age (for additional information, see section 5.2).',
#  'Licorice sticks for pharmaceutical use',
#  'In addition, the company marketing Procysbi will provide educational materials to all physicians who may prescribe the drug, with important safety information including the risk that the drug may be harmful to the fetus.',
#  'Furnaces for metal decontamination',
#  'It is important to avoid the introduction of the IB D388 vaccine virus into holdings where the wild strain is not present.',
#  'In terms of intensity, 42.1% reported strong pain, 25.9% moderate, 19.4% mild, and 12.6% considered feeling the worst possible pain.',
#  'A deformation of the global balance and/or collective order implies that some people relax while others overexert themselves.',
#  'Different doses of fentolamine administered via the subarachnoid route produce various effects on pain sensitivity, possibly by the involvement of different subtypes of alpha-adrenergic receptors in the pain modulatory pathways.',
#  'The initial dose is 15 mg as a single daily dose in monotherapy or 10 mg per day in combination therapy (see section 5.1).',
#  'This was an observational, analytical and prospective study.',
#  'CYP3A inhibitors',
#  'In light of the need to know the perception that the person with DM has regarding AS, as well as their relationship with metabolic control and adherence to both pharmacological and non-pharmacological treatments, this study was developed.',
#  'Additional measures are needed to prospectively minimize the reappearance of this contamination.',
#  'Consideration should be given to reducing the dose of pramipexole when these medications are administered concurrently with Oprymea.',
#  'This activity breaks the life cycle of the mite.',
#  '- if you are allergic (hypersensitive) to sitagliptin or any of the other ingredients of',
#  'It se resalta que el conocimiento sobre el nombre, dosis y frecuencia de administración de los medicamentos es de suma importancia para que el paciente esté apto a evitar errores en la utilización de los mismos.\nIt is destacated that knowledge about the name, dosage and administration frequency of medications is of utmost importance for the patient to be able to avoid errors in the use of the same.',
#  'Breast Cancer Resistance Protein (BCRP)',
#  'This is also the case of the credits related to the Flexibility Instrument.',
#  'Poverty and lack of access to health services allow the existence of such diseases.',
#  'Do not inject into a blood vessel.',
#  'Exposure to bosentan decreased over time in accordance with the known enzymatic auto-inductive properties of bosentan.',
#  'The breath samples, collected in breath sample bags, are analyzed by non-dispersive infrared spectroscopy (NDIR).',
#  'Adrenaline (tartrate) Jext',
#  'The concentration of social housing in sparsely equipped populations gives Los Morros a different character to that of Gran Avenida.',
#  'If you have taken more Zonegran than you should, tell a carer (relative or friend), your doctor or pharmacist immediately, or contact your nearest hospital casualty department, taking your medicine with you.',
#  'The fatigue models developed for different materials and service conditions produce different results, which generates the need to perform model calibration for local use conditions.',
#  'Do not use in pregnant or breeding animals (see section 4.7).',
#  'Pharmacokinetics of atazanavir.',
#  'Thus, for Herz, the totality of these relationships is the spatialization of the field Herz, 2008.',
#  'A second group is concerned with the audiovisual, with a special emphasis on Hollywood films and a phenomenon that has gained strength in recent years: the boom of Colombian telenovelas in Spain.',
#  'Planning to be a parent',
# ...
#  'Aluminum hydroxide, Mineral oil (Marcol 52), Sorbitan monooleate (Arlacel A), Polysorbate 80 (Tween 80), Thimerosal',
#  'In general, there is no difference in class hours, teaching strategies and evaluation of AIEPI teaching between public and private institutions, but the number of qualified teachers is lower in private schools, which can imply precariousness in the quality of teaching.',
#  'Savings account services',
#  'The European Commission granted a marketing authorisation valid throughout the European Union to the pharmaceutical company Helsinn Birex Pharmaceuticals Ltd. on 22 March 2005.',
#  'Patients treated with adalimumab showed a significantly greater improvement at week 12, which was maintained through week 24 as measured by both the SF36 and the Ankylosing Spondylitis Quality of Life Questionnaire (ASQoL).',
#  'In the BCSC, a novel design was developed whereby there are 2 induction rooms connected to each operating room in order to offer a highly efficient flow of auxiliary personnel.',
#  'Other medicines and Silapo',
#  'These include a careful selection of blood and plasma donors to ensure that those at risk of being carriers of infections are excluded, and the monitoring of individual donations and plasma banks for signs of virus/infections.',
#  'Variables with a non-normal distribution were subjected to log transformation.',
#  'What you need to know before you use ADYNOVI',
#  '- The other ingredients are: sodium hydroxide, glacial acetic acid, sorbitol, polisorbate 80.',
#  'You can discuss this with your doctor.',
#  "From an operational point of view, the characteristics of these trades result in high salaries and high security costs, and negatively affect the worker's motivation.",
#  'Liver damage (hepatocellular, cholestatic, and mixed) and autoimmune hepatitis cases have been observed.',
#  'Aranesp 500 micrograms solution for injection in pre-filled syringe Each pre-filled syringe contains 3.79 mg of sodium in 1 mL.',
#  'Ibalizumab is active against group M HIV-1 (subtypes A, B, C, D, E or O) strains.',
#  'There was a great variability between neighborhoods in the distribution of the mortality rate due to IHD 0 to 9,247.77/100,000.',
#  'There is no information on safety or efficacy in children or adolescents regarding the use of Rebetol with peginterferon or other forms of interferon (that is, not alfa-2b).',
#  'Plasma levels of some HIV-1 protease inhibitors metabolized mainly by CYP3A4 may increase when administered with low doses of ritonavir, which is an inhibitor of this metabolic pathway.',
#  'Based on a normal approximation of the difference in response rate (NC = Fa) Plasma HIV-RNA',
#  'There is a trend in academic research to name mutilation as a mark that can be seen with the eyes, an act performed on the body that aims to eliminate the disease and is necessary for the healing of the person.',
#  'If only Insulatard is injected.',
#  'In this registry, we applied an early invasive strategy aiming to identify high-risk patients, such as those with severe multiarterial CAD 23.0% and left main coronary artery stenosis 2.0%.',
#  'Following subcutaneous administration of a daily dose, steady state plasma levels are achieved after 3 to 4 days with a 1.3-fold increase in Cmax and AUC.',
#  'As for all parenteral medicinal products, inspect the reconstituted solution visually.',
#  'Write the new expiration date in the box including day/month/year (no more than 30 days after the medication is removed from the refrigerator).',
#  'There is no evidence of in vitro or in vivo mitochondrial toxicity.',
#  'Summary of RA flares in RA patients receiving tocilizumab monotherapy or in combination with MTX or other DMARDs',
#  'The artículo está dividido en tres secciones.\n\nbecomes:\n\nThe article is divided into three sections.',
#  'Cardiovascular risk factor prevalence and distribution',
#  'The oral bioavailability of itraconazole is maximum when the capsules are taken immediately after a full meal.',
#  'This is a prospective, observational study; a cardiac arrest registry was designed, distributed, and doctors at the participating hospital were asked to fill it out who participated in cardiopulmonary resuscitation maneuvers during the described period.',
#  'In this study 5 mcg.kg.min were used, without initial bolus dose.',
#  'Patients with moderate to severe renal impairment, the dose of Trobalt should be adjusted, dose adjustment of Trobalt is not necessary in patients with mild renal impairment (see section 4.2).',
#  'As a maintenance dose, clopidogrel should be administered as a single daily dose of 75 mg with or without food.',
#  'The data shown in Figure 2 display seven latent variables with a total of 43 observed variables.',
#  'The treatment groups were defined as follows:',
#  "There is no teenager with diabetes who doesn't like eating chocolate, but they can't.",
#  '26 Belgium/Belgique/Belgien Eli Lilly Benelux S. A/ N. V.',
#  'Caution should be exercised in patients with low white blood cell and/or neutrophil counts for any reason; in patients on medications known to cause neutropenia; in patients with a history of drug-induced myelosuppression; in patients with myelosuppression caused by concomitant diseases, radiation therapy, or chemotherapy; and in patients with disorders associated with hyper eosinophilia or myeloproliferative disease.',
#  'The hospital is a public institution, of great size, which has agreements with 27 municipalities of the Triángulo Sur macro region, with a total of 281 operational beds, which serve an estimated population of 645,000 individuals.',
#  'Hand tools',
#  'Electric dish dryers for domestic use',
#  'see also sections 4.4 and 4.7.',
#  'Diarrhoea caused by Vibrio cholerae',
#  '• trouble breathing or chest discomfort',
#  'The average duration of the test was longer in the non-obese group p < 0.05 than in the obese group.',
#  'Throughout life, the dentition goes through three stages of development: deciduous or milk teeth from 6 months to 6 years, mixed from 6 to 12 years, and permanent from 12 years onwards.',
#  'The main final result was the incidence of agranulocytosis, which occurred at a frequency of 1.2%.',
#  'A minimum of 100 subjects is recommended in cultural adaptation studies.',
#  'Resistance to emtricitabine or tenofovir has been observed in vitro and in some HIV-1-infected patients, due to the development of a M184V or M184I substitution in the RT with emtricitabine or a K65R substitution in the RT with tenofovir.',
#  'Construct validity estimation: convergent construct validity and known groups or contrast validity were established.',
#  'Other medicines and Rebetol',
#  'The syringe is now ready for use.',
#  "In this context, the nurse's primary role is highlighted, whether in direct care to the elderly patient or in training their caregiver and/or family members.",
#  'Although a higher risk of hemorrhage in the mucous membranes (the tissues that line body cavities such as the nose, intestine, and vagina) was observed, the Committee considered that such a risk could be controlled with appropriate measures.',
#  'The etiology of ventricular dysfunction was not a criterion for inclusion.',
#  'In these cases of combined administration, the same monitoring recommendations should be applied.',
#  'The complex needs to capture interrelations, different and contradictory realities, through a thought that respects diversity, seeking to unite rather than simplify.',
#  'Metformin: metformin should be used with caution: there is a risk of lactic acidosis, induced by possible renal function failure, associated with hydrochlorothiazide.',
#  'Recently the Imbanaco Clinic group in Cali, led by Dr. Iván Unigarro, has also initiated the exciting experience of Spyglass colangioscopy with two successful diagnostic cases.',
#  's filled out an "informed consent" form that allowed the observation of pharmacy activities and were informed about an evaluation study of the distribution system, however they were not aware of the objectives and methodology of the study, these aspects being blind to pharmacy staff with the objective of avoiding known biases.',
#  'Other studies showed that the administration of lidocaine before intubation was able to suppress the sympathetic activity related to laryngoscopy and intubation.',
#  'It is essential to highlight that the judicious study of personality requires the expertise of a professional in this field.',
#  'Each tablet contains 1 mg of rasagiline (as mesylate).',
#  'In addition, there is a need for an adequate offer of services that allow the prevention of those infections through educational activities that reduce the risk of acquiring them, in especially vulnerable groups such as adolescents or the LGBT community, or at the moment of contact of the patients with the health services such as prenatal control or family planning consultation.',
#  'The radionuclide ventriculography study showed a moderate to severe reduction in the function of the right and left ventricles, respectively.',
#  'Meanwhile, these differences were statistically significant only in the domains Mental Health and Pain.',
#  'Results: The results were favorable, facial and dental harmony and periodontal function, as well as aesthetics and patient satisfaction were achieved.',
#  'Since liver damage and tumors have been observed in rats treated with Mycamine for prolonged periods, patients should be monitored for liver problems during treatment with Mycamine through blood tests.',
#  "With the introduction of these services in the student's practice, he came to live with visible physical and psychological wear, due to the lack of familiarity with the work process, which was aggravated by the lack of control and decision-making power.",
#  'This is especially likely in patients with impaired renal function.',
#  'In the case of a patient who refers additional symptoms following CE ingestion, intervention will be endoscopic or surgical.',
#  'Hyperglycemia and diabetes Rare cases of hyperglycemia and/or development or exacerbation of diabetes occasionally associated with ketoacidosis or coma, with some fatal outcome (see section 4.8).',
#  'Unknown frequency alopecia, erythema, night sweats rash',
#  'Considering the information obtained by SIMOSTE, a prevalence of physiological loads 36.8%, biological loads 27.2%, mechanical loads 25.9%, and psychological loads 18.9% was observed, at the same time, the notable underreporting of chemical and physical loads.',
#  '29 15.',
#  'Aspartate aminotransferase; alanine aminotransferase increase',
#  'Simple binary logistic regression analysis revealed an association between low scores on the Glasgow scale and the occurrence of UP p<0.001.',
#  'Before starting the data collection process, the project was submitted for review and obtained approval from the Research Ethics Committee of the School of Nursing at the University of São Paulo.',
#  'In this high-demand context, delays in the release of medical reports can occur, in the same way that failures in the production process in the imaging sector cause harm to the patient.',
#  'The alternatives vary from 0 to 5 points none of the time to all the time.',
#  'For a temporary travel restriction to have the desired effect in terms of reducing the spread of the virus, it is necessary to limit exemptions to essential movements.',
#  'When the results of the first four studies are combined, 320 (26%) of the 1,213 patients who received a weekly dose of 1.0 mg/ kg of Raptiva responded to treatment, compared with 25 (4%) of the 715 who received placebo.',
#  'Take all safety precautions.',
#  'A good start would be to recognize that equality should be taught and learned within the framework of the integration of individuals to their social community of reference.',
#  'Preparations for repairing floors',
#  'In this sense, one of the most relevant studies has been the National Survey of Victimization and Public Safety ENVIPE, in which it is observed that the most frequent crimes, from the perspective of the victims, are street alcohol consumption, drug consumption and sale, theft, and assault.',
#  'If you are unsure, talk to your doctor or pharmacist before taking Vascace.',
#  'Direct determination of LDL-ox in plasma, or serum, is complicated by the possibility of in vivo modifications of the samples and the variety of particles, at different levels of oxidation, that can be identified and whose significance, in terms of predictive disease, is also potentially variable.',
#  'No teratogenic effects were observed in rabbits at > 1,000 times human exposure.',
#  'After injecting the liquid, remove the needle and release the skin.',
#  'Head trauma and cerebral aneurysms remain relatively common situations in neuroanesthesia.',
#  'In the study comparing Jalra with metformin, significantly better results were observed with metformin: a reduction of HbA1c levels of 1.5 percentage points after 52 weeks, compared to a reduction of approximately 1 percentage point in patients treated with Jalra.',
#  'It is observed that this flying ash, rich in silica SiO2 is composed of 3 crystalline phases silimanite, silica and sodium aluminate.',
#  "That's why it's important to evaluate this Colombian population with a high incidence of CG, and to contrast the hypothesis that cases and controls show significant differences in the frequencies of the genetic polymorphisms GSTM1, GSTP1 and GSTT1, and at the same time, to test if there are differences between smoking habits, alcohol consumption and socioeconomic level, as well as their possible interactions.",
#  'How to capture the displacements "promoted by technology in modes of subjectivation: learning, concentration, time/space and effort/pleasure"?',
#  'Then, this percentage was obtained separately for patients allergic to mold and to carbon dust, to assess which is the most important.',
#  'If you forget to take a dose, take it as soon as you remember.',
#  'What can be stated is that nurses believe they have autonomy, control over the environment, get along with doctors and have organizational support for governance in nursing practice.',
#  'The suffering is present in this group of men, which makes them more vulnerable, even more so when there is an internal break caused by the disease, aware that it is not curable, but it can be controlled, and that there also comes a time when the disease knocks them down, preventing them from carrying out everything they used to do in their daily life.',
#  'The reason was that the competent national authority in Germany considered that this veterinary medicinal product could represent a potential serious risk to animal health because its efficacy had not been sufficiently demonstrated in the dossier.',
#  'Once absorbed, it binds primarily to plasma proteins, mainly albumin, metabolized in the liver and its excretion pathway is basically renal.',
#  'Based on clinical studies, the recommended dose for patients over 65 years old is 20 mg per day (20 mg once a day), as previously described.',
#  'Very common side effects that may appear in a blood test • abnormal changes in your bone marrow cells',
#  'Elderly patients: no dose adjustment of Irbesartan Hydrochlorothiazide BMS is necessary in elderly patients.',
#  'Dynamic that invites, in addition, to put into perspective the social and cultural mechanisms of reception of the state in the local world, through the conceptual re-adaptation of historiographical interpretations on the formation of the national state in the Ecuadorian decimononic.',
#  'The effect of these factors on consumption is also presented.',
#  'The tooth could be contaminated because it is exposed to a large amount of bacteria in the oral cavity, although the dental pulp is surrounded by hard dental tissues enamel, dentin and cement in the oral cavity.',
#  'Infections caused by Candida in this range of CMI will likely respond to treatment.',
#  ...]

# %%
# =============================================================================
# USAGE: RAG TRANSLATION WITH BATCHING
# =============================================================================
print("="*70)
print("RAG TRANSLATION (Top 5 Examples) - GPU BATCHED")
print("="*70)

start_time = time.time()

rag_predictions = translate_all_rag_batched(
    test_sources,
    retriever,
    model,
    tokenizer,
    batch_size=25
)

elapsed = time.time() - start_time
print(f"\n✓ Translated {len(rag_predictions)} sentences in {elapsed:.1f}s ({len(rag_predictions)/elapsed:.1f} sent/s)")

# Evaluate
rag_scores = evaluate_all_metrics(rag_predictions, test_references, test_sources, "RAG (Top 5)")
# Out:
# ======================================================================
# RAG TRANSLATION (Top 5 Examples) - GPU BATCHED
# ======================================================================
# Translating 5000 sentences with GPU batching (batch_size=25)...
# Batch 1/200 done ✓
# Batch 2/200 done ✓
# Batch 3/200 done ✓
# Batch 4/200 done ✓
# Batch 5/200 done ✓
# Batch 6/200 done ✓
# Batch 7/200 done ✓
# Batch 8/200 done ✓
# Batch 9/200 done ✓
# Batch 10/200 done ✓
# Batch 11/200 done ✓
# Batch 12/200 done ✓
# Batch 13/200 done ✓
# Batch 14/200 done ✓
# Batch 15/200 done ✓
# Batch 16/200 done ✓
# Batch 17/200 done ✓
# Batch 18/200 done ✓
# Batch 19/200 done ✓
# Batch 20/200 done ✓
# Batch 21/200 done ✓
# Batch 22/200 done ✓
# Batch 23/200 done ✓
# Batch 24/200 done ✓
# Batch 25/200 done ✓
# Batch 26/200 done ✓
# Batch 27/200 done ✓
# Batch 28/200 done ✓
# Batch 29/200 done ✓
# Batch 30/200 done ✓
# Batch 31/200 done ✓
# Batch 32/200 done ✓
# Batch 33/200 done ✓
# Batch 34/200 done ✓
# Batch 35/200 done ✓
# Batch 36/200 done ✓
# Batch 37/200 done ✓
# Batch 38/200 done ✓
# Batch 39/200 done ✓
# Batch 40/200 done ✓
# Batch 41/200 done ✓
# Batch 42/200 done ✓
# Batch 43/200 done ✓
# Batch 44/200 done ✓
# Batch 45/200 done ✓
# Batch 46/200 done ✓
# Batch 47/200 done ✓
# Batch 48/200 done ✓
# Batch 49/200 done ✓
# Batch 50/200 done ✓
# Batch 51/200 done ✓
# Batch 52/200 done ✓
# Batch 53/200 done ✓
# Batch 54/200 done ✓
# Batch 55/200 done ✓
# Batch 56/200 done ✓
# Batch 57/200 done ✓
# Batch 58/200 done ✓
# Batch 59/200 done ✓
# Batch 60/200 done ✓
# Batch 61/200 done ✓
# Batch 62/200 done ✓
# Batch 63/200 done ✓
# Batch 64/200 done ✓
# Batch 65/200 done ✓
# Batch 66/200 done ✓
# Batch 67/200 done ✓
# Batch 68/200 done ✓
# Batch 69/200 done ✓
# Batch 70/200 done ✓
# Batch 71/200 done ✓
# Batch 72/200 done ✓
# Batch 73/200 done ✓
# Batch 74/200 done ✓
# Batch 75/200 done ✓
# Batch 76/200 done ✓
# Batch 77/200 done ✓
# Batch 78/200 done ✓
# Batch 79/200 done ✓
# Batch 80/200 done ✓
# Batch 81/200 done ✓
# Batch 82/200 done ✓
# Batch 83/200 done ✓
# Batch 84/200 done ✓
# Batch 85/200 done ✓
# Batch 86/200 done ✓
# Batch 87/200 done ✓
# Batch 88/200 done ✓
# Batch 89/200 done ✓
# Batch 90/200 done ✓
# Batch 91/200 done ✓
# Batch 92/200 done ✓
# Batch 93/200 done ✓
# Batch 94/200 done ✓
# Batch 95/200 done ✓
# Batch 96/200 done ✓
# Batch 97/200 done ✓
# Batch 98/200 done ✓
# Batch 99/200 done ✓
# Batch 100/200 done ✓
# Batch 101/200 done ✓
# Batch 102/200 done ✓
# Batch 103/200 done ✓
# Batch 104/200 done ✓
# Batch 105/200 done ✓
# Batch 106/200 done ✓
# Batch 107/200 done ✓
# Batch 108/200 done ✓
# Batch 109/200 done ✓
# Batch 110/200 done ✓
# Batch 111/200 done ✓
# Batch 112/200 done ✓
# Batch 113/200 done ✓
# Batch 114/200 done ✓
# Batch 115/200 done ✓
# Batch 116/200 done ✓
# Batch 117/200 done ✓
# Batch 118/200 done ✓
# Batch 119/200 done ✓
# Batch 120/200 done ✓
# Batch 121/200 done ✓
# Batch 122/200 done ✓
# Batch 123/200 done ✓
# Batch 124/200 done ✓
# Batch 125/200 done ✓
# Batch 126/200 done ✓
# Batch 127/200 done ✓
# Batch 128/200 done ✓
# Batch 129/200 done ✓
# Batch 130/200 done ✓
# Batch 131/200 done ✓
# Batch 132/200 done ✓
# Batch 133/200 done ✓
# Batch 134/200 done ✓
# Batch 135/200 done ✓
# Batch 136/200 done ✓
# Batch 137/200 done ✓
# Batch 138/200 done ✓
# Batch 139/200 done ✓
# Batch 140/200 done ✓
# Batch 141/200 done ✓
# Batch 142/200 done ✓
# Batch 143/200 done ✓
# Batch 144/200 done ✓
# Batch 145/200 done ✓
# Batch 146/200 done ✓
# Batch 147/200 done ✓
# Batch 148/200 done ✓
# Batch 149/200 done ✓
# Batch 150/200 done ✓
# Batch 151/200 done ✓
# Batch 152/200 done ✓
# Batch 153/200 done ✓
# Batch 154/200 done ✓
# Batch 155/200 done ✓
# Batch 156/200 done ✓
# Batch 157/200 done ✓
# Batch 158/200 done ✓
# Batch 159/200 done ✓
# Batch 160/200 done ✓
# Batch 161/200 done ✓
# Batch 162/200 done ✓
# Batch 163/200 done ✓
# Batch 164/200 done ✓
# Batch 165/200 done ✓
# Batch 166/200 done ✓
# Batch 167/200 done ✓
# Batch 168/200 done ✓
# Batch 169/200 done ✓
# Batch 170/200 done ✓
# Batch 171/200 done ✓
# Batch 172/200 done ✓
# Batch 173/200 done ✓
# Batch 174/200 done ✓
# Batch 175/200 done ✓
# Batch 176/200 done ✓
# Batch 177/200 done ✓
# Batch 178/200 done ✓
# Batch 179/200 done ✓
# Batch 180/200 done ✓
# Batch 181/200 done ✓
# Batch 182/200 done ✓
# Batch 183/200 done ✓
# Batch 184/200 done ✓
# Batch 185/200 done ✓
# Batch 186/200 done ✓
# Batch 187/200 done ✓
# Batch 188/200 done ✓
# Batch 189/200 done ✓
# Batch 190/200 done ✓
# Batch 191/200 done ✓
# Batch 192/200 done ✓
# Batch 193/200 done ✓
# Batch 194/200 done ✓
# Batch 195/200 done ✓
# Batch 196/200 done ✓
# Batch 197/200 done ✓
# Batch 198/200 done ✓
# Batch 199/200 done ✓
# Batch 200/200 done ✓
#
# ✓ Translated 5000 sentences in 1381.2s (3.6 sent/s)
#
# ======================================================================
# COMPUTING METRICS: RAG (Top 5)
# ======================================================================
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 625/625 [00:42<00:00, 14.87it/s]
#  RESULTS (n=5000 sentences):
# ======================================================================
# BLEU:   48.18  (higher is better, 0-100)
# chrF:   72.04  (higher is better, 0-100)
# METEOR: 0.7358  (higher is better, 0-1)
# COMET:  0.8749  (higher is better, 0-1+)
# ======================================================================

# %%
rag_predictions
# Out:
# ['Shelf life after first opening the vial: 10 hours.',
#  'Children and adolescents The use of Telmisartan Teva is not recommended in children and adolescents up to 18 years.',
#  '·Promote, in accordance with international standards, the improvement of conditions of detention and treatment of persons deprived of liberty.',
#  'Out of 1,165 patients treated with Picato in clinical trials on actinic keratosis conducted with ingenol mebutate gel, 656 patients (56%) were aged 65 or over, while 241 patients (21%) were aged 75 or over.',
#  'In light of the limited effectiveness of this mechanism in the work of Members and the WTO, NGOs today argue that such materials should be better organized on the website and, even, that the Secretariat should take a more active position, indicating some topics for the presentation of the material based on more defined deadlines and patterns.',
#  '275 • When the previously cleaned skin area has dried, pinch it and hold it firmly with one hand.',
#  'A commonly used dose to induce ovulation consists of the administration of 150-225 IU (0.24-0.36 ml) of GONAL-f per day, starting on day 2 or 3 of the treatment cycle.',
#  '20 150 IU/ kg 3x/ week or 450 IU/ kg once weekly',
#  'However, in the sample, the SAPS II and LODS showed good discriminatory capacity for occurrence of death in the ICU AUC=0.85 and 0.83.',
#  'The factor "Increase in material cost leads to the use of low-quality materials which is detrimental to workers" was ranked in the second position among the project implementation group with a RII = 0.631 and was ranked 43 among all quality factors groups.',
#  'This is the first time that modern epidemiological methods are applied in our publications.',
#  'The process develops through the following stages: 1 initial, in which symptoms are perceived and interpreted, 2 assumption of the role of patient after interpreting symptoms as disease, 3 search for assistance to resolve the problem, 4 assumption of the role of patient accepting recommendations, and 5 recovery or acceptance of the disease in case of chronicity.',
#  'The coronavirus pandemic has severely impacted consumer spending, industrial production, investment, trade, capital flows, and supply chains.',
#  'The CHMP considered that the inability of the HPS2-THRIVE study to achieve the main efficacy objectives raises serious reservations about the efficacy of laropiprant/nicotine acid.',
#  'In order to clarify that question better, we used an additional regression model using stratification of the levels of iPTH.',
#  'Parenteral medicinal products should be visually inspected for particulate matter and discoloration prior to administration.',
#  'Another notable observation is that many countries that adopt the logic of a universal health system do not guarantee the right to health, but, yes, the right to health services.',
#  'It is composed of Likert-type questions with five answer options, which varied from very satisfied to very dissatisfied in the Satisfaction sub-scale. In the Impact and concerns sub-scale it varied from never to always.',
#  'Drake, in 174 cases of complex aneurysms, reports good surgical outcomes in 71.5% of patients, poor outcomes in 13% and fatal outcomes in 15.5%.',
#  'For the analysis of the data related to the MBI, each of the dimensions of emotional exhaustion, professional satisfaction, and depersonalization was added.',
#  'For a long time, deaf people were considered ill, with limitations and cognitive deficits, stigmatized and objects of prejudice.',
#  'In normal volunteers, differences were found between both sexes in the pharmacokinetic parameters of phenylbutyrate and phenylacetate (AUC and Cmax approximately 30-50% higher in women), but not of phenylacetylglutamine.',
#  'Another classification described is given by the triggering cause: benign, malignant or idiopathic.',
#  'Liprolog Mix50 100 U/ ml Pen suspension for injection 50% insulin lispro and 50% insulin lispro protamine suspension (rDNA origin)',
#  'There have also been reported a similar pattern of impulse control disorders with rasagilina after marketing, which also included compulsions, obsessive thoughts and impulsive behaviour (see section 4.4).',
#  'Duavive demonstrated that it improved symptoms caused by oestrogen deficiency in postmenopausal women, when compared with placebo.',
#  'Core of the tablet: microcrystalline cellulose (E460) calcium hydrogen phosphate (anhydrous) (E341) croscarmellose sodium (E468) magnesium stearate (E470b) stearate and sodium fumarate',
#  'In this study, no increased incidence of lymphoproliferative disorders or tumors was observed.',
#  'These buildings offer tourist services regardless of the reasons and include monasteries, convents, seminaries, religious schools, etc.',
#  'After sunset.',
#  'The company also presented results from a series of studies with other vaccines containing different serotypes of the bluetongue virus, as well as published information to demonstrate how the vaccine will act in younger sheep.',
#  'According to this distinction, nurses are not simple passive transmitters of knowledge, connecting the academic world and public service networks with the community, but have the autonomy to adapt communication according to contexts and situations.',
#  'The primary variable of the two studies was the continuous dropout rate of 4 weeks (4W-CQR) from week 9 to week 12, confirmed by carbon monoxide (CO).',
#  'p value < 0.0001.',
#  "Head and neck tumors cause deficiencies at various levels, potentially compromising the functional integrity of mastication, voice, speech, swallowing, and articulation, causing psychological and aesthetic damage, and leading to occupational disturbances in the patient's lifestyle.",
#  'Data analysis.',
#  'With the intensification of globalization, the exchange of goods, services, people, and diseases between countries, interest in global health issues has increased in various health professions, and consequently, these contents are inserted into various undergraduate courses in the health field and other related areas.',
#  'To complete his academic formation, he declared himself to be a reader by "hobby".',
#  'This effect may be attributed to the increase in fatty acid oxidation potential in the muscle of trained animals and also to the permissive effect of GC on the lipolytic action of adrenaline and noradrenaline, whose plasma concentrations are elevated during physical exercise.',
#  'A semi-structured questionnaire of own elaboration was used for data collection, which consisted of two parts: the first part collected general and personal data of the family and the responsible for the first aid kit; the second part was formed by questions related to the study variables.',
#  'Cattle, sheep, pigs',
#  'There are some possible explanations for the differences between our results and what is reported in the literature.',
#  'The revised proposal was adopted with 671 votes in favor, 10 against and 15 abstentions.',
#  'Treatment and prevention of respiratory infections associated with Mycoplasma gallisepticum in chickens.',
#  'The session this year has been held in a virtual form.',
#  'Erasmus+ Project Results Platform',
#  'Flebogamma DIF 100 mg/ml should be infused intravenously at an initial rate of 0.01 ml/kg/min for the first thirty minutes.',
#  'Immediately before the booster injection, anti-PRP GMTs were 0.40 µg/ml and 0.64 µg/ml for HEXAVAC and the control group, respectively.',
#  'When compared with REYATAZ 300 mg/ritonavir 100 mg once daily in the afternoon without efavirenz.',
#  'The benefits of such practices for the maintenance of the quality of life of the people were the great motivator of this study.',
#  'Bondronat is indicated for:',
#  'Left ventricular ejection fraction LVEF was calculated from the final diastolic volume VDF and final systolic volume VSF data.',
#  'In the Brazilian democratic scenario, CEPs are spaces for that debate.',
#  'Life-supporting treatments included hemodynamic support with infusion of vasoactive drugs, antiarrhythmics, antihypertensives, inotropics; mechanical support with intra-aortic balloon pump/BIA; and ventilatory support with invasive mechanical ventilation.',
#  'When recommended loading doses are administered, either intravenously or orally, plasma concentrations approach steady-state levels within the first 24 hours of administration.',
#  'The observation and interviews revealed that families make festive gatherings or with friends a reason to share a few drinks.',
#  'Drinks for cats',
#  'On 19 March, Trump falsely claimed that the drug chloroquine was approved by the FDA as a treatment for COVID-19.',
#  'QUADRAMET is only used in bone metastases that can take up a type of chemical substances called bisphosphonates, which means that the metastases will also take up the QUADRAMET drug.',
#  '• a preloaded syringe of Pelgraz;',
#  'In another study conducted in France, which used linear regression analysis, the authors found a relationship between low knowledge and not having received training, and feeling poorly informed.',
#  'Physical education information',
#  'In more than 60 years of existence, the Brazilian Archives of Cardiology has been the main vehicle for the dissemination of Brazilian scientific research in the field of cardiovascular diseases, representing the largest heritage of the Brazilian Society of Cardiology.',
#  'There are no safety data available following treatment with Ziagen in children under three months.',
#  'The Marketing Authorisation Holder (MAH) shall carry out the following programme of studies within the specified period, the results of which shall serve as the basis for the annual reassessment of the benefit/ risk profile.',
#  'Special effects animation services for film and video.',
#  'The marketing authorisation was renewed on 16 October 2003 and 16 October 2008.',
#  "The efficacy of rotigotine in the treatment of the signs and symptoms of idiopathic Parkinson's disease was evaluated in an international pharmaceutical development program that consisted of four pivotal, parallel, randomized, double-blind, placebo-controlled studies and three studies on specific aspects of Parkinson's disease.",
#  'The majority of reactions were managed by a reduction in the infusion rate, temporary cessation of infusion, or pre-treatment, usually with oral antihistamines, antipyretics and/ or corticosteroids.',
#  'The EDGE study included 7,111 patients with OA treated with a dose of etoricoxib of 90 mg per day (1.5 times the recommended dose in OA) or diclofenac 150 mg per day for a median duration of 9.1 months (maximum 16.6 months, median 11.4 months).',
#  'Also see ribavirin SPC if interferon alfa-2b is to be administered in combination with ribavirin in patients with chronic hepatitis C.',
#  'Pertussis toxoid1 Filamentous haemagglutinin1 Pertactin1 Hepatitis B surface antigen2,3',
#  'In a validity study of the AUDIT in 302 university students in Mexico, 40.13% abstained from drinking, 88.29% were high-risk drinkers, and 103.34% met the criteria for dependence.',
#  'The lessons learned will be taken into account to detect any lack or problem or a potential improvement of the actions or their results and to contribute to maximizing their exploitation or impact.',
#  'Glucine',
#  'The literature points to a decrease in sleep quality in the first days after surgical intervention, with return to preoperative levels at varying intervals; however, there are no reports of improvement in sleep quality in the postoperative period, as was found in this study.',
#  'It was paradoxical that I received a couple of Skype calls from friends in the US and Saudi Arabia on the same Saturday, and many email messages, indicating the concern that this catastrophe generated worldwide, in circumstances where I only had telephone contact with my brother, who lives a few kilometers away in Santiago, three days later.',
#  '• Allergic reaction in the eye',
#  'Patients should be clinically evaluated after two years of treatment and the continuation of treatment should be decided by the prescribing physician on an individual basis.',
#  'The elaboration of the content was based on scientific literature, to ensure it was credible.',
#  'No dose adjustment is required in these patients.',
#  'Type 2 diabetes is a disease in which the pancreas does not make enough insulin to control the level of glucose in the blood, or when the body is unable to use insulin effectively.',
#  'DATE OF REVISION OF THE TEXT [To be completed nationally]',
#  'But how to promote this new way of thinking and managing the SUS?',
#  'The work performed by these professionals is characterized by low control over activities performed, workload overload, repetition of tasks, high competitiveness and low salaries.',
#  'In addition, the age of onset of the problems coincided with the phase of residence and immediately after residence, which appears to be a period of greater vulnerability for this type of dependence in particular.',
#  "It is considered a'site' the grouping of one or several curves with similar geometric characteristics of the same condition, whether horizontal, vertical, or the combination Fitzpatrick et al., 2000.",
#  'Vaccination with Nobivac Piro does not prevent infection.',
#  'In Brazil, following global trends, breast cancer takes the first place in statistics, followed by Cervical Cancer (CCU) which takes the second position.',
#  'For the model related to horizontal movements, the response variable was the closest distance to the coast at which the fish was found and the selected explanatory variables were the bathymetry of the area, the water temperature recorded by the acoustic transmitters, the time of day and sex.',
#  'The decrease in renal excretion of calcium may be accompanied by a fall in serum phosphate levels, which does not require therapeutic measures.',
#  'Novartis Animal Health GmbH Tel: +43-(0)5338 2000',
#  'Residential stability, a concept opposite to residential mobility, facilitates the transmission of intergenerational values and the subsequent creation of social networks that provide new generations with opportunities to maintain or improve their social status.',
#  'In an open-label, single-arm, Phase 3b clinical trial (ENHANCE), 2378 adult patients with severe sepsis were treated with drotrecogin alfa (activated).',
#  'In the body, waste nitrogen is in the form of ammonia, which is especially toxic for the brain and causes, in severe cases, a decrease in the level of consciousness and coma.',
#  'That recognition is related to the vulnerability of the professional, which will be, in a certain way, alleviated, if he is aware.',
#  'Diclofenac sodium Voltarol Ampoules 75mg/3ml, solution for injection',
#  'Therapeutic strategies to overcome this infection have been basically two.',
#  'In reality, the Limean history of the passages has been built under the imprint of a basic condition.',
#  'A tool was developed for the study containing the following variables: age, sex, presence of concomitant diseases diabetes mellitus, hypertension, history of peripheral vascular disease, severe coronary artery disease, and smoking >10 cigarettes/day.',
#  'The women were categorized as belonging to a low socio-economic canton or a high socio-economic canton based solely on their reported place of residence, and not on any other demographic characteristic.',
#  'The scientific opinion is transmitted to the European Commission.',
#  'Finally, our patients had received antivenom at the accident site. However, the time elapsed between the accident and administration of the antivenom exceeded the ideal time for its beneficial effects.',
#  'Of the 93 deaths from all causes, 21 classified as resulting from "ill-defined conditions" were of unknown cause.',
#  'The simultaneous administration of ENGERIX B and a standard dose of IgHB does not result in lower anti-HBs antibody titres, provided they are administered at different injection sites.',
#  'The Union has experience in the field of loans for financial assistance, particularly within the framework of the European Financial Stability Mechanism (EFSM) and balance of payments assistance.',
#  'Safety: Warning 6; Adverse effects 7; Contraindications 8; Interactions 10;',
#  'Luggage skis for vehicles',
#  'Palm leaves [raw or partially processed material]',
#  'The immunogenicity of HEXAVAC may be reduced by immunosuppressive treatment or immunodeficiency.',
#  'A significantly higher proportion of women treated with Livensa showed a benefit in the three variables, which was considered clinically significant, compared to women who received placebo.',
#  'A two-compartment model with parallel linear and non-linear clearance from the central compartment described the trastuzumab concentration-time profile.',
#  'The National Institute of Nursing Research (NINR) has been funding nursing research through training programs, as well as support for individual researchers to investigate nursing phenomena, using the existing funding mechanisms at the NIH.',
#  "In this sense, the valuation of the relationship between parents and the healthcare team in the relief of the child's postoperative pain constitutes one of the important efforts for the occurrence of that practice.",
#  '3 mm in diameter and supplied in a single dose applicator (labeled with [sublingual tablet]).',
#  'It is expected that the results of this study will serve as guidance and support for nursing research in health systems and services across the entire region.',
#  'Focetria should not be administered at the same time as other vaccines (if another vaccine is required at the same time, the injection should be carried out in a different limb.',
#  'In all cases, it is a matter of variable strip-type communities and/or coral reefs, located in bays or behind rocks that protect them from the waves, that do not exceed 12 m in depth.',
#  'Only nine items had mean scores for the total sample that were 4.0 or less; while only other 12 items had mean scores below 4.0 for one or more subsamples.',
#  'A questionnaire with closed questions was designed, where the following variables were collected: Age, gender, bile duct size on ultrasound, bile duct dilation on ERCP, common bile duct diameter on ERCP, post-ERCP diagnosis and failed ERCP.',
#  'The Spanish "umbrella" scheme allows the granting of aid in accordance with the modifications to the Temporary Framework, adopted by the Commission on 3 April 2020.',
#  'Before inserting the cartridge into the reusable OptiClik pen, the cartridge must be stored at room temperature for 1 to 2 hours.',
#  'ic',
#  'Eesti BRISTOL-MYERS SQUIBB GYÓGYSZERKERESKEDELMI KFT.',
#  'In men, FSH is needed for the production of sperm.',
#  'Based on these parameters, consumption ranges were re-grouped, thus identifying the population below and above the consumption levels suggested by this organization.',
#  'The findings of that study allowed observing that the largest number of interventions/activities was related to the domains "Complex Physiological" and "Health System".',
#  'Cross-resistance with other fluoroquinolones is observed.',
#  'Single-dose container containing 15 vials with powder and 15 pre-filled syringes with solvent.',
#  'However, its efficacy was lower in areas with high metronidazole resistance.',
#  'The mean FEVD in the four groups was, respectively, 42.4 ± 4.7, 28.2 ± 2.7, 50.3 ± 5.1, and 22.0 ± 6.5%.',
#  'A standardized observer analyzed the radiographs using a radiograph viewer, to evaluate the presence of supernumerary teeth, which was subsequently confirmed through photographs.',
#  'Therefore, it can be concluded that closantel administered subcutaneously should not be used during drying.',
#  'Ciprofloxacin is present in the plasma, to a large extent, in a non-ionized form, and, in a steady state, has a large volume of distribution, of 2 to 3 l/kg of body weight.',
#  '17, Boulevards De La Plaine B-1050 Bruxelles Belgium',
#  'Apealea should be reconstituted with one of the three following suitable reconstitution solutions and in accordance with the following steps:',
#  '- Do not take antacids, multivitamins, or other products containing calcium (such as milk',
#  '(It is also better to avoid Amlodipino/Valsartán Mylan in early pregnancy, see Pregnancy section).',
#  'The Pearson correlation test was used to analyze the numerical variables between the two stages of the study.',
#  'In the first stage of the operationalization of the data, the mapping of the exploratory phase of the research was concretized, developed in three stages:',
#  'Valproic Acid/emtricitabine',
#  'Piroxicam exerted a negligible increase of 0.49 mmHg in mean blood pressure.',
#  'The term "post-secular ethics" is coined by Jürgen Habermas, which is surprising in a thinker cataloged and criticized as excessively rationalist, although worn down by his consequent search for dialogue with religiosity, as illustrated by his respectful conversations with then Cardinal Ratzinger.',
#  'Initially, three categories of ethical problems affecting nurses were identified, moral suffering, moral uncertainty, and moral dilemmas.',
#  'Blood pressure is significantly higher in obese patients when compared to lean normotensive subjects, regardless of blood pressure levels, thus the activation of the renin-angiotensin-aldosterone system RAS is involved in arterial hypertension and obesity.',
#  'Atripla should be avoided in patients with HIV-1 harbouring the K65R, M184V/I or K103N mutation (see sections 4.1 and 5.1).',
#  'Member States, with the support of the Commission and the European Medicines Agency, must continue to carry out the following tasks:',
#  'It is necessary to think about the nefarious consequences for the international order of the hypothesis that each of the nearly two hundred states invokes for itself the right to conduct "preventive attacks", based on unilateralism.',
#  'A coronary and axial imaging composite was performed in all cases.',
#  'The patient responses were compared with the data contained in the medical record.',
#  'In the absence of compatibility studies, this medicinal product must not be mixed with other medicinal products except with human NPH insulin.',
#  'Early gastric cancer CGT is a tumor confined to the mucosa or submucosa, regardless of the presence or absence of lymph node metastasis 15, whose prognosis is excellent if it can be detected and treated promptly, achieving a survival rate of over 90% at 5 years, which is in stark contrast to that of advanced gastric cancer 15, 16.',
#  'Erythema multiforme1), Stevens-Johnson syndrome1), angioedema1), cutaneous vasculitis1) lichenoid reaction in the skin1)',
#  'In acute toxicity studies, single intravenous and oral doses of iloprost produced severe symptoms of intoxication or death (IV) at doses approximately two orders of magnitude above the intravenous therapeutic dose.',
#  'Injecting your Dose A.',
#  'Intrathecal opioids are known to increase the analgesia of subtherapeutic doses of local anesthetics.',
#  'The population consisted of 1st degree Nursing students enrolled in Faculties and Schools of the University District of Seville during the academic year 2010-2011 N=510.',
#  'Adverse reactions attributed to MIRCERA treatment in controlled clinical studies in patients with CKD.',
#  'It is primarily bacteriostatic and its antimicrobial effect is thought to be due to the inhibition of protein synthesis.',
#  'The vasoconstrictors most often used in combination with local anesthetics belong to the group of sympathomimetic amines that include epinephrine, norepinephrine, levonordefrin, phenylephrine, and methoxamine.',
#  'After reconstitution, the liquid should be colourless and essentially free of foreign particles; the parathyroid hormone (ADNr) should not be used if the reconstituted solution is turbid, coloured or contains visible particles.',
#  'Round, biconvex white tablet, marked "OL 5" on one side.',
#  'Administration of doses higher than the recommended (see section 4.2) for a longer period (of several months) may cause suppression of the hypothalamic-pituitary-adrenal axis.',
#  'On rectal examination, a hypotonic sphincter with a limited anal margin and non-tender circular papillae were observed.',
#  'Communication of data by electronic means',
#  'There are no adequate data or these are limited on the use of filgrastim in pregnant women.',
#  '• Patients receiving injectable calcitonin who have questions should speak with their doctor or pharmacist.',
#  'Pigs treated with Metacam showed a significant decrease in blood cortisol levels (indicating they were exposed to lower stress levels) 30 minutes after castration compared to the control group.',
#  'Storage of Insulin Human Winthrop Rapid Contents of the container and additional information',
#  'The company was asked to provide more data to justify the use of that comparator drug and specifically, to see how the furoate of mometasone was released in the body of the comparator drug and the already approved medicine.',
#  'In a study conducted in 2005 by SCS Engineers at the RESA of Chihuahua Mexico, it was found that they used the SCS Model, which is a modified version of the EPA model.',
#  '- if you are taking diltiazem, verapamil,',
#  'Insulin Human Winthrop Infusat 100 IU/ml solution for injection in a vial Insulin human',
#  'From the geometry of Figure 3a, the length of the sliding plane is LBD = h/2 cos?, the angle of inclination iBD is equal to?/2 -? +?, and as shown in Figure 3b the increase in velocity is',
#  'The effect of gravitational field between celestial bodies of large mass also shows analogy with the electromagnetic forces that ensure the organized arrangement of electrons in their orbits around the atomic nucleus.',
#  'The target of adalimumab is a protein called tumour necrosis factor (TNFα), whose levels increase in the inflammatory diseases listed above.',
#  'Because of this, mothers should be advised to discontinue breast-feeding before taking Zerit.',
#  'No prolongation of the QT interval was observed for nintedanib in the clinical trial program (see section 5.1).',
#  'In relation to alternative transport (7), the circumstances of the COVID-19 outbreak may affect the right to choose an alternative transport as quickly as possible (8).',
#  'Administration of the medicine should be carried out under the close supervision of a healthcare professional with experience and in an environment where resuscitation equipment is readily available.',
#  'The sequelae left by LM significantly impair the ability of people to perform some activities in their daily routine, mainly those that require a lot of musculoskeletal functions such as: transferring, walking, and climbing stairs.',
#  'Mother, E5, P.12',
#  'The "great time" is, above all, this possibility of the "strange coincidences", as if destiny were leading one by the hand with some inextricable purpose.',
#  'At the end of the surgeries, the patients were monitored in the recovery room for 60 minutes after they woke up and were then transferred to the admission units.',
#  'Certain health problems that you may have or have had require special precautions before or during treatment with Invirase/ritonavir.',
#  'The participant will express their consent in writing or, in default, orally in the presence of an independent witness from the research team who will record it in writing under their responsibility.',
#  'There are assisted feeding alternatives that should be taken into account before suggesting artificial feeding to these patients 5, 14.',
#  'If you have any problems, please ask your doctor or nurse for help and advice.',
#  'The examples of multiple substitutions were insufficient to determine a consistent pattern of substitutions or their effect on viral susceptibility to enfuvirtide.',
#  'The web server allows access to the configuration and diagnostic data of the concentrator circuit through an Internet browser.',
#  'Dry mouth',
#  'Sandimmun concentrate for infusion solution contains ricinoleate of macrogolglycerol/castor oil polyethoxylated which can cause the redisolution of polyvinyl chloride phthalate.',
#  'Your symptoms may return after stopping treatment.',
#  'The aim of this study is to present the results of PCIs in Brazil, with focus on the access route used, in the four-year period 2005-2008, according to the data from the National Center of Cardiovascular Interventions CENIC.',
#  'Administration of glucagon Can recover consciousness more quickly if you administer a glucagon injection to them',
#  'That word is changing in meaning.',
#  'Incidentally, the community does not need a new indicator, but rather to carry out the work of the documentary filmmakers of the early 20th century, and a good start would be to manage the bibliographies, and then who knows who will propose new indicators.',
#  'The pharmacokinetics of eltrombopag have been studied after administration of eltrombopag to adults with renal impairment.',
#  'Even when they recognize the differences, the spaces of dispute and conflicts, they seek strategies of overcoming and continuous learning in the work environment, in order to improve interpersonal relationships, as can be illustrated in the following comments:',
#  'It is worth noting that the prevalence of non-adherence in individuals with glycated hemoglobin greater than 7% was 85.7%.',
#  'Calcitonin Sandoz 100 IU/ml solution for injection and infusion intravenous use, intramuscular use, subcutaneous use',
#  'Thus, for the same reason, it was also possible to suppose that divine wisdom had disposed each of the natural forms on earth in such a way that distances would not neutralize their intentions.',
#  'Haematological parameters should be determined before the start of treatment and after each dose of VEPESID and associated formulations: platelet count, haemoglobin, white cell count and differential.',
#  'The mother presented a normoevolutive pregnancy and regular prenatal controls which demonstrated at 28 weeks of intrauterine life an increase in the fetal head circumference and anomalies in the development of the upper and lower limbs.',
#  'It appears to us that the inspiratory phase is very long, almost three times compared to the expiratory phase E, not being for us the I:E ratio most suitable for an asthmatic crisis, nor is the respiratory frequency and the volumes a bit low.',
#  'The total number of cases increased to 15,679 and the number of deaths reached 277.',
#  'Thus, it does not limit itself to the issue of the sexual act, it goes much further and is configured as a symbolically constructed reality.',
#  'Thus, it is not to the figure of other professionals that nurses are approaching in that analogy, and yes to the function of those professionals.',
#  "It's very good.",
#  'The EG study in patients with IRC on dialytic treatment and on conservative treatment, did not yield statistically significant differences in the gastric retention curve and in the EG half-life, when compared to a group of healthy patients.',
#  'Some studies have been demonstrating that patients with LES have a risk of 2 to 50 times higher of acquiring atherosclerotic heart disease, which represents an important cause of premature mortality in that disease.',
#  'HOW TO USE VELCADE',
#  'Multiple logistic regression analysis was conducted with consideration of variables that presented p<0.20 in the bivariate analysis.',
#  'These terms share a common root: the discipline, from the Latin discere, which means to learn, from which derive student and disciple.',
#  'Rainwater collection system installations',
#  'uth 14.',
#  'What you need to know before starting to use LUMIGAN 0.3 mg/ml',
#  'The anticoagulant efficacy of Clopidogrel BMS was compared with that of aspirin in a study called CAPRIE that included approximately 19,000 patients with atherothrombosis.',
#  'Remote control vehicle models',
#  'If used well and widely applied, eHealth can be a strategic tool that enables improved access, expanded coverage, and increased financial efficiency of health care systems.',
#  "Total dose = patient's weight multiplied by the recommended dose (1.8 mg/kg",
#  'A shared approach between the patient and healthcare professional could avoid the knowledge gaps of diabetic patients.',
#  'The AHRLJ is published twice a year, in March and in October.',
#  'For diagnostic use only.',
#  'Distribution No significant binding to plasma proteins, except circulating insulin antibodies (if present) has been observed.',
#  'The fetus is a vital organ during gestation and plays a leading role; as Dr. Alejandro Bautista expresses, "it is a dynamic force in the orchestration of its own destiny".',
#  'Back pain Arthralgia Muscle spasms Myalgia',
#  'In a model of visceral pain, colorectal nociceptive response was attenuated by the intrathecal administration of an NMDA receptor antagonist in ovariectomized rats, compared to those ovariectomized with estradiol replacement.',
#  'Myelosuppression The treatment with Tasigna has been associated with thrombocytopenia, neutropenia, and anaemia (Grade 3-4 according to the "Common Toxicity Criteria" of the National Cancer Institute).',
#  'The nursing diagnosis was the only unrecorded stage in the charts.',
#  'Take the soluble tablets once a day with a meal to enhance absorption, and at the same time each day, preferably in the morning.',
#  'The factor "The current negative culture that dominates the household community decreases quality" was ranked in the second position among the promotion of safety and health group with RII = 0.701 and was ranked also in the 27 position among all quality factors groups.',
#  'The carcinogenic potential of cladribine was evaluated in a long-term 22-month study with subcutaneous administration in mice and a short-term 26-week study by oral administration in transgenic mice.',
#  'Although DC increased in both groups between weeks 3 and 18, the elevation was lower in the GEAo than in the CG only in week 18.',
#  'To be taken into consideration by patients on a controlled sodium diet.',
#  'In the attempt to explain and justify the answers, the following constructions were collected: "are homonyms"; "one is linked to the other"; "they go together"; "the two things walk together", and "nothing happens by chance, everything has a meaning".',
#  'In all studies, the primary criterion of efficacy was the time of muscle recovery.',
#  'In the event of pump malfunction, patients should always have injection devices (injection syringe or pen) and insulin available for subcutaneous injection.',
#  'Ziconotide is a 25-amino acid natural L-configuration peptide and does not appear to undergo significant metabolism in the liver.',
#  'Table 1 Recommended dosing schedule for Farydak in combination with bortezomib and dexamethasone (cycles 1-8)',
#  'The dose recommended for the second week of treatment is the total dose administered during the first week.',
#  'In comparison with fasting administration, the dosing of tenofovir disoproxil and emtricitabine with a high-fat or light meal increased the mean AUC of tenofovir by 43.6% and 40.5%, and the Cmax by 16% and 13.5%, respectively, without affecting exposures to emtricitabine.',
#  'The processes are the set of tangible and intangible inputs that are related to each other, and operate and transform to produce the expected result or output.',
#  '1 ml (one vial) contains 400 micrograms of methoxy polyethylene glycol-epoetin beta*.',
#  'The present article deals with the use of this algorithm to solve the Duhamel Integral, and focuses on the effect produced by varying the population size on the ability to find an appropriate response.',
#  'These data are adequate as a bridge between the documented efficacy of the reference product (Drontal Plus) and the concerned product (Milaxyn Plus, Strantel Plus, Prazical Plus, Voxical Plus, Exitel Plus, Cazitel Plus and Prazitel Plus and associated trade names).',
#  'The overall safety profile of these subjects was not different from that of the general population.',
#  'Since it is not possible to predict the end of the current crisis, it may quickly lead to a paralysis of activities and companies in a very sector sensitive to cyclical variations.',
#  'Subsequent to this, patients underwent a mandatory tapering regimen with a complete discontinuation of corticosteroids at Week 19.',
#  'As to the communication skills and performance of health workers, there are significant differences between health teams that received training in the AIEPI intervention group and those that did not receive training control group.',
#  'Tadalafil is more than 10,000 times more potent for PDE5 than for PDE7, PDE8, PDE9, and PDE10.',
#  'It is also important that there be a sufficient number of properly trained researchers to prepare and conduct a valid and ethically correct study.',
#  '• Type I diabetes that may include feeling hungrier or thirstier than usual, having to urinate more frequently, weight loss, and feeling tired',
#  'Researchers found an excess of collagen intermixed with myocardial cells that composed up to 20% of the material examined.',
#  'In this study, participants who committed medication errors reported that the occurrence "did not cause harm" to the patient, likely because the mistakes made did not result in injury, or in other words, were errors that apparently did not become adverse events.',
#  'The following aspects must be recorded at each visit: age, weight, height and assessment of motor development performance.',
#  'Given the significant socio-economic consequences of the COVID-19 outbreak and the need for liquidity in the economy, it should be possible to support the temporary cessation of fishing activities caused by the COVID-19 crisis with a maximum co-financing rate of 75% of eligible public expenditure.',
#  'In the case of perinatal mortality, the direct determinants are the biological factors: low birth weight and prematurity.',
#  'Zinc chloride Glycerol Metacresol Phenol Disodium phosphate dihydrate Sodium hydroxide (for pH adjustment) Hydrochloric acid (for pH adjustment) Protamine sulphate Water for injections',
#  'The potential risk to humans is unknown.',
#  'The cause of allergic reactions with BeneFIX has not yet been determined.',
#  'A study found, in the bivariate analysis, that men who self-reported hypertension had a prevalence ratio of 1.44 times to have overweight and obesity, and for women that ratio was 1.72.',
#  'Those results, both the PPV and the NPV, are in line with those found in the literature in adults.',
#  'Along 2019, the evolution of the labor market continued to be positive, but disparities persisted between regions, rural and urban areas, and socioeconomic groups.',
#  'Patients with hepatic impairment: The effect of hepatic impairment on the pharmacokinetics in the steady state of saquinavir/ritonavir (1000 mg/100 mg twice daily for 14 days) was studied in 7 HIV-infected patients with moderate hepatic impairment (Child Pugh Grade B score of 7 to 9 points).',
#  'If you take more Bonviva than you should, you may suffer a decrease in blood levels of calcium, phosphorus, or magnesium.',
#  'The interaction between the technical skills and knowledge of the systems engineer and administrative knowledge can generate software products that support teaching and training processes in SISP.',
#  'During many years, science was part of philosophy, to the extent that scientists were called Natural Philosophers.',
#  'Financial services provided by telephone and through a global computer network or the Internet.',
#  '9/ 19 PARTICULARS TO APPEAR ON THE OUTER PACKAGE',
#  'The patients in whom more than one attempt at laryngoscopy and intubation was made, or in whom the laryngoscopy and intubation procedure took more than 20 seconds, were also excluded from the study.',
#  'Taking Olanzapina Teva with food and drink Do not drink alcohol while taking Olanzapina Teva as the combination of Olanzapina Teva and alcohol may cause drowsiness.',
#  'The correct identification of risk factors from available information, site visits, and additional data collection allows the formulation of measures in favor of reducing accidents.',
#  'Additionally, it represents a significant medical-legal risk for the healthcare professional and the work team in this area; figures from the UK show that nearly 70% of medical-legal payment is derived from obstetric care.',
#  'The term iatrogenesis is derived from the Greek and is composed of iatros, meaning "physician", and genesis, "origin".',
#  'The Irish and British Association of Anesthesiologists generated a 25-page document specifically to deal with the problem of fatigue in its members and made recommendations on safety issues for equipment and patients.',
#  'This study aims to identify the NPS of the ICU and the interior of the incubator of a university hospital affiliated with a public university in São Paulo, SP, Brazil.',
#  'Dogs compromised or weakened:',
#  'Many conclusions have been drawn and many types of filters have been proposed in order to minimize their effect, for example, a differential mode filter was proposed by S. J. Kim and S. K. Sul in 1997 and a common mode filter was proposed by S. Ogasawara and H. Akagi in 2001.',
#  'The seroprotection rate, the seroconversion rate and seroconversion factor for anti-HA antibody were as follows 21 days after the first dose:',
#  'Pharmacokinetic parameters of Spectrila were determined in 7 adult patients after intravenous infusion of 5000 U/m².',
#  'In the unfortunate case of no means being available, at least the wound must be covered from the air and microorganisms with any piece of cloth or tissue, as long as it is well cleaned.',
#  '• Hold the ampoule upright and tap lightly before removing the top to prevent spillage.',
#  'Another limitation refers to the fact that, in the studied sample, the psychosocial variables that determine medication adherence are unknown, which could enable a better delineation of the intervention - motivational and/or volitional.',
#  'Limited experience with overdose of Hemlibra has been reported.',
#  'Talc Hypromellose Macrogol Titanium dioxide (E171)',
#  'Natriuretic peptides PNB and NT-proPNB have utility in the diagnosis of decompensated HF in emergencies, confirming or ruling out the diagnosis in patients with breathlessness, and giving a prognostic value to that population, especially in hospital discharge, to prevent future events.',
#  'The National Demographic and Health Survey (ENDES) 2008 Baseline involved women between 15 and 49 years old.',
#  'With the end of the Mexican Empire, from mid-1867, several men of science, involved in imperial scientific activities, had to reorient their political activities under the republican government of Benito Juárez and disentangle themselves from the imperial past to pursue the scientific and professional goals they were seeking.',
#  'In vitro studies with human microsomes show that concomitant treatment with substances metabolized by CYP450 isoforms may produce higher or lower plasma concentrations of masitinib or those substances.',
#  'Publication of calendars',
#  'Solvent for injection suspension.',
#  'All the sequences of the cagA, FR, and WSR regions of the reference strain: H. pylori NCTC 11637 were compared with the sequences already reported in the databases, therefore it was used as a positive control for the sequencing.',
#  'Other information about Ceplene',
#  'Common side effects (may affect at least 1 in 10 patients)',
#  'As can be observed, of the 50 samples analyzed for meat, 48% of the establishments presented a good appearance and all were maintained in refrigeration chambers; the opposite for the sausage, where around 54% of the establishments appeared in a regular to poor condition.',
#  '• Treatment of hyperlipoproteinemia, • Primary prevention of cardiovascular morbidity.',
#  'Neither EVA nor morphologic side effects were evaluated.',
#  'It is worth noting that the concept of vulnerability gained strength and visibility in the Brazilian health area with the advent of AIDS, due to the association of the disease transmission mode with the concept of risk.',
#  'The calculation of the required dose of factor IX is based on the empirical finding that 1 International Unit (IU) of factor IX per kg body weight increases the plasma factor IX activity by 0.7 IU/dl (range of 0.31 to 1.0 IU/dl) or 0.7% of normal activity in patients under 12 years of age (for additional information, see section 5.2).',
#  'Licorice roots for pharmaceutical purposes',
#  'In addition, the company that markets Procysbi will provide educational materials to all doctors who may prescribe the medicine, with important safety information that includes the risk that the medicine may be harmful to the fetus.',
#  'Furnaces for metal decontamination',
#  'It is important to avoid the introduction of the IB D388 vaccine virus in holdings where the wild strain is not present.',
#  'In terms of intensity, 42.1% reported strong pain, 25.9% moderate, 19.4% mild, and 12.6% considered feeling the worst possible pain.',
#  'A deformation of the global balance and/or collective order implies that some people relax while others overexert themselves.',
#  'Different doses of fentolamine administered via the subarachnoid route generate various effects on pain sensitivity, possibly due to the involvement of different subclasses of alpha-adrenergic receptors in the pain modulatory pathways.',
#  'The initial dose is 15 mg as a single daily dose in monotherapy or 10 mg per day in combination therapy (see section 5.1).',
#  'This was a prospective observational and analytical study.',
#  'CYP3A inhibitors',
#  'In the face of the need to know the perception that the person with DM has regarding AS, as well as its relationship with metabolic control and adherence to both pharmacological and non-pharmacological treatments, this study was developed.',
#  'Additional measures are needed to prospectively minimize the reappearance of this contamination.',
#  'Consideration should be given to reducing the dose of pramipexole when these medicines are administered concurrently with Oprymea.',
#  'This activity breaks the life cycle of the mite.',
#  '- if you are allergic (hypersensitive) to sitagliptin or any of the other ingredients of',
#  'It is destacated that knowledge about the name, dose, and frequency of administration of the medications is of utmost importance so that the patient is able to avoid errors in the use of the same.',
#  'Breast Cancer Resistance Protein (BCRP)',
#  'This is also the case for the credits related to the Flexibility Instrument.',
#  'Poverty and lack of access to health services allow the existence of such diseases.',
#  'Zutectra should not be injected into a blood vessel.',
#  'Exposure to bosentan decreased over time in accordance with the known enzymatic auto-inductive properties of bosentan.',
#  'The breath samples, collected in breath sample bags, are analyzed by non-dispersive infrared spectroscopy (NDIR).',
#  'Adrenaline (tartrate) Jext',
#  'The concentration of social housing in sparsely equipped populations gives Los Morros a different character to that of Gran Avenida.',
#  'If you take more Zonegran than you should, tell a carer (relative or friend), your doctor or pharmacist immediately, or contact your nearest hospital casualty department, taking your medicine with you.',
#  'The fatigue models developed for different materials and service conditions produce different results, which generates the need to perform model calibration for local use conditions.',
#  'Do not use in pregnant or breeding animals (see section 4.7).',
#  'Pharmacokinetics of atazanavir.',
#  'Thus, for Herz, the totality of these relationships is the spatialization of the field Herz, 2008.',
#  'A second group focuses on the audiovisual, with special emphasis on Hollywood films and a phenomenon that has gained strength in recent years: the boom of Colombian telenovelas in Spain.',
#  'Planning to be a father and mother',
# ...
#  'In the abatacept-controlled clinical trials with placebo, adverse drug reactions (ADRs) were reported in 52.2% of abatacept-treated patients and in 46.1% of placebo-treated patients.',
#  'Aluminum hydroxide, Mineral oil (Marcol 52), Sorbitan monoleate (Arlacel A), Polysorbate 80 (Tween 80), Thimerosal',
#  'In general, there is no difference in teaching load, didactic strategies, and evaluation of AIEPI teaching between public and private institutions, but the number of trained teachers is lower in private schools, which may imply precarious quality of teaching.',
#  'Savings account services',
#  'The European Commission granted a marketing authorisation valid throughout the European Union for Aloxi to Helsinn Birex Pharmaceuticals Ltd. on 22 March 2005.',
#  'Patients treated with adalimumab showed a significantly greater improvement at week 12, which was maintained through week 24 in both the SF36 and the Ankylosing Spondylitis Quality of Life (ASQoL) questionnaire.',
#  'In the BCSC, a novel design was developed, according to which there are 2 induction rooms connected to each operating room in order to offer a highly efficient flow of the assisting personnel.',
#  'Other medicines and Silapo',
#  'These include a careful selection of blood and plasma donors to ensure that those at risk of carrying infections are excluded, and the testing of individual donations and plasma banks for signs of virus/infections.',
#  'Variables with a non-normal distribution were subjected to log transformation.',
#  'What you need to know before you use ADYNOVI',
#  '- The other ingredients are: sodium hydroxide, glacial acetic acid, sorbitol, polysorbate 80.',
#  'You can discuss this with your doctor.',
#  "From an operational perspective, the characteristics of these trades result in high wages and high safety costs, and negatively affect the worker's motivation.",
#  'Cases of hepatic damage (hepatocellular, cholestatic, and mixed) and autoimmune hepatitis have been observed.',
#  'Aranesp 500 micrograms solution for injection in pre-filled syringe Each pre-filled syringe contains 3.79 mg of sodium in 1 mL.',
#  'Ibalizumab is active against HIV-1 group M strains (subtypes A, B, C, D, E, or O).',
#  'There was a large variability between districts in the distribution of the IHD mortality rate 0 to 9,247.77/100,000.',
#  'There is a lack of safety or efficacy data in children or adolescents regarding the use of Rebetol with peginterferon or other forms of interferon (that is, not alfa-2b).',
#  'Plasma levels of some HIV-1 protease inhibitors metabolized mainly by CYP3A4 may increase when administered with low doses of ritonavir, which is an inhibitor of this metabolic pathway.',
#  'Based on a normal approximation of the difference in response rates (NC = Fa) Differene in means',
#  'There is a trend in academic research to refer to mutilation as a mark that can be seen with the eyes, an act performed on the body that aims to eliminate the disease and is necessary for the healing of the person.',
#  'If only Insulatard is injected.',
#  'In this registry, we applied an early invasive strategy aiming to identify high-risk patients, such as carriers of severe multi-vessel CAD 23.0% and stenosis in the left coronary trunk 2.0%.',
#  'Following subcutaneous administration of a daily dose, steady state plasma levels are achieved after 3 to 4 days with a 1.3-fold increase in Cmax and AUC.',
#  'As for all parenteral medicinal products, inspect the reconstituted solution visually for particulate matter and discolouration prior to administration.',
#  'Write the new expiry date on the carton including day/month/year (not more than 30 days after the medicine is removed from the refrigerator).',
#  'There is no evidence of in vitro or in vivo mitochondrial toxicity.',
#  'Summary of AEs occurring in RA patients receiving tocilizumab monotherapy or in combination with MTX or other DMARDs',
#  'The article is divided into three sections.',
#  'Prevalence and distribution of cardiovascular risk factors',
#  'The oral bioavailability of itraconazole is maximum when the capsules are taken immediately after a full meal.',
#  'This is a prospective, observational study; a cardiac arrest registry was designed, disseminated, and requested to be filled out by the hospital physicians who participated in cardiopulmonary resuscitation maneuvers during the described period.',
#  'In this study, 5 mcg.kg.min was used, without a bolus dose.',
#  'Patients with moderate to severe renal impairment: dose adjustment of Trobalt is recommended, no dose adjustment of Trobalt is required in patients with mild renal impairment (see section 4.2).',
#  'As a maintenance dose, clopidogrel should be administered as a daily dose of 75 mg with or without food.',
#  'The data presented in Figure 2 show seven latent variables with a total of 43 observed variables.',
#  'The treatment groups were defined as follows:',
#  "There is no teenager with diabetes who doesn't like eating a chocolate, but can't.",
#  '26 Belgium/Eli Lilly Benelux S.A./N.V.',
#  'Caution should be taken in patients with low white blood cell counts and/or neutrophil counts for any reason; in patients on medications known to cause neutropenia; in patients with a history of drug-induced myelosuppression; in patients with myelosuppression caused by concomitant diseases, radiation therapy, or chemotherapy; and in patients with disorders associated with eosinophilia or myeloproliferative disease.',
#  'The hospital is a public institution, of great size, that has agreements with 27 municipalities of the South Triangle macro region, with a total of 281 operational beds, which serve an estimated population of 645,000 individuals.',
#  'Hand tools',
#  'Electric drying machines for household dishes',
#  'See also sections 4.4 and 4.7.',
#  'Diarhoea caused by Vibrio cholerae',
#  '• difficulty breathing or chest discomfort',
#  'The average duration of the test was longer in the non-obese group p < 0.05 than in the obese group.',
#  'During life, the dentition passes through three phases of development: deciduous or milk dentition from 6 months to 6 years, mixed dentition from 6 to 12 years, and permanent dentition from 12 years onwards.',
#  'The primary end result was the incidence of agranulocytosis, which occurred at a frequency of 1.2%.',
#  'In cultural adaptation studies, a minimum of 100 subjects is suggested.',
#  'Resistance to emtricitabine or tenofovir has been observed in vitro and in some HIV-1 infected patients, due to the development of a M184V or M184I substitution in the RT with emtricitabine or a K65R substitution in the RT with tenofovir.',
#  'Construct validity estimation: Construct convergent validity and known groups or contrast validity were confirmed.',
#  'Other medicines and Rebetol',
#  'The pre-filled syringe is now ready for use.',
#  'The role of nurses is highlighted in this context, whether in direct care to the elderly patient or in the training of their caregiver and/or family members.',
#  'Although a greater risk of hemorrhage in the mucous membranes (the tissues that cover body cavities such as the nose, intestine, and vagina) was observed, the Committee considered that such a risk could be controlled with the appropriate measures.',
#  'The etiology of ventricular dysfunction was not an inclusion criterion.',
#  'In these cases of joint administration, the same monitoring recommendations should be applied.',
#  'The complex needs to capture interrelations, distinct and contradictory realities, through a thought that respects diversity, seeking to unite rather than simplify.',
#  'Metformin: metformin should be used with caution: there is a risk of lactic acidosis, induced by a possible renal function failure, associated with hydrochlorothiazide.',
#  'Recently the Imbanaco Clinic group in Cali, led by Dr. Iván Unigarro, has also initiated the exciting experience of Spyglass colangioscopy, with two successful diagnostic cases.',
#  'Pharmacists and auxiliaries filled out an "informed consent" form that allowed the observation of their activities and were notified about an evaluation study of the distribution system, however they remained unaware of the objectives and methodology of the study, these aspects being blind to the pharmacy staff in order to avoid known biases.',
#  'Other studies have demonstrated that the administration of lidocaine before intubation suppressed sympathetic activity related to laryngoscopy and intubation.',
#  'It is essential to highlight that the judicious study of personality requires the expertise of a professional in this field.',
#  'Each tablet contains 1 mg of rasagiline (as mesilate).',
#  'Moreover, an adequate offer of services is required that allows the prevention of those infections through educational activities that reduce the risk of acquiring them, in especially vulnerable groups such as adolescents or the LGBT community, or at the time of contact of patients with health services such as prenatal control or family planning consultation.',
#  'The nuclear ventriculography study showed moderate and severe reduction of ventricular function in the right and left ventricles, respectively.',
#  'Meanwhile, these differences were statistically significant only in the domains Mental Health and Pain.',
#  'Results: The results were favorable, achieving facial and periodontal dental harmony, as well as function, esthetics, and patient satisfaction.',
#  'Since liver damage and tumors have been observed in rats treated with Mycamine for extended periods, patients should be monitored for liver problems during Mycamine treatment with blood tests.',
#  "With the introduction of these services in the student's practice, this led to living with visible physical and psychological wear, due to the lack of familiarity with the work process, which was exacerbated by the lack of control and decision-making power.",
#  'This is especially likely in patients with impaired renal function.',
#  'In the case of a patient who refers additional symptoms after CE ingestion, the intervention will be endoscopic or surgical.',
#  'Hyperglycaemia and diabetes Rare cases of hyperglycaemia and/or development or exacerbation of diabetes occasionally associated with ketoacidosis or coma, including some fatal cases (see section 4.8).',
#  'Not known: alopecia, erythema, night sweats, rash',
#  'Considering the information obtained by SIMOSTE, a prevalence of physiological loads of 36.8%, biological loads of 27.2%, mechanical loads of 25.9%, and psychical loads of 18.9% was observed, at the same time, a notable underreporting of chemical and physical loads was noted.',
#  '29 15.',
#  'Aspartate aminotransferase; increase in alanine aminotransferase)',
#  'Binary logistic regression analysis revealed an association between low scores on the Glasgow scale and the occurrence of UP p<0.001.',
#  'Before starting the data collection process, the project was submitted for review and obtained approval from the Research Ethics Committee of the School of Nursing of the University of São Paulo.',
#  'In this context of high demand, delays in the release of medical reports can occur, as well as failures in the production process in the imaging sector can cause harm to the patient.',
#  'The options vary from 0 to 5 points, none of the time to all the time.',
#  'For a temporary travel restriction to have the desired effect in terms of reducing the spread of the virus, it is necessary to limit the exemptions to essential movements.',
#  'When the results of the first four studies are pooled, 320 (26%) of the 1,213 patients who received a weekly dose of 1.0 mg/ kg of Raptiva responded to treatment, compared with 25 (4%) of the 715 who received placebo.',
#  'E4: Take all safety precautions.',
#  'A good starting point would be to recognize that equality should be taught and learned in the framework of the integration of individuals to their social community of reference.',
#  'Floor preparations for repairing floors',
#  'In this sense, one of the most relevant studies has been the National Survey of Victimization and Public Safety ENVIPE, in which it is observed that the most frequent crimes, from the perspective of the victims, are alcohol consumption on the street, drug consumption and sale, robbery, and assault.',
#  'Talk to your doctor or pharmacist if you are unsure before taking Vascace.',
#  'Direct determination of LDL-ox in plasma, or serum, is complicated by the possibility of in vivo modifications of the samples and the variety of particles, at different levels of oxidation, that can be identified and whose significance, in terms of predictive disease, is also potentially variable.',
#  'No teratogenic effects were observed in rabbits at > 1,000 times the human exposure.',
#  'After injecting the liquid, remove the needle and release the skin.',
#  'Head trauma and cerebral aneurysms remain relatively common situations in neuroanesthesia.',
#  'In the study comparing Jalra with metformin, significantly better results were observed in metformin: a reduction of HbA1c levels of 1.5 percentage points after 52 weeks, compared to a reduction of approximately 1 percentage point in patients treated with Jalra.',
#  'This ash, rich in silica SiO2, is composed of three crystalline phases: sillimanite, silica, and sodium aluminate.',
#  'This population group from Colombia with a high incidence of CG is therefore of great importance to evaluate, and to contrast the hypothesis that cases and controls show significant differences in the frequencies of the genetic polymorphisms GSTM1, GSTP1 and GSTT1, and at the same time, to test whether there are differences in smoking habits, alcohol consumption and socioeconomic level, as well as their possible interactions.',
#  'How to capture the displacements "promoted by technology in the modes of subjectivation: learning, concentration, time/space and effort/enjoyment"?',
#  'Then, this percentage was obtained separately for patients allergic to mold and to dust mites, to evaluate which is the most important.',
#  'If you forget to take a dose, take it as soon as you remember.',
#  'What can be asserted is that nurses believe they have autonomy, control over the environment, get along with doctors, and have organizational support for governance in nursing practice.',
#  'Suffering is present in this group of men, making them more vulnerable, especially when there is an internal break caused by the disease, aware that it is not curable, but it can be controlled, and that there is also a moment when the disease knocks them down, preventing them from doing everything they used to do in their daily life.',
#  'The reason was that the competent national authority in Germany considered that this veterinary medicinal product could represent a significant potential risk to animal health because its efficacy had not been sufficiently demonstrated in the dossier.',
#  'Once absorbed, it binds to plasma proteins primarily albumin, metabolized in the liver and its excretion pathway is basically renal.',
#  'Based on clinical studies, the recommended dose for patients over 65 years old is 20 mg per day (20 mg once a day), as previously described.',
#  'Very common side effects that may appear on a blood test • abnormal changes in your bone marrow cells',
#  'Elderly patients: no dosage adjustment of Irbesartan Hydrochlorothiazide BMS is necessary in elderly patients.',
#  'Dynamic that invites, besides, to put in perspective the social and cultural mechanisms of reception of the state in the local world, through the conceptual readaptation of the historiographical interpretations on the formation of the national state in the Ecuadorian decimononic.',
#  'The same effect is also seen on consumption.',
#  'The tooth could be contaminated because it is exposed to a large amount of bacteria in the oral cavity, although the dental pulp is surrounded by hard dental tissues enamel, dentin, and cement in the oral cavity.',
#  'Infections caused by Candida in this range of CMI will likely respond to treatment.',
#  ...]

# %%
# # =============================================================================
# # STEP 10: RUN RAG TRANSLATION & EVALUATION
# # =============================================================================
# print("="*70)
# print("RAG TRANSLATION (Top 5 Examples)")
# print("="*70)

# rag_predictions = []

# for i, spanish_sent in enumerate(test_sources):
#     print(f"Translating {i+1}/{len(test_sources)}...", end=' ')
#     translation = translate_rag(spanish_sent, retriever)
#     rag_predictions.append(translation)
#     print("✓")

#     # Show first example
#     if i in range (0, len(test_sources)):
#         print(f"\nExample:")
#         print(f"  Source:     {spanish_sent}")
#         print(f"  RAG Output: {translation}")
#         print(f"  Reference:  {test_references[i]}")

# # Evaluate RAG
# rag_scores = evaluate_all_metrics(rag_predictions, test_references, test_sources, "RAG (Top 5)")

# %%
# =============================================================================
# STEP 11: COMPARE RESULTS
# =============================================================================
print("="*70)
print("FINAL COMPARISON: ICL vs RAG")
print("="*70)

comparison = pd.DataFrame({
    'Metric': ['BLEU', 'chrF', 'METEOR', 'COMET'],
    'ICL (Top 1)': [
        f"{icl_scores['bleu']:.2f}",
        f"{icl_scores['chrf']:.2f}",
        f"{icl_scores['meteor']:.4f}",
        f"{icl_scores['comet']:.4f}"
    ],
    'RAG (Top 5)': [
        f"{rag_scores['bleu']:.2f}",
        f"{rag_scores['chrf']:.2f}",
        f"{rag_scores['meteor']:.4f}",
        f"{rag_scores['comet']:.4f}"
    ],
    'Winner': [
        'ICL' if icl_scores['bleu'] > rag_scores['bleu'] else ' RAG',
        'ICL' if icl_scores['chrf'] > rag_scores['chrf'] else ' RAG',
        'ICL' if icl_scores['meteor'] > rag_scores['meteor'] else ' RAG',
        'ICL' if icl_scores['comet'] > rag_scores['comet'] else ' RAG'
    ]
})

print("\n")
print(comparison.to_string(index=False))
print("\n")

# Show sentence-level comparison for first 3
print("="*70)
print("SENTENCE-LEVEL COMPARISON")
print("="*70)

for i in range(0, len(test_sources)):
    print(f"\n{'─'*70}")
    print(f"Sentence {i+1}")
    print(f"{'─'*70}")
    print(f"Source:    {test_sources[i]}")
    print(f"Reference: {test_references[i]}")
    print(f"ICL:       {icl_predictions[i]}")
    print(f"RAG:       {rag_predictions[i]}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Sentence 4377
# ──────────────────────────────────────────────────────────────────────
# Source:    Trastornos del sistema inmunológico Poco frecuentes - Urticaria, rash Muy raros – Reacciones anafilácticas Los síntomas de hipersensibilidad generalizada pueden incluir rash cutáneo generalizado, escozor, sudor, trastornos gastrointestinales, edema angioneurótico, dificultad en la respiración, palpitaciones, hipotensión y mareo/ pérdida de consciencia.
# Reference: 33 Immune system disorders Uncommon - Urticaria, rash Very rare - Anaphylactic reactions Symptoms of generalised hypersensitivity may include generalised skin rash, itching, sweating, gastrointestinal upset, angioneurotic oedema, difficulties in breathing, palpitation, reduction in blood pressure and fainting/ loss of consciousness.
# ICL:       Immunological disorders Rare - Urticaria, rash Very rare – Anaphylactic reactions The symptoms of generalised hypersensitivity may include generalised skin rash, itching, sweating, gastrointestinal disturbances, angioneurotic oedema, respiratory difficulty, palpitations, hypotension and dizziness/loss of consciousness.
# RAG:       Immune system disorders Uncommon - Urticaria, rash Rare - Anaphylactic reactions Generalized hypersensitivity symptoms may include generalised skin rash, itching, sweating, gastrointestinal disturbances, angioneurotic oedema, respiratory difficulty, palpitations, hypotension, and dizziness/fainting.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4378
# ──────────────────────────────────────────────────────────────────────
# Source:    Los datos farmacocinéticos procedentes de mujeres embarazadas infectadas por VIH que recibieron REYATAZ cápsulas con ritonavir se presentan en la Tabla 9.
# Reference: The pharmacokinetic data from HIV-infected pregnant women receiving REYATAZ capsules with ritonavir are presented in Table 9.
# ICL:       Pharmacokinetic data from HIV-infected pregnant women who received REYATAZ capsules with ritonavir are presented in Table 9.
# RAG:       Pharmacokinetic data from HIV-infected pregnant women who received REYATAZ capsules with ritonavir are presented in Table 9.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4379
# ──────────────────────────────────────────────────────────────────────
# Source:    Estudios retrospectivos son debilitados a causa de su riesgo de sesgo de selección.
# Reference: Retrospective studies are weakened because of their risk of selection bias.
# ICL:       Retrospective studies are weakened due to their risk of selection bias.
# RAG:       Retrospective studies are weakened due to their risk of selection bias.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4380
# ──────────────────────────────────────────────────────────────────────
# Source:    El control del plagio también forma parte de la agenda de RGE, con previsión de adopción de un sistema para detección de plagio para el año de 2016, conforme necesidad identificada por la CED y orientación del SciELO para los periódicos en el indexados.
# Reference: Control of plagiarism is also on RGE’s agenda, where there are plans to adopt a plagiarism detection system in 2016, in response to the need identified by CED and guidelines from SciELO for journals indexed in it.
# ICL:       Plagiarism control also forms part of RGE's agenda, with a plan for the adoption of a plagiarism detection system for the year 2016, in accordance with the identified need by CED and SciELO's guidelines for indexed journals.
# RAG:       Plagiarism control is also part of the RGE agenda, with provision for the adoption of a plagiarism detection system for the year 2016, in accordance with the identified need by the CED and SciELO guidance for indexed journals.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4381
# ──────────────────────────────────────────────────────────────────────
# Source:    Las nuevas medidas prohibieron los deportes al aire libre y las carreras, excepto las que son individualmente y si se hacen muy cerca de la residencia de uno.
# Reference: The new measures banned open-air sports and running, except individually and in close proximity of one's residence.
# ICL:       New measures prohibited outdoor sports and races, except those that are done individually and if they are very close to one's residence.
# RAG:       Outdoor sports and races, except those done individually and near one's residence, were prohibited by the new measures.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4382
# ──────────────────────────────────────────────────────────────────────
# Source:    Sin embargo, desde perspectivas didácticas de orientación constructivista, se plantea una visión más integrada de las actividades, como unidades del proceso metodológico cuyo sentido es facilitar a los estudiantes la construcción del conocimiento .
# Reference: However, from the didactic perspectives of a constructivist approach, activities are seen to be an integral part of the methodological process whose purpose is to help students in the construction of knowledge .
# ICL:       However, from a constructivist pedagogical perspective, a more integrated vision of activities is presented as units of the methodological process whose purpose is to facilitate students' construction of knowledge.
# RAG:       However, from constructivist teaching perspectives, a more integrated view of activities is presented, as units of the methodological process whose purpose is to facilitate students' construction of knowledge.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4383
# ──────────────────────────────────────────────────────────────────────
# Source:    ¿Quiénes podían comprar esclavos en Buenos Aires?
# Reference: Who could buy slaves in Buenos Aires?
# ICL:       Who could buy slaves in Buenos Aires?
# RAG:       Who could buy slaves in Buenos Aires?
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4384
# ──────────────────────────────────────────────────────────────────────
# Source:    57,7 (45/78) 43,3; 72,1
# Reference: 57.7 (45/78) 43.3, 72.1
# ICL:       57.7 (45/78) 43.3, 72.1
# RAG:       57.7 (45/78) 43.3; 72.1
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4385
# ──────────────────────────────────────────────────────────────────────
# Source:    Los resultados muestran que la mayoría de ellas fue producida en las áreas/campos asistencial 171 o 38,1% y de la organización 164 o 36,6%, seguidas del área profesional 86 o 19,1%.
# Reference: Their results show that most studies were produced in the care 171 or 38.1% and organizational area/field 164 or 36.6%, followed by the professional area 86 or 19.1%.
# ICL:       The results show that the majority of them was produced in the assistance areas/fields 171 or 38.1% and of the organization 164 or 36.6%, followed by the professional area 86 or 19.1%.
# RAG:       The results show that the majority were produced in the clinical/field 171 or 38.1% and organizational 164 or 36.6%, followed by the professional area 86 or 19.1%.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4386
# ──────────────────────────────────────────────────────────────────────
# Source:    ¿Para qué se utiliza Myocet?
# Reference: What is Myocet used for?
# ICL:       What Myocet is used for.
# RAG:       What is Myocet used for?
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4387
# ──────────────────────────────────────────────────────────────────────
# Source:    La violencia puede predominar sobre la política, tal como nos muestran los trabajos de García sobre Colombia y de Trejo y Ley sobre México.
# Reference: Second, the papers by García on Colombia and Trejo and Ley on Mexico show us that violence may trump politics.
# ICL:       Violence may predominate over politics, as the work of García on Colombia and Trejo and Ley on Mexico shows.
# RAG:       Violence can predominate over politics, as shown by García's work on Colombia and Trejo and Ley's work on Mexico.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4388
# ──────────────────────────────────────────────────────────────────────
# Source:    El diseño de la mezcla asfáltica fue realizado aplicando la metodología Marshall, el cual fue suministrado por las empresas.
# Reference: Design of asphaltic mixture was developed by applying Marshall Methodology, which was provided by the companies.
# ICL:       The asphalt mixture design was carried out using the Marshall method, which was provided by the companies.
# RAG:       The asphalt mixture design was performed using the Marshall method, which was provided by the companies.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4389
# ──────────────────────────────────────────────────────────────────────
# Source:    No conduzca ni maneje herramientas o máquinas hasta que sepa cómo le afecta el tratamiento con YENTREVE.
# Reference: Do not drive or use any tools or machines until you know how YENTREVE affects you.
# ICL:       Do not drive or operate tools or machines until you know how the YENTREVE treatment affects you.
# RAG:       Do not drive or use any tools or machines until you know how this YENTREVE treatment affects you.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4390
# ──────────────────────────────────────────────────────────────────────
# Source:    La dosis diaria es de 30 mg de principios combinados por kg de peso vivo administrados por vía oral.
# Reference: The daily dose is 30mg of combined actives per kg bodyweight by oral administration.
# ICL:       The daily dose is 30 mg of combined principles per kg of body weight administered orally.
# RAG:       The daily dose is 30 mg of combined principles per kg of body weight administered orally.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4391
# ──────────────────────────────────────────────────────────────────────
# Source:    En el dolor neuropático, Duloxetina Lilly se ha comparado con placebo en dos estudios de 12 semanas en los que participaron 809 pacientes diabéticos adultos.
# Reference: For neuropathic pain, Duloxetine Lilly has been compared with placebo in two 12-week studies in 809 diabetic adults.
# ICL:       In neuropathic pain, Duloxetina Lilly has been compared with placebo in two 12-week studies involving 809 adult diabetic patients.
# RAG:       In diabetic neuropathic pain, Duloxetine Lilly was compared with placebo in two 12-week studies involving 809 adult diabetic patients.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4392
# ──────────────────────────────────────────────────────────────────────
# Source:    Echando una ojeada rápida al censo indígena, se verá que solo en un departamento, el de Imperial, forman los Araucanos la mitad de la población i que no hay en la República las más pequeña porción de territorio que esté poblada exclusivamente por ellos.
# Reference: A quick glance at the indigenous census reveals that only in one department, Imperial, do the Araucanos make up half of the population and that not even the smallest portion of territory in the Republic is populated exclusively by them.
# ICL:       A quick glance at the indigenous census will show that in only one department, Imperial, the Araucanos make up half of the population and there is no smaller portion of territory in the Republic that is exclusively inhabited by them.
# RAG:       A quick glance at the indigenous census will show that only in one department, Imperial, the Araucanos make up half of the population, and there is no region in the Republic with a smaller portion of territory exclusively inhabited by them.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4393
# ──────────────────────────────────────────────────────────────────────
# Source:    No tire ningún medicamento a través de su fregadero, inodoro o en la basura doméstica.
# Reference: Do not throw away any medicines via your sink, toilet or in your household waste.
# ICL:       Do not dispose of any medication through your sink, toilet or household trash.
# RAG:       Do not dispose of any medication through your sink, toilet or household waste.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4394
# ──────────────────────────────────────────────────────────────────────
# Source:    EMEND es un antagonista del receptor neurocinina 1 (NK1).
# Reference: EMEND is a neurokinin 1 (NK1) receptor antagonist.
# ICL:       EMEND is a neurokinin 1 (NK1) receptor antagonist.
# RAG:       EMEND is a neurokinin 1 receptor antagonist (NK1).
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4395
# ──────────────────────────────────────────────────────────────────────
# Source:    En el primero, Juan Carlos Muñoz-Mora analiza las implicaciones microeconómicas del conflicto armado rural en la decisión productiva de los campesinos cafeteros colombianos, utilizando una base de datos única con información por finca cafetera para 2006.
# Reference: In the first one, Juan Carlos Muñoz-Mora analyzes the microeconomic implications of rural conflict in the production decisions of Colombian coffee growers, using a unique database with information on coffee farms in 2006.
# ICL:       In the first, Juan Carlos Muñoz-Mora analyzes the microeconomic implications of the rural armed conflict on the productive decision of Colombian coffee farmers, using a unique database with information by coffee farm for 2006.
# RAG:       In the first, Juan Carlos Muñoz-Mora analyzes the microeconomic implications of the rural armed conflict on the productive decision of Colombian coffee farmers, using a unique database with information by coffee farm for 2006.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4396
# ──────────────────────────────────────────────────────────────────────
# Source:    1 vial + 1 jeringa precargada sin aguja
# Reference: 1 vial + 1 pre-filled syringe without needle
# ICL:       1 vial + 1 pre-filled syringe without needle
# RAG:       1 pre-filled syringe without needle
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4397
# ──────────────────────────────────────────────────────────────────────
# Source:    Blister (Alu/ PP) Blister (Alu/ PP) Blister (Alu/ PP)
# Reference: blister (alu/ PP) blister (alu/ PP) blister (alu/ PP)
# ICL:       blister (alu/ PP) blister (alu/ PP) blister (alu/ PP)
# RAG:       blister (alu/ PP) blister (alu/ PP) blister (alu/ PP)
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4398
# ──────────────────────────────────────────────────────────────────────
# Source:    No se han realizado ensayos clínicos en niños y adolescentes  75 años.
# Reference: No clinical studies have been performed in children and adolescents  75 years of age.
# ICL:       Clinical trials have not been conducted in children and adolescents 75 years old.
# RAG:       No clinical trials have been performed in children and adolescents 75 years.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4399
# ──────────────────────────────────────────────────────────────────────
# Source:    En este estudio no se contó con la información suficiente para analizar a profundidad la situación del marco legal en cada país.
# Reference: In this study there was not enough information to carry out an in-depth analysis of the legal framework status in each country.
# ICL:       In this study, there was not enough information to thoroughly analyze the legal framework situation in each country.
# RAG:       In this study, there was not enough information to analyze in depth the situation of the legal framework in each country.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4400
# ──────────────────────────────────────────────────────────────────────
# Source:    Se realizó un análisis de farmacocinética poblacional de formoterol basado en los datos recopilados en un total de 437 pacientes con EPOC.
# Reference: A population pharmacokinetic analysis of formoterol was performed based on data collected in a total of 437 subjects with COPD.
# ICL:       A population pharmacokinetic analysis of formoterol based on data collected from a total of 437 patients with COPD.
# RAG:       A population pharmacokinetic analysis of formoterol was performed based on data collected from a total of 437 patients with COPD.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4401
# ──────────────────────────────────────────────────────────────────────
# Source:    91 deberá tener precaución cuando se añada Pegasys y ribavirina al tratamiento con TARGA (ver Ficha Técnica de ribavirina).
# Reference: Caution should therefore be exercised when adding Pegasys and ribavirin to HAART therapy (see ribavirin SPC).
# ICL:       Should exercise caution when adding Pegasys and ribavirin to TARGA therapy (see Ribavirin Technical Data Sheet).
# RAG:       Patients should exercise caution when adding Pegasys and ribavirin to TARGA therapy (see ribavirin SPC).
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4402
# ──────────────────────────────────────────────────────────────────────
# Source:    Si se producen disminuciones inexplicadas de los niveles de bicarbonato sérico a menos de 20 mmol/l, la dosis deberá disminuirse en un 50 % en el siguiente ciclo.
# Reference: If unexplained reductions in serum bicarbonate levels to less than 20 mmol/l occur, the dose should be reduced by 50 % on the next cycle.
# ICL:       If unexplained decreases in serum bicarbonate levels are less than 20 mmol/l, the dose should be reduced by 50% in the next cycle.
# RAG:       If unexplained decreases in serum bicarbonate levels are less than 20 mmol/l, the dose must be reduced by 50% in the next cycle.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4403
# ──────────────────────────────────────────────────────────────────────
# Source:    Los puntos de corte adoptados para hombres fueron: 0 27 - FPM 27 - FPM<=14Kgf.
# Reference: The cutoff points for men adopted were: 0 27 - MGF 27 - MGF<=14Kgf.
# ICL:       The cut-off points adopted for men were: 0 27 - FPM 27 - FPM<=14Kgf.
# RAG:       The cut-off points adopted for men were: 0 27 - FPM 27 - FPM<=14Kgf.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4404
# ──────────────────────────────────────────────────────────────────────
# Source:    InformaciÃ³n sobre el material de origen de HyQvia La inmunoglobulina humana normal 10% de HyQvia y la albÃºmina sÃ©rica humana (un componente de la hialuronidasa humana recombinante) se producen a partir del plasma humano (la parte lÃ­quida de la sangre).
# Reference: The human normal immunoglobulin 10% of HyQvia and human serum albumin (an ingredient of the recombinant human hyaluronidase) are made from human plasma (the liquid part of blood).
# ICL:       Information about the source material of HyQvia Human normal immunoglobulin 10% of HyQvia and human serum albumin (a component of recombinant human hyaluronidase) are produced from human plasma (the liquid part of blood).
# RAG:       Information about the material of origin of HyQvia Human normal immunoglobulin, 10% of HyQvia and human serum albumin (a component of recombinant human hyaluronidase) are produced from human plasma (the liquid part of blood).
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4405
# ──────────────────────────────────────────────────────────────────────
# Source:    ad EU/ 1/ 02/ 232/ 001
# Reference: is EU/ 1/ 02/ 232/ 001 Velosulin
# ICL:       is EU/ 1/ 02/ 232/ 001
# RAG:       ad EU/ 1/ 02/ 232/ 001
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4406
# ──────────────────────────────────────────────────────────────────────
# Source:    50 mg cápsulas duras EFG Pregabalina
# Reference: 50 mg hard capsules Pregabalin
# ICL:       50 mg hard capsules Pregabalin
# RAG:       50 mg hard capsules Pregabalin
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4407
# ──────────────────────────────────────────────────────────────────────
# Source:    Embarcaciones [barcas y barcos]
# Reference: Vessels [boats and ships]
# ICL:       Vessels [boats and ships]
# RAG:       Watercraft [boats and ships]
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4408
# ──────────────────────────────────────────────────────────────────────
# Source:    Confirmando esta línea de razonamiento, así como los resultados obtenidos en el perfil de la pobreza, el cuadro 2 muestra que la probabilidad de ser pobre es mayor para los hogares cuyos jefes de familia se desempeñan en ocupaciones que requieren estándares bajos de capital humano como en el caso de los obreros agrícolas, ambulantes o la mano de obra no calificada.
# Reference: Confirming this line of reasoning, as well as the results obtained in the poverty profile, Table 2 shows that the probability of being poor is higher for households whose head works in occupations which require a low stock of human capital such as agricultural worker, ambulatory worker or unskilled manufacturing worker.
# ICL:       Confirming this line of reasoning, as well as the results obtained in the poverty profile, table 2 shows that the probability of being poor is higher for households whose heads of household engage in occupations that require low standards of human capital, such as agricultural workers, street vendors or unskilled labor.
# RAG:       Confirming this line of reasoning, as well as the results obtained in the poverty profile, table 2 shows that the probability of being poor is higher for households whose heads of household are engaged in occupations that require low standards of human capital such as in the case of agricultural workers, street vendors or unskilled labor.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4409
# ──────────────────────────────────────────────────────────────────────
# Source:    Carmelosa de calcio Hiprolosa Lactosa monohidrato Estearato de magnesio
# Reference: Carmellose calcium Hyprolose Lactose monohydrate Magnesium stearate
# ICL:       Calcium carboxymethylcellulose Hyprolose Lactose monohydrate Magnesium stearate
# RAG:       Calcium carmelose Hyprolose Lactose monohydrate Magnesium stearate
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4410
# ──────────────────────────────────────────────────────────────────────
# Source:    La Tabla I presenta el resultado de los promedios de los porcentajes de los valores previstos de la CVF, VEF1 y VEF1/CVF, y el valor de p del análisis de variancia en las tres posiciones estudiadas.
# Reference: Table I shows the results of mean percentage of predicted values for FVC, FEV1, and FEV1/FVC, and the value of p on analysis of variance on all three positions.
# ICL:       Table I presents the results of the means of the percentages of the predicted values of CVF, VEF1, and VEF1/CVF, and the p-value of the variance analysis in the three studied positions.
# RAG:       Table I presents the results of the means of the percentages of the predicted values of CVF, VEF1 and VEF1/CVF, and the p-value of the analysis of variance in the three studied positions.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4411
# ──────────────────────────────────────────────────────────────────────
# Source:    • sensación de omisión de un latido cardiaco, latido cardiaco inusualmente lento
# Reference: • sensation of a missed heart beat, unusually slow heart beat
# ICL:       • feeling of a missed heart beat, abnormally slow heart beat
# RAG:       • feeling of a missed heart beat, abnormally slow heart beat
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4412
# ──────────────────────────────────────────────────────────────────────
# Source:    Una vez abierto el envase, utilizar antes de 10 horas
# Reference: EXPIRY DATE EXP {month/year} Once broached, use within 10 hours.
# ICL:       Once opened the container, use within 10 hours.
# RAG:       Once broached, use within 10 hours.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4413
# ──────────────────────────────────────────────────────────────────────
# Source:    Mialgia, artralgia
# Reference: Myalgia; arthralgia
# ICL:       Arthralgia
# RAG:       • Myalgia, arthralgia
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4414
# ──────────────────────────────────────────────────────────────────────
# Source:    Se comprende que el aprendizaje representa una readaptación de la estructura cognitiva del sujeto, a partir de un esquema asimilativo que envuelve: repetición, generalización y diferenciación-reconocimiento.
# Reference: Learning represents a re-adaptation of the cognitive structure of individuals, based on an assimilative scheme that involves: repetition, generalization, and differentiation-recognition.
# ICL:       It is understood that learning represents a reorganization of the cognitive structure of the subject, from an assimilative scheme that involves: repetition, generalization, and differentiation-recognition.
# RAG:       It is understood that learning represents a reorganization of the cognitive structure of the subject, from an assimilative scheme that involves: repetition, generalization, and differentiation-recognition.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4415
# ──────────────────────────────────────────────────────────────────────
# Source:    Se ha recomendado una convulsión motora con más de 25 segundos de duración para garantizar la adecuación clínica del tratamiento, y convulsiones cortas se consideran previsoras de un resultado negativo .
# Reference: Motor seizure duration greater than 25 seconds has been recommended to ensure clinical adequacy of treatment, and short seizures are considered negative predictors of outcome .
# ICL:       Seizures lasting more than 25 seconds have been recommended to ensure clinical appropriateness of treatment, and short seizures are considered precursors to a negative outcome.
# RAG:       Motor seizure lasting more than 25 seconds has been recommended to ensure clinical appropriateness of treatment, and short seizures are considered precursors to a negative outcome.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4416
# ──────────────────────────────────────────────────────────────────────
# Source:    Si padece una enfermedad hepática o cardíaca, o se ha sometido recientemente a una intervención quirúrgica, existe un mayor riesgo de complicaciones relacionadas con la coagulación.
# Reference: If you suffer from a liver or cardiac disease or if you have recently had surgery, there is an increased risk for coagulation complications.
# ICL:       If you have liver or heart disease, or have recently undergone surgery, there is a higher risk of complications related to coagulation.
# RAG:       If you suffer from liver or heart disease, or if you have recently undergone surgical intervention, there is a higher risk of complications related to coagulation.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4417
# ──────────────────────────────────────────────────────────────────────
# Source:    Al analizar la morbilidad y la mortalidad postoperatorias, la AG se asoció con un aumento significativo de las complicaciones respiratorias reintubación, neumonía y la necesidad de traqueostomía durante los primeros 30 días del postoperatorio AG=23 [79,2%] vs. AP=3 [14,3%]; p<0,001].
# Reference: When postoperative morbidity and mortality were reviewed, GA was associated with a significant increase in respiratory complications re-intubation, pneumonia and need for tracheostomy during the first 30 postoperative days [GA=23 79.2% vs. PA=3 14.3%; p<0.001].
# ICL:       Analyzing postoperative morbidity and mortality, AG was associated with a significant increase in respiratory complications reintubation, pneumonia, and the need for tracheostomy during the first 30 days of postoperative AG=23 [79.2%] vs. AP=3 [14.3%]; p<0.001].
# RAG:       Analyzing postoperative morbidity and mortality, AG was associated with a significant increase in respiratory complications reintubation, pneumonia, and the need for tracheostomy during the first 30 days of postoperative AG=23 [79.2%] vs. AP=3 [14.3%]; p < 0.001.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4418
# ──────────────────────────────────────────────────────────────────────
# Source:    116 Preparación de NovoMix 50 FlexPen
# Reference: Preparing your NovoMix 50 FlexPen
# ICL:       NovoMix 50 FlexPen preparation
# RAG:       Preparation of NovoMix 50 FlexPen
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4419
# ──────────────────────────────────────────────────────────────────────
# Source:    Es cierto que, en algunos casos, puede ser mejor para la tripulación o los pasajeros permanecer a bordo del buque, siempre que se apliquen las medidas sanitarias adecuadas.
# Reference: In some cases, crew and/or passengers may indeed be better off staying on board the ship, provided that the appropriate sanitary measures are in place.
# ICL:       It is true that, in some cases, it may be better for the crew or passengers to remain on board the ship, provided that the necessary health measures are applied.
# RAG:       It is true that, in some cases, it may be better for the crew or passengers to remain on board the ship, provided that the necessary health measures are applied.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4420
# ──────────────────────────────────────────────────────────────────────
# Source:    Al total, 930 participantes de ambos sexos y con 30 años o superior fueron entrevistados, residentes en el área urbana de Ribeirão Preto en 2006.
# Reference: In total, 930 participants were interviewed, male and female, aged 30 years or older, living in urban Ribeirão Preto in 2006.
# ICL:       A total of 930 participants of both sexes aged 30 years or older were interviewed, residents in the urban area of Ribeirão Preto in 2006.
# RAG:       A total of 930 participants of both sexes aged 30 or older were interviewed, residents in the urban area of Ribeirão Preto in 2006.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4421
# ──────────────────────────────────────────────────────────────────────
# Source:    Recipientes de vidrio huecos para medida
# Reference: Hollow glass containers for measuring
# ICL:       Empty glass containers for measurement
# RAG:       Empty glass containers for measurement
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4422
# ──────────────────────────────────────────────────────────────────────
# Source:    Recientemente, en 2005, Yoshihara y cols. están de acuerdo en que un programa dental preventivo continuo, sistemático e individualizado, con métodos disponibles puede suprimir el progreso de la enfermedad periodontal en sujetos con SD.
# Reference: In 2005, Dr. Yoshinara et al. agreed on stating that a preventive, continuous, systematic and individualized dental program with available methods, can suppress the progress of periodontal disease in DS subjects.
# ICL:       Recently, in 2005, Yoshihara et al. agree that a continuous, systematic, and individualized preventive dental program, with available methods, can suppress the progression of periodontal disease in subjects with SD.
# RAG:       Recently, in 2005, Yoshihara et al. agree that a continuous, systematic, and individualized preventive dental program, with available methods, can suppress the progression of periodontal disease in subjects with SD.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4423
# ──────────────────────────────────────────────────────────────────────
# Source:    Esto es importante en personas con miastenia gravis (enfermedad rara del sistema nervioso)
# Reference: This is important in people with myasthenia gravis (a rare disease of the nervous system).
# ICL:       This is important in people with myasthenia gravis (rare nervous system disease)
# RAG:       This is important in people with myasthenia gravis (rare nervous system disease)
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4424
# ──────────────────────────────────────────────────────────────────────
# Source:    El CHMP concluyó que, de conformidad con los requisitos de la UE, Efavirenz Teva ha demostrado tener una calidad comparable y ser bioequivalente a Sustiva.
# Reference: The CHMP concluded that, in accordance with EU requirements, Efavirenz Teva has been shown to have comparable quality and to be bioequivalent to Sustiva.
# ICL:       The CHMP concluded that, in accordance with EU requirements, Efavirenz Teva has demonstrated comparable quality and bioequivalence to Sustiva.
# RAG:       The Agency's Committee for Medicinal Products for Human Use (CHMP) concluded that, in accordance with EU requirements, Efavirenz Teva has been shown to have comparable quality and to be bioequivalent to Sustiva.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4425
# ──────────────────────────────────────────────────────────────────────
# Source:    La formulación final tras el marcaje radiactivo contiene 2,08 mg de ibritumomab tiuxetan en un volumen total de 10 ml
# Reference: The final formulation after radiolabeling contains 2.08 mg ibritumomab tiuxetan in a total volume of 10 ml.
# ICL:       The final formulation after radioactive labeling contains 2.08 mg of ibritumomab tiuxetan in a total volume of 10 ml
# RAG:       The final formulation after radioactive labeling contains 2.08 mg of ibritumomab tiuxetan in a total volume of 10 ml.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4426
# ──────────────────────────────────────────────────────────────────────
# Source:    De ese panorama emergen las cuestiones bioéticas que posibilitan percibir que el hombre contemporáneo no está habituado a la muerte o a morir.
# Reference: From this panorama emerge the bioethical questions that make it possible to perceive that contemporary man is not accustomed to death and dying.
# ICL:       From this panorama emerge the bioethical issues that enable one to perceive that the contemporary man is not accustomed to death or dying.
# RAG:       From this panorama emerge the bioethical issues that allow us to perceive that the contemporary human being is not accustomed to death or dying.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4427
# ──────────────────────────────────────────────────────────────────────
# Source:    Inmunización pasiva de los lechones vía calostro, después de inmunización activa de las cerdas jóvenes y reproductoras, para reducir las lesiones en los tejidos linfoides asociadas a la infección por PCV2, y como ayuda para reducir la mortalidad ligada al PCV2.
# Reference: Passive immunisation of piglets via the colostrum, after active immunisation of sows and gilts, to reduce lesions in lymphoid tissues associated with PCV2 infection and as an aid to reduce PCV2- linked mortality.
# ICL:       Passive immunisation of piglets via colostrum, after active immunisation of young and breeding sows, to reduce lesions in lymphoid tissues associated with PCV2 infection, and as aid to reduce mortality linked to PCV2.
# RAG:       Passive immunisation of piglets via colostrum, after active immunisation of young and breeding sows, to reduce lesions in lymphoid tissues associated with PCV2 infection, and as an aid to reduce mortality linked to PCV2.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4428
# ──────────────────────────────────────────────────────────────────────
# Source:    Deutschland Sanofi Pasteur MSD GmbH Tel: +49 6224.594.0
# Reference: 33 Deutschland Sanofi Pasteur MSD GmbH Tel: +49 6224.594.0
# ICL:       Germany Sanofi Pasteur MSD GmbH Tel: +49 6224.594.0
# RAG:       Germany Sanofi Pasteur MSD GmbH Tel: +49 6224 594 0
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4429
# ──────────────────────────────────────────────────────────────────────
# Source:    La diferencia entre grupos en el aumento de la media de mínimos cuadrados en el porcentaje de DSR para el asma fue estadísticamente significativa (de -2,8 con un IC del 95% de -4,7, -0,9), pero dentro del límite predefinido para ser clínicamente no inferior.
# Reference: The between group difference in LS mean increase in the percentage of asthma RFDs was statistically significant (- 2.8 with a 95% CI of -4.7, -0.9), but within the limit pre-defined to be clinically not inferior.
# ICL:       The difference between groups in the increase in mean square root of the percentage of DSR for asthma was statistically significant (by -2.8 with a 95% CI of -4.7, -0.9), but within the predefined limit to be clinically not inferior.
# RAG:       The between-group difference in the increase in mean squared predicted probabilities for asthma DSR was statistically significant (-2.8 with a 95% CI of -4.7, -0.9), but within the pre-specified boundary for being clinically non-inferior.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4430
# ──────────────────────────────────────────────────────────────────────
# Source:    La pioglitazona y el metabolito M III contribuyen de una forma similar a la eficacia, si se tiene en cuenta su actividad, concentración y unión a proteínas.
# Reference: When activity, concentrations and protein binding are taken into account, pioglitazone and metabolite M-III contribute equally to efficacy.
# ICL:       Pioglitazone and its metabolite M III contribute similarly to efficacy, if their activity, concentration and protein binding are taken into account.
# RAG:       Pioglitazone and metabolite M III contribute similarly to efficacy, if their activity, concentration and protein binding are taken into account.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4431
# ──────────────────────────────────────────────────────────────────────
# Source:    EE. UU (64%) Suiza (16%) UE (15%) Canadá (3%) Australia (2%)
# Reference: USA (64%) Switzerland (16%) EU (15%) Canada (3%) Australia (2%)
# ICL:       United States (64%) Switzerland (16%) EU (15%) Canada (3%) Australia (2%)
# RAG:       United States (64%) Switzerland (16%) EU (15%) Canada (3%) Australia (2%)
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4432
# ──────────────────────────────────────────────────────────────────────
# Source:    No se ha establecido la necesidad de una dosis de recuerdo en individuos sanos que han recibido la serie primaria de vacunación completa; sin embargo, actualmente algunos programas oficiales de vacunación recomiendan una dosis de recuerdo que debe ser respetada.
# Reference: The need for a booster dose of hepatitis B vaccine in healthy individuals who have received a full primary vaccination course has not been established; however some official vaccination programmes currently include a recommendation for a booster dose of hepatitis B vaccine and these should be respected.
# ICL:       No need has been established for a booster dose in healthy individuals who have received a complete primary vaccination series; however, some official vaccination programs currently recommend a booster dose that should be respected.
# RAG:       It is not established whether healthy individuals who have received a complete primary vaccination series will require a booster dose; however, some official vaccination programmes currently recommend a booster dose which should be respected.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4433
# ──────────────────────────────────────────────────────────────────────
# Source:    Saque el prospecto de la bandeja.
# Reference: Take the leaflet from the tray.
# ICL:       Take out the insert from the tray.
# RAG:       Take the insert out of the tray.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4434
# ──────────────────────────────────────────────────────────────────────
# Source:    El ensayo aleatorizado prospectivo (UKPDS) ha establecido el beneficio a largo plazo del control intensivo de la glucosa en sangre en la diabetes tipo 2.
# Reference: The prospective randomised (UKPDS) study has established the long-term benefit of intensive blood glucose control in type 2 diabetes.
# ICL:       The prospective randomised UKPDS study has established the long-term benefit of intensive blood glucose control in type 2 diabetes.
# RAG:       The prospective randomised UKPDS study has established the long-term benefit of intensive blood glucose control in type 2 diabetes.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4435
# ──────────────────────────────────────────────────────────────────────
# Source:    En el Resumen de las Características del Producto (incluido en el EPAR) puede encontrarse la lista de hongos contra los cuales ECALTA es activo.
# Reference: The list of fungi against which ECALTA is active can be found in the Summary of Product Characteristics (also part of the EPAR).
# ICL:       In the Summary of Product Characteristics (included in the EPAR) can be found the list of fungi against which ECALTA is active.
# RAG:       For more information on the use of ECALTA, see the summary of product characteristics (also part of the EPAR) which includes the list of fungi against which ECALTA is active.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4436
# ──────────────────────────────────────────────────────────────────────
# Source:    68 PROSPECTO:
# Reference: 63 PACKAGE LEAFLET:
# ICL:       PACKAGE LEAFLET:
# RAG:       69 PACKAGE LEAFLET:
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4437
# ──────────────────────────────────────────────────────────────────────
# Source:    Triptosa y NZ-aminas:
# Reference: Tryptose and NZ-Amines:
# ICL:       Triptose and NZ-aminase:
# RAG:       Triptose and NZ-aminas:
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4438
# ──────────────────────────────────────────────────────────────────────
# Source:    La Unión también apoyará el desarrollo de tecnologías facilitadoras esenciales que revisten una importancia estratégica para el futuro industrial de Europa.
# Reference: The EU will also support the development of key enabling technologies that are strategically important for Europe's industrial future.
# ICL:       The Union will also support the development of essential enabling technologies that are of strategic importance for Europe's future industrial development.
# RAG:       The EU will also support the development of key enabling technologies that are strategically important for Europe's future industrial development.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4439
# ──────────────────────────────────────────────────────────────────────
# Source:    Por un lado, se ha presentado un panorama de la situación del conflicto armado y la violencia política en Colombia, pretendiendo mostrar que es una situación lo suficientemente contundente como para concitar el interés de una profesión como la enfermería.
# Reference: On the one side, we have presented a panorama of the situation of the armed conflict and political violence in Colombia, seeking to show that it is a sufficiently convincing situation to incite interest from a profession like nursing.
# ICL:       On one hand, a panorama of the situation of the armed conflict and political violence in Colombia has been presented, aiming to show that it is a situation sufficiently forceful enough to arouse the interest of a profession such as nursing.
# RAG:       On the one hand, a panorama of the situation of the armed conflict and political violence in Colombia has been presented, aiming to show that it is a situation sufficiently compelling to attract the interest of a profession like nursing.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4440
# ──────────────────────────────────────────────────────────────────────
# Source:    El texto completo del EPAR de Zalasta puede encontrarse aquí.
# Reference: The full EPAR for Zalasta can be found here.
# ICL:       The full EPAR for Zalasta can be found here.
# RAG:       The full EPAR for Zalasta can be found here.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4441
# ──────────────────────────────────────────────────────────────────────
# Source:    Refiérase a la Tabla 1 para los ciclos 1 al 8 y a la Tabla 2 para los ciclos 9-16
# Reference: Please refer to Table 1 for cycles 1 to 8 and Table 2 for cycles 9-16.
# ICL:       Refer to Table 1 for cycles 1-8 and to Table 2 for cycles 9-16
# RAG:       Refer to Table 1 for cycles 1-8 and to Table 2 for cycles 9-16
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4442
# ──────────────────────────────────────────────────────────────────────
# Source:    El 58% de los pacientes tenían un índice de masa corporal (IMC) ≥ 30 kg/m2.
# Reference: 58% of patients had a body mass index (BMI) ≥ 30 kg/m2.
# ICL:       58% of the patients had a body mass index (BMI) ≥ 30 kg/m2.
# RAG:       Patients had a body mass index (BMI) ≥ 30 kg/m².
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4443
# ──────────────────────────────────────────────────────────────────────
# Source:    El fenómeno de las drogas: apreciaciones y creencias sobre uso de sustancias psicoactivas
# Reference: The drugs phenomenon: opinions and beliefs on the use of psychoactive substances
# ICL:       The drug phenomenon: views and beliefs about the use of psychoactive substances
# RAG:       The phenomenon of drugs: views and beliefs about the use of psychoactive substances
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4444
# ──────────────────────────────────────────────────────────────────────
# Source:    En consecuencia, el CHMP considera que la relación riesgo/beneficio de los productos que contienen candesartán, irbesartán, losartán, olmesartán y valsartán sigue siendo favorable, siempre que se cumplan las condiciones descritas anteriormente.
# Reference: The CHMP, as a consequence, considers that the benefit-risk balance of products containing candesartan, irbesartan, losartan, olmesartan, valsartan remains favourable subject to the conditions described above.
# ICL:       As a consequence, the CHMP considers that the benefit-risk balance of the products containing candesartan, irbesartan, losartan, olmesartan and valsartan remains favourable, provided the conditions described previously are met.
# RAG:       The CHMP, as a consequence, considers that the benefit-risk balance of candesartan, irbesartan, losartan, olmesartan and valsartan-containing products remains favourable, subject to the conditions described above.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4445
# ──────────────────────────────────────────────────────────────────────
# Source:    En la Figura 1d se observa que el módulo tangente a cortante Gtges igual al módulo de elasticidad al corte del acero Gantes de alcanzar el esfuerzo de fluencia a cortante ty.
# ...
# RAG:       For the first day, the double dose of the maintenance dose will be required.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4980
# ──────────────────────────────────────────────────────────────────────
# Source:    Es interesante notar la correlación observada entre el comportamiento I y las variables número de medicaciones y presión arterial sistólica: cuanto mayor es el número de medicaciones utilizadas y cuanto mayor es la presión arterial sistólica dos indicadores inmediatos para paciente de la gravedad de su enfermedad, más las mujeres relataron restringir la adición de sal en la preparación de los alimentos.
# Reference: It is interesting to note the correlation observed between Behavior I and the variables 'number of medications' and 'systolic blood pressure': the greater the number of medications used and the higher the systolic blood pressure two immediate indicators to the patient of the gravity of his illness, the more the women report restricting the addition of salt in the preparation of the foods.
# ICL:       It is interesting to note the observed correlation between Behavior I and the variables number of medications and systolic blood pressure: the more medications used and the higher the systolic blood pressure, two immediate indicators of the severity of the patient's disease, the more women reported restricting the addition of salt in the preparation of the foods.
# RAG:       It is interesting to note the observed correlation between behavior I and the variables number of medications and systolic blood pressure: the greater the number of medications used and the higher the systolic blood pressure, the two immediate indicators of the severity of the patient's disease, the more women reported restricting the addition of salt in the preparation of foods.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4981
# ──────────────────────────────────────────────────────────────────────
# Source:    Informe a su médico si usted está en período de lactancia.
# Reference: Tell your doctor if you are breast-feeding.
# ICL:       Persons who are breast-feeding should tell the doctor.
# RAG:       Persons who are breast-feeding should tell the doctor.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4982
# ──────────────────────────────────────────────────────────────────────
# Source:    Doctor en filosofía, titulado en microbiología farmacéutica por la Universidad de Strathclyde, Glasgow.
# Reference: Doctor of Philosophy, degree in pharmaceutical microbiology from the University of Strathclyde, Glasgow.
# ICL:       PhD in Philosophy, graduated in Pharmaceutical Microbiology by the University of Strathclyde, Glasgow.
# RAG:       PhD in philosophy, qualified in pharmaceutical microbiology from the University of Strathclyde, Glasgow.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4983
# ──────────────────────────────────────────────────────────────────────
# Source:    En un ensayo con leflunomida marcada radiactivamente (14C-leflunomida) en tres voluntarios sanos, no se detectó leflunomida inalterada en plasma, orina o heces.
# Reference: In a study with radiolabelled 14C-leflunomide in three healthy volunteers, no unchanged leflunomide was detected in plasma, urine or faeces.
# ICL:       In a study with radiolabeled leflunomide (14C-leflunomide) in three healthy volunteers, no unchanged leflunomide was detected in plasma, urine, or feces.
# RAG:       In a study with radiolabelled leflunomide (14C-leflunomide) in three healthy volunteers, no unchanged leflunomide was detected in plasma, urine, or feces.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4984
# ──────────────────────────────────────────────────────────────────────
# Source:    A-1150 Wien Austria
# Reference: Storchengasse 1 A-1150 Wien
# ICL:       A-1150 Vienna Austria
# RAG:       A-1150 Wien Austria
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4985
# ──────────────────────────────────────────────────────────────────────
# Source:    Desde un punto de vista ambiental, el uso de la escoria de alto horno produce beneficios como la disminución del uso de cemento y la utilización de un subproducto industrial; y desde un punto de vista económico, los costos del procesamiento de la escoria pueden ser en principio inferiores que los costos que se generan en la producción del cemento normal.
# Reference: From an environmental standpoint, the use of blast furnace slag provides benefits including recycling an industrial by-product and, from an economic standpoint, the costs of processing the slag may be lower than the cost of Portland cement production.
# ICL:       From an environmental point of view, the use of blast furnace slag has benefits such as a reduction in cement use and the utilization of an industrial byproduct; and from an economic point of view, the costs of processing the slag can be initially lower than the costs generated in the production of normal cement.
# RAG:       From an environmental point of view, the use of blast furnace slag produces benefits such as the reduction of cement use and the utilization of an industrial byproduct; and from an economic point of view, the costs of processing the slag can be initially lower than the costs generated in the production of normal cement.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4986
# ──────────────────────────────────────────────────────────────────────
# Source:    [5]​ A la mujer se le realizaron las pruebas pertinentes y fueron enviadas al Instituto Costarricense de Investigación y Enseñanza en Nutrición y Salud (Inciensa) para, ya sea, descartar o confirmar el caso.
# Reference: The pertinent tests were carried out on the woman and they were sent to the Costa Rican Institute of Research and Teaching in Nutrition and Health (Inciensa) to either rule out or confirm the case.
# ICL:       The relevant tests were performed on the woman and were sent to the Costa Rican Institute of Research and Teaching in Nutrition and Health (Inciensa) to either rule out or confirm the case.
# RAG:       The relevant tests were performed on the woman and were sent to the Costa Rican Institute of Research and Teaching in Nutrition and Health (Inciensa) to either rule out or confirm the case.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4987
# ──────────────────────────────────────────────────────────────────────
# Source:    Aunque al estado ECOG, la tasa de filtración glomerular (TFG) basal la albúmina, el peso corporal, y la insuficiencia hepática ligera tuvieron un efecto sobre el CL de nivolumab, el efecto no fue
# Reference: Although ECOG status, baseline glomerular filtration rate (GFR), albumin, body weight, and mild hepatic impairment had an effect on nivolumab CL, the effect was not clinically meaningful.
# ICL:       Although ECOG status, the baseline glomerular filtration rate (eGFR), albumin, body weight, and mild hepatic insufficiency had an effect on the CL of nivolumab, the effect was not significant.
# RAG:       Although ECOG status, baseline glomerular filtration rate (GFR), albumin, body weight, and mild hepatic impairment had an effect on the CL of nivolumab, the effect was not
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4988
# ──────────────────────────────────────────────────────────────────────
# Source:    Forma farmacéutica Especie de destino
# Reference: Strength Pharmaceutical form
# ICL:       Pharmaceutical Form Species of destination
# RAG:       Strength Pharmaceutical Form
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4989
# ──────────────────────────────────────────────────────────────────────
# Source:    La ARP no presentó diferencia estadística entre los grupos, como también, entre los momentos Tabla 6.
# Reference: Plasma renin activity did not differ significantly between both groups at any time point Table 6.
# ICL:       The ARP did not show a statistical difference between the groups, nor between the moments Table 6.
# RAG:       There was no statistically significant difference between the groups, as also between the moments Table 6.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4990
# ──────────────────────────────────────────────────────────────────────
# Source:    En 1998 y 1999, uno de los cambios principales en las actividades del sector consistirá en un aumento de la carga de trabajo relacionada con el mantenimiento de los productos ya autorizados.
# Reference: In 1998-99 one of the main changes in the pattern of activities for this sector will be the increased workload in relation to maintenance activities for products already authorised.
# ICL:       In 1998 and 1999, one of the main changes in sector activities will be an increase in workload related to the maintenance of already authorized products.
# RAG:       In 1998 and 1999, one of the main changes in sector activities will be an increase in workload related to the maintenance of already authorized products.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4991
# ──────────────────────────────────────────────────────────────────────
# Source:    Se administrará una dosis (0,5 ml) de la vacuna.
# Reference: A dose (0.5 ml) of the vaccine will be given.
# ICL:       A dose (0.5 ml) of the vaccine will be administered.
# RAG:       A dose (0.5 ml) of the vaccine will be administered.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4992
# ──────────────────────────────────────────────────────────────────────
# Source:    Los pacientes deberán ser estrechamente monitorizados para la detección de infecciones (incluyendo tuberculosis), antes, durante y después del tratamiento con Trudexa.
# Reference: Patients must be monitored closely for infections, including tuberculosis, before, during and after treatment with Trudexa.
# ICL:       Patients will need to be closely monitored for infections (including tuberculosis), before, during and after treatment with Trudexa.
# RAG:       Patients must therefore be monitored closely for infections, including tuberculosis, before, during and after treatment with Trudexa.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4993
# ──────────────────────────────────────────────────────────────────────
# Source:    Conservación de FIRMAGON 6.
# Reference: How to store FIRMAGON 6.
# ICL:       Storage of FIRMAGON 6.
# RAG:       How to store FIRMAGON 6.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4994
# ──────────────────────────────────────────────────────────────────────
# Source:    Máquinas para hacer cigarrillos
# Reference: Cigarette making machines
# ICL:       Cigarette-making machines
# RAG:       Cigarette-making machines
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4995
# ──────────────────────────────────────────────────────────────────────
# Source:    6.1 DATOS FARMACÉUTICOS
# Reference: tho 6.1 List of excipients
# ICL:       PHARMACEUTICAL DATA
# RAG:       PHARMACEUTICAL DATA
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4996
# ──────────────────────────────────────────────────────────────────────
# Source:    Cortapapeles [artículos de oficina]
# Reference: Paper knives [cutters] [office requisites]
# ICL:       Scissors [office supplies]
# RAG:       Scissors [office articles]
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4997
# ──────────────────────────────────────────────────────────────────────
# Source:    17 DATOS QUE DEBEN APARECER EN EL ENVASE
# Reference: 15 PARTICULARS TO APPEAR ON THE IMMEDIATE PACKAGE
# ICL:       17 PARTICULARS TO APPEAR ON THE PACKAGE
# RAG:       17 PARTICULARS TO APPEAR ON THE IMMEDIATE PACKAGE
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4998
# ──────────────────────────────────────────────────────────────────────
# Source:    Se presenta este caso clínico por su rareza y por el interés de investigación clínica que representa, dado lo peligroso del hallazgo en un paciente, por lo demás, previamente sano.
# Reference: The case was presented because of its infrequent occurrence and for the interesting clinical analysis it represents, as this finding could herald a serious condition in an otherwise healthy patient. 2. Sharma NS, Doi JL, Papalkar DJ.
# ICL:       This clinical case is presented due to its rarity and the clinical research interest it represents, given the dangerousness of the finding in a patient who was otherwise healthy.
# RAG:       This case is presented due to its rarity and the clinical research interest it represents, given the dangerousness of the finding in a patient who was otherwise previously healthy.
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 4999
# ──────────────────────────────────────────────────────────────────────
# Source:    Frecuentes: hipotensión y efectos relacionados con la hipotensión Muy raros: arritmia, angina de pecho, infarto de miocardio e ictus, posiblemente secundarios a una hipotensión excesiva en los pacientes de alto riesgo (véase 4.4 “ Advertencias y precauciones especiales de empleo).
# Reference: Common: hypotension and effects related to hypotension Very rare: arrhythmia, angina pectoris, myocardial infarction and stroke, possibly secondary to excessive hypotension in high-risk patients (see 4.4 Special warnings and special precautions for use).
# ICL:       - Frequent: hypotension and hypotension-related effects Rare: arrhythmia, chest angina, myocardial infarction and stroke, possibly secondary to excessive hypotension in high-risk patients (see 4.4 "Special warnings and special precautions for use").
# RAG:       Common: hypotension and hypotension-related effects Rare: arrhythmia, angina pectoris, myocardial infarction and stroke, possibly secondary to excessive hypotension in high-risk patients (see 4.4 "Special warnings and special precautions for use).
#
# ──────────────────────────────────────────────────────────────────────
# Sentence 5000
# ──────────────────────────────────────────────────────────────────────
# Source:    Un estudio sobre el tiempo de permanencia de catéteres de acuerdo con el tipo de curativo desarrollado por las investigadoras y publicado en la Revista Latino Americana de Enfermería en 2005, demostró que el tipo de curativo ejerció una influencia significativa p = 0,022 en el tiempo promedio de permanencia de los catéteres estudiados, concluyendo que el curativo con gasa estéril mantiene el catéter por más tiempo.
# Reference: A study related to the length of catheter placement according to the dressing regimes performed by this researchers and published in the Latin American Journal of Nursing in 2005 demonstrated that the type of dressing exerted a significant influence p = 0.022 on the average dwell time of the studied catheters, concluding that the dressing with sterile gauze maintained the catheter placed for a longer time.
# ICL:       A study on the duration of catheters in accordance with the type of dressing developed by the researchers and published in the Latin American Journal of Nursing in 2005, demonstrated that the type of dressing had a significant influence p = 0.022 on the average duration of the catheters studied, concluding that the sterile gauze dressing keeps the catheter in place for a longer period.
# RAG:       A study on the duration of catheter stay according to the type of dressing developed by the researchers and published in the Latin American Journal of Nursing in 2005, demonstrated that the type of dressing had a significant influence p = 0.022 on the average duration of the catheter stay studied, concluding that the sterile gauze dressing keeps the catheter in place for a longer time.

# %%
# # =============================================================================
# # SIMPLE INDEX SIZE TEST
# # =============================================================================

def test_index_size(retriever):
    """Quick check that knowledge base is built correctly"""

    n_vectors = retriever.index.ntotal
    n_spanish = len(retriever.spanish_sentences)
    n_english = len(retriever.english_sentences)

    print("="*70)
    print("KNOWLEDGE BASE SIZE CHECK")
    print("="*70)
    print(f"\nVectors in FAISS index: {n_vectors:,}")
    print(f"Spanish sentences:      {n_spanish:,}")
    print(f"English sentences:      {n_english:,}")

    if n_vectors == n_spanish == n_english:
        print(f"\n✅ PASS: Knowledge base has {n_vectors:,} entries")
        return True
    else:
        print(f"\n❌ FAIL: Counts don't match!")
        return False

# Run the test
test_index_size(retriever)
# Out:
# ======================================================================
# KNOWLEDGE BASE SIZE CHECK
# ======================================================================
#
# Vectors in FAISS index: 50,000
# Spanish sentences:      50,000
# English sentences:      50,000
#
# ✅ PASS: Knowledge base has 50,000 entries
# True
